# %%
54q2aSQIN4MCZ8baU_aw
qU3u6LNbIm
display
start

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "54q2aSQIN4MCZ8baU_aw"
client_secret = "qU3u6LNbIm"
검색어 = '스타벅스'
start=1
api = 'blog'

encText = urllib.parse.quote(검색어)
url = "https://openapi.naver.com/v1/search/"+api+"?query=" + encText + "&display=100&start="+str(start) # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Thu, 04 Aug 2022 09:53:18 +0900",
# 	"total":4251796,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"새로나온 <b>스타벅스<\/b> 퍼플사워블렌디드",
# 			"link":"https:\/\/blog.naver.com\/brightenedu?Redirect=Log&logNo=222786790959",
# 			"description":"얼마 전에 여름 신메뉴 2탄으로 <b>스타벅스<\/b> 퍼플사워블렌디드 포함 3종이 나왔다고 해서 마셔봤어요.... 그래도 <b>스타벅스<\/b> 퍼플사워블렌디드와 커피 드로잉 말차 프라푸치노의 맛이 궁금해 주문해 보았고요. 늘... ",
# 			"bloggername":"김원장의 탐구생활",
# 			"bloggerlink":"https:\/\/blog.naver.com\/brightenedu",
# 			"postdate":"20220624"
# 		},
# 		{
# 			"title":"<b>스타벅스<\/b> 제주 청귤 라임 에이드 직접 마셔본 후기",
# 			"link":"https:\/\/blog.naver.com\/etienne03?Redirect=Log&logNo=222836999230",
# 			"description":"얼마 전 여름 3차 md 나오는 날 저는 <b>스타벅스<\/b> 제주 청귤 라임 에이드 마시고 왔어요. 아침부터 친구랑... 이번 <b>스타벅스<\/b> 신음료는 총 3가지로 제주 청귤 라임 에이드 우리 쑥 크림 프라푸치노 with 콜드 브루 쿨... ",
# 			"bloggername":"Barbie&apos;s place",
# 			"bloggerlink":"https:\/\/blog.naver.com\/etienne03",
# 			"postdate":"20220802"
# 		},
# 		{
# ...

# %%
import json

json_obj = json.loads(response_body)
json_obj
# Out:
# {'lastBuildDate': 'Thu, 04 Aug 2022 09:53:18 +0900',
#  'total': 4251796,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '새로나온 <b>스타벅스</b> 퍼플사워블렌디드',
#    'link': 'https://blog.naver.com/brightenedu?Redirect=Log&logNo=222786790959',
#    'description': '얼마 전에 여름 신메뉴 2탄으로 <b>스타벅스</b> 퍼플사워블렌디드 포함 3종이 나왔다고 해서 마셔봤어요.... 그래도 <b>스타벅스</b> 퍼플사워블렌디드와 커피 드로잉 말차 프라푸치노의 맛이 궁금해 주문해 보았고요. 늘... ',
#    'bloggername': '김원장의 탐구생활',
#    'bloggerlink': 'https://blog.naver.com/brightenedu',
#    'postdate': '20220624'},
#   {'title': '<b>스타벅스</b> 제주 청귤 라임 에이드 직접 마셔본 후기',
#    'link': 'https://blog.naver.com/etienne03?Redirect=Log&logNo=222836999230',
#    'description': '얼마 전 여름 3차 md 나오는 날 저는 <b>스타벅스</b> 제주 청귤 라임 에이드 마시고 왔어요. 아침부터 친구랑... 이번 <b>스타벅스</b> 신음료는 총 3가지로 제주 청귤 라임 에이드 우리 쑥 크림 프라푸치노 with 콜드 브루 쿨... ',
#    'bloggername': 'Barbie&apos;s place',
#    'bloggerlink': 'https://blog.naver.com/etienne03',
#    'postdate': '20220802'},
# ...

# %%
type(json_obj)
# Out:
# dict

# %%
json_obj['total']
# Out:
# 4251796

# %%
f"{json_obj['total']:,}"
# Out:
# '4,251,796'

# %%
json_obj['items']
# Out:
# [{'title': '새로나온 <b>스타벅스</b> 퍼플사워블렌디드',
#   'link': 'https://blog.naver.com/brightenedu?Redirect=Log&logNo=222786790959',
#   'description': '얼마 전에 여름 신메뉴 2탄으로 <b>스타벅스</b> 퍼플사워블렌디드 포함 3종이 나왔다고 해서 마셔봤어요.... 그래도 <b>스타벅스</b> 퍼플사워블렌디드와 커피 드로잉 말차 프라푸치노의 맛이 궁금해 주문해 보았고요. 늘... ',
#   'bloggername': '김원장의 탐구생활',
#   'bloggerlink': 'https://blog.naver.com/brightenedu',
#   'postdate': '20220624'},
#  {'title': '<b>스타벅스</b> 제주 청귤 라임 에이드 직접 마셔본 후기',
#   'link': 'https://blog.naver.com/etienne03?Redirect=Log&logNo=222836999230',
#   'description': '얼마 전 여름 3차 md 나오는 날 저는 <b>스타벅스</b> 제주 청귤 라임 에이드 마시고 왔어요. 아침부터 친구랑... 이번 <b>스타벅스</b> 신음료는 총 3가지로 제주 청귤 라임 에이드 우리 쑥 크림 프라푸치노 with 콜드 브루 쿨... ',
#   'bloggername': 'Barbie&apos;s place',
#   'bloggerlink': 'https://blog.naver.com/etienne03',
#   'postdate': '20220802'},
#  {'title': '<b>스타벅스</b> 원두 데일리로 부담일 때 가성비 핸드드립 커피 원두... ',
#   'link': 'https://blog.naver.com/sticky4?Redirect=Log&logNo=222836936488',
# ...

# %%
len(json_obj['items'])
# Out:
# 100

# %%
import pandas as pd

df = pd.DataFrame(json_obj['items'])

# %%
df
# Out:
#                                            title  \
# 0                      새로나온 <b>스타벅스</b> 퍼플사워블렌디드
# 1             <b>스타벅스</b> 제주 청귤 라임 에이드 직접 마셔본 후기
# 2   <b>스타벅스</b> 원두 데일리로 부담일 때 가성비 핸드드립 커피 원두...
# 3                    <b>스타벅스</b> 천안서북이마트점 리뉴얼 오픈
# 4              <b>스타벅스</b> 선불충전금과 선수금 회계처리 기본 개념
# ..                                           ...
# 95                     대구 월촌 8번출구 <b>스타벅스</b>월촌점
# 96      코로나와 울산 시내 버스 / <b>스타벅스</b> 신메뉴 / 서이추 테러
# 97                    <b>스타벅스</b> 써머 캐빈 파우치 - 그린
# 98                    길벗과 오랜만에 <b>스타벅스</b>에서 아침을
# 99          [양평] <b>스타벅스</b> 더양평 DTR - 양평에 살어리랏다
#
#                                                  link  \
# 0   https://blog.naver.com/brightenedu?Redirect=Lo...
# 1   https://blog.naver.com/etienne03?Redirect=Log&...
# 2   https://blog.naver.com/sticky4?Redirect=Log&lo...
# 3   https://blog.naver.com/renapark99?Redirect=Log...
# 4   https://blog.naver.com/zhowoon79?Redirect=Log&...
# ...

# %%
검색어 = '스타벅스'
start=1
api = 'blog'

res = []
for i in range(3):
    encText = urllib.parse.quote(검색어)
    url = "https://openapi.naver.com/v1/search/"+api+"?query=" + encText + "&display=100&start="+str(start+(i*100)) # json 결과
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if(rescode==200):
        response_body = response.read()
        # print(response_body.decode('utf-8'))
        json_obj = json.loads(response_body)
        tmp = pd.DataFrame(json_obj['items'])
        res.append(tmp)
    else:
        print("Error Code:" + rescode)

# df = pd.DataFrame(res[0]['items'])
# for i in range(1,len(res)):
#     tmp = pd.DataFrame(res[i]['items'])
#     # display(tmp)
#     df =pd.concat([df, tmp])
df = pd.concat(res)
df
# Out:
#                                                 title  \
# 0                           새로나온 <b>스타벅스</b> 퍼플사워블렌디드
# 1                  <b>스타벅스</b> 제주 청귤 라임 에이드 직접 마셔본 후기
# 2        <b>스타벅스</b> 원두 데일리로 부담일 때 가성비 핸드드립 커피 원두...
# 3                         <b>스타벅스</b> 천안서북이마트점 리뉴얼 오픈
# 4                   <b>스타벅스</b> 선불충전금과 선수금 회계처리 기본 개념
# ..                                                ...
# 95      Kt 통신사 멤버쉽 쿠폰 사용더블할인 후기 <b>스타벅스</b> vip쿠폰...
# 96                    구로 디지털단지 “<b>스타벅스</b> 구로디지털타워점”
# 97        <b>스타벅스</b> 2022  프리퀀시 서머 캐리백 레드 (그리고 불량.ㅠ)
# 98  <b>스타벅스</b> B.E.L.T 샌드위치 후기 <b>스타벅스</b> 샌드위치 추...
# 99                     무조건 당첨이벤트(갤럭시워치,<b>스타벅스</b>쿠폰)
#
#                                                  link  \
# 0   https://blog.naver.com/brightenedu?Redirect=Lo...
# 1   https://blog.naver.com/etienne03?Redirect=Log&...
# 2   https://blog.naver.com/sticky4?Redirect=Log&lo...
# 3   https://blog.naver.com/renapark99?Redirect=Log...
# ...

# %%
res[0]
# Out:
# '{\n\t"lastBuildDate":"Thu, 04 Aug 2022 10:27:48 +0900",\n\t"total":4248166,\n\t"start":1,\n\t"display":100,\n\t"items":[\n\t\t{\n\t\t\t"title":"새로나온 <b>스타벅스<\\/b> 퍼플사워블렌디드",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/brightenedu?Redirect=Log&logNo=222786790959",\n\t\t\t"description":"얼마 전에 여름 신메뉴 2탄으로 <b>스타벅스<\\/b> 퍼플사워블렌디드 포함 3종이 나왔다고 해서 마셔봤어요.... 그래도 <b>스타벅스<\\/b> 퍼플사워블렌디드와 커피 드로잉 말차 프라푸치노의 맛이 궁금해 주문해 보았고요. 늘... ",\n\t\t\t"bloggername":"김원장의 탐구생활",\n\t\t\t"bloggerlink":"https:\\/\\/blog.naver.com\\/brightenedu",\n\t\t\t"postdate":"20220624"\n\t\t},\n\t\t{\n\t\t\t"title":"<b>스타벅스<\\/b> 제주 청귤 라임 에이드 직접 마셔본 후기",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/etienne03?Redirect=Log&logNo=222836999230",\n\t\t\t"description":"얼마 전 여름 3차 md 나오는 날 저는 <b>스타벅스<\\/b> 제주 청귤 라임 에이드 마시고 왔어요. 아침부터 친구랑... 이번 <b>스타벅스<\\/b> 신음료는 총 3가지로 제주 청귤 라임 에이드 우리 쑥 크림 프라푸치노 with 콜드 브루 쿨... ",\n\t\t\t"bloggername":"Barbie&apos;s place",\n\t\t\t"bloggerlink":"https:\\/\\/blog.naver.com\\/etienne03",\n\t\t\t"postda
# ...

# %%
res[1]
# Out:
# '{\n\t"lastBuildDate":"Thu, 04 Aug 2022 10:27:10 +0900",\n\t"total":4248506,\n\t"start":101,\n\t"display":100,\n\t"items":[\n\t\t{\n\t\t\t"title":"캠핑장에 함께 한 <b>스타벅스<\\/b> 프리퀀시 서머 캐리백 크림",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/dalcom96?Redirect=Log&logNo=222830092486",\n\t\t\t"description":"이번 캠핑여행엔 <b>스타벅스<\\/b> 서머 캐리백에 캠핑장에서 쓸 베개를 담아 갔답니다. 베개와 대형 타월... <b>스타벅스<\\/b> 서머캐리백, 발암물질 논란…사측 &quot;검사 진행중&quot; 이번에 코베아 캠핑 베개를 2개 구입했어요.... ",\n\t\t\t"bloggername":"크리에이터민의 라이프 스테이지",\n\t\t\t"bloggerlink":"https:\\/\\/blog.naver.com\\/dalcom96",\n\t\t\t"postdate":"20220726"\n\t\t},\n\t\t{\n\t\t\t"title":"방콕의 랑수안 <b>스타벅스<\\/b>는 아시아 1호점이 아닙니다",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/malahalo?Redirect=Log&logNo=222825045305",\n\t\t\t"description":"태국 방콕 여행을 기획한 나언니가 방콕에 아시아 1호점 <b>스타벅스<\\/b>가 있다고 해서 굉장히 설레는... 실제로 국내에선 보기 힘든 형태의 건물이 <b>스타벅스<\\/b>여서 시선을 끌긴 하더라고요. 심지어 저희가 묵었던 호텔... ",\n\t\t\t"bloggername":"라깰의 어제보다 즐거운 오늘",\n\t\t\t"bloggerlink":"https:\\/\\/blog.naver.com\\/malahalo",\n\t
# ...

# %%
res[2]
# Out:
# '{\n\t"lastBuildDate":"Thu, 04 Aug 2022 10:27:10 +0900",\n\t"total":4248578,\n\t"start":201,\n\t"display":100,\n\t"items":[\n\t\t{\n\t\t\t"title":"<b>스타벅스<\\/b> 23주년 기념 MD 투고 그린 5종 실사, 구매후기",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/kmk1264?Redirect=Log&logNo=222818787890",\n\t\t\t"description":"<b>스타벅스<\\/b> 23주년 기념 MD 투고 그린 5종 실사, 구매후기 오늘 <b>스타벅스<\\/b> 23주년 기념 엠디 투고 그린 5종이 출시되는 날이란다 관심없었는데, 어제 인친님 인스타에 뜨길래 또... 키링이 갖고싶어서 아침부터 총총... ",\n\t\t\t"bloggername":"만복이누나님의 블로그",\n\t\t\t"bloggerlink":"https:\\/\\/blog.naver.com\\/kmk1264",\n\t\t\t"postdate":"20220719"\n\t\t},\n\t\t{\n\t\t\t"title":"비오는날, 한강에 떠있는 <b>스타벅스<\\/b>",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/purple4ever?Redirect=Log&logNo=222809538020",\n\t\t\t"description":"내가 가고자 했던 곳은 바로 <b>스타벅스<\\/b> 서울웨이브점. ‘잠원한강공원 <b>스타벅스<\\/b> 한강에 떠있는 선상카페’ 라고 지도에 소개되어 있는데 딱 소개대로다. 흐린 하늘, 뭔가 물결을 표현한 것 같은 카페, 멀리보이는... ",\n\t\t\t"bloggername":"Blog, Purple",\n\t\t\t"bloggerlink":"https:\\/\\/blog.naver.com\\/purple4ever",\n\t\t\t"postdat
# ...

# %%
# 질문 스타벅스, 이디야, 빽다방 300개씩 다 가지고 싶어. 각각 .csv 파일로 저장

카페_리스트 = ['스타벅스', '이디야', '빽다방']
start=1
api = 'blog'

for cafe in 카페_리스트:
    res = []
    for i in range(3):
        encText = urllib.parse.quote(cafe)
        url = "https://openapi.naver.com/v1/search/"+api+"?query=" + encText + "&display=100&start="+str(start+(i*100)) # json 결과
        # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

        request = urllib.request.Request(url)
        request.add_header("X-Naver-Client-Id",client_id)
        request.add_header("X-Naver-Client-Secret",client_secret)
        response = urllib.request.urlopen(request)
        rescode = response.getcode()

        if(rescode==200):
            response_body = response.read()
            # print(response_body.decode('utf-8'))
            json_obj = json.loads(response_body.decode('utf-8'))
            tmp = pd.DataFrame(json_obj['items'])
            res.append(tmp)
        else:
            print("Error Code:" + rescode)

    df = pd.concat(res)
    # display(df)
    df.to_csv(f'./카페/{cafe}.csv', encoding='utf-8-sig')
# Out:
#                                                 title  \
# 0                           새로나온 <b>스타벅스</b> 퍼플사워블렌디드
# 1                  <b>스타벅스</b> 제주 청귤 라임 에이드 직접 마셔본 후기
# 2        <b>스타벅스</b> 원두 데일리로 부담일 때 가성비 핸드드립 커피 원두...
# 3                         <b>스타벅스</b> 천안서북이마트점 리뉴얼 오픈
# 4                   <b>스타벅스</b> 선불충전금과 선수금 회계처리 기본 개념
# ..                                                ...
# 95      Kt 통신사 멤버쉽 쿠폰 사용더블할인 후기 <b>스타벅스</b> vip쿠폰...
# 96                    구로 디지털단지 “<b>스타벅스</b> 구로디지털타워점”
# 97        <b>스타벅스</b> 2022  프리퀀시 서머 캐리백 레드 (그리고 불량.ㅠ)
# 98  <b>스타벅스</b> B.E.L.T 샌드위치 후기 <b>스타벅스</b> 샌드위치 추...
# 99                     무조건 당첨이벤트(갤럭시워치,<b>스타벅스</b>쿠폰)
#
#                                                  link  \
# 0   https://blog.naver.com/brightenedu?Redirect=Lo...
# 1   https://blog.naver.com/etienne03?Redirect=Log&...
# 2   https://blog.naver.com/sticky4?Redirect=Log&lo...
# 3   https://blog.naver.com/renapark99?Redirect=Log...
# ...
