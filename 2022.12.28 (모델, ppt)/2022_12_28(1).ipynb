# %%
import os

path = "C:/Users/user/Desktop/7. 김한호 강사님/raw_data/input/covid19/open/train"
file_list = os.listdir(path)

# print ("file_list: {}".format(file_list))
print(len(file_list))
for file in file_list:
    print(file)
    break
# Out:
# 3805
# 00001.wav

# %%
import pandas as pd

df = pd.read_csv('train_data.csv')
print(df.head())
print(len(df))
# Out:
#    id  age  gender  respiratory_condition  fever_or_muscle_pain  covid19
# 0   1   24  female                      0                     1        0
# 1   2   51    male                      0                     0        0
# 2   3   22    male                      0                     0        0
# 3   4   29  female                      1                     0        0
# 4   5   23    male                      0                     0        0
# 3805

# %%
import shutil
import os

query = 'C:/Users/user/Desktop/8. 부성순 강사님/2022.12.28/train'
query_1 = 'C:/Users/user/Desktop/8. 부성순 강사님/2022.12.28'
mels = os.listdir(query)
covids = df['covid19']
# print(len(mels), len(covids))
for mel,covid in zip(mels,covids):
    print(mel,covid)
    shutil.move(query + '/' + mel, query_1 + '/' + str(covid) + '/' + mel)
    # break
    
# shutil.move(query + '/' + file_name, './custom_dataset/train/' + query + '/' + file_name)
# Out:
# 00001.wav 0
# 00002.wav 0
# 00003.wav 0
# 00004.wav 0
# 00005.wav 0
# 00006.wav 0
# 00007.wav 1
# 00008.wav 0
# 00009.wav 0
# 00010.wav 0
# 00011.wav 0
# 00012.wav 0
# 00013.wav 0
# 00014.wav 0
# 00015.wav 1
# 00016.wav 1
# 00017.wav 0
# 00018.wav 0
# 00019.wav 0
# 00020.wav 0
# 00021.wav 0
# 00022.wav 0
# 00023.wav 1
# 00024.wav 0
# 00025.wav 0
# 00026.wav 0
# 00027.wav 1
# 00028.wav 0
# 00029.wav 0
# 00030.wav 0
# 00031.wav 0
# 00032.wav 0
# 00033.wav 0
# 00034.wav 0
# 00035.wav 0
# 00036.wav 0
# 00037.wav 0
# 00038.wav 0
# 00039.wav 0
# 00040.wav 0
# 00041.wav 0
# 00042.wav 0
# 00043.wav 0
# 00044.wav 0
# 00045.wav 0
# 00046.wav 0
# 00047.wav 0
# 00048.wav 0
# 00049.wav 0
# 00050.wav 1
# 00051.wav 0
# 00052.wav 0
# 00053.wav 0
# 00054.wav 0
# 00055.wav 0
# 00056.wav 0
# 00057.wav 0
# 00058.wav 0
# 00059.wav 0
# 00060.wav 0
# 00061.wav 0
# 00062.wav 0
# 00063.wav 0
# 00064.wav 1
# 00065.wav 0
# 00066.wav 1
# 00067.wav 0
# 00068.wav 0
# 00069.wav 0
# 00070.wav 0
# 00071.wav 0
# ...

# %%
df['covid19'].value_counts()
# Out:
# 0    3499
# 1     306
# Name: covid19, dtype: int64

# %%
# 0 : 304
# 1 : 43

dirty_data_0 = 
f = open("C:/doit/새파일.txt", 'r')
lines = f.readlines()
for line in lines:
    print(line)
f.close()
# Out:
#   Input In [7]
#     dirty_data_0 = [00012.png,
#                          ^
# SyntaxError: invalid decimal literal
