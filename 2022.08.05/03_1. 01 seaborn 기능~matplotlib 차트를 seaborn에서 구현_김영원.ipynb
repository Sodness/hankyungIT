# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from IPython.display import Image

# seaborn
import seaborn as sns

# %%
plt.rc('font', family='NanumBarunGothic') 
plt.rcParams["figure.figsize"] = (12, 9)

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
plt.show()

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex')
plt.show()

# %%
tips.groupby('day').sum()
# Out:
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216

# %%
tips.groupby('day').sum()['total_bill']
# Out:
# day
# Thur    1096.33
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Name: total_bill, dtype: float64

# %%
tips.groupby('day').sum()['total_bill'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='day'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
tips['day'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(tips['day'])
# Out:
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(tips['sex'])
# Out:
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(tips['time'])
# Out:
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
sns.countplot(tips['time'], hue=tips['sex'])
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
sns.countplot(tips['time'], hue=tips['smoker'])
# Out:
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
sns.countplot(tips['time'], hue=tips['day'])
# Out:
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
sns.relplot(x='tip', y='total_bill', data=tips)

# %%
sns.relplot(x='tip', y='total_bill', data=tips, hue='smoker')

# %%
sns.relplot(x='tip', y='total_bill', data=tips, hue='sex')

# %%
sns.relplot(x='tip', y='total_bill', data=tips, hue='day')

# %%
sns.relplot(x='tip', y='total_bill', data=tips, hue='time')

# %%
sns.relplot(x='tip', y='total_bill', data=tips)

# %%
sns.relplot(x='tip', y='total_bill', data=tips, kind='line')

# %%
sns.relplot(x='tip', y='total_bill', data=tips, size='size')

# %%
sns.relplot(x='tip', y='total_bill', data=tips, col='time')

# %%
sns.relplot(x='tip', y='total_bill', data=tips, col='day')

# %%
sns.relplot(x='tip', y='total_bill', data=tips, row='day', col='time')

# %%
sns.relplot(x='tip', y='total_bill', data=tips, col='day', col_wrap=2)

# %%
sns.lmplot(x='tip', y='total_bill', data=tips)

# %%
sns.lmplot(x='tip', y='total_bill', data=tips, hue='sex')

# %%
sns.lmplot(x='tip', y='total_bill', data=tips, col='day')

# %%
sns.lmplot(x='tip', y='total_bill', data=tips, col='day', hue='smoker')

# %%
sns.heatmap(tips.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day', y='total_bill', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day', y='total_bill', data=tips, hue='sex', ci=None)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day', y='total_bill', data=tips, hue='sex', ci=None, palette='YlGnBu_r')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(x='sex', y='survived', data=titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x='sex', y='survived', data=titanic, hue='alone')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>
