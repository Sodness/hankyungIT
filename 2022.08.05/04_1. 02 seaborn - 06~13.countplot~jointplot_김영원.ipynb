# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 한글 폰트 적용
plt.rc('font', family='NanumBarunGothic') 
# 캔버스 사이즈 적용
plt.rcParams["figure.figsize"] = (12, 9)

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# 배경을 darkgrid 로 설정
sns.set(style='darkgrid')

# %%
sns.countplot(x="class", hue="who", data=titanic)
plt.show()

# %%
sns.countplot(y="class", hue="who", data=titanic)
plt.show()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x='day', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(x='day', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(y='day', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='count', ylabel='day'>

# %%
# 샘플데이터 생성
x = np.random.randn(100)
x
# Out:
# array([-0.38466014, -0.81278494, -0.12685066,  0.39875449,  0.2802603 ,
#         0.96557848,  2.78139212,  0.13070429, -0.32060446, -0.42633233,
#         0.96553156, -1.78218842, -1.55207738, -1.91703483,  1.90374139,
#        -1.13916673,  0.75256404,  0.7491246 , -0.11107071,  0.57736013,
#         0.39491127,  0.15859538, -1.08456726, -1.13574508, -1.02012707,
#         1.22446186,  1.63861692, -0.72110373,  0.46912639,  1.46279365,
#        -1.51241311,  0.29264558,  0.39544197, -0.21038278, -0.73388313,
#         1.28233986,  1.23968875,  0.36485575,  0.99008945, -0.74307632,
#        -0.33925786, -0.03346787,  0.08145244, -1.40161259, -1.17260721,
#         0.05180634, -0.30358041, -0.71551888,  0.90982911,  0.83505123,
#        -2.22780632,  0.64539394, -0.43756982,  1.69355035,  0.21016879,
#         0.63629999, -1.87842186, -0.97493355, -1.07190703, -1.22308626,
#        -1.37286666,  0.17879891,  0.34304498, -0.04699182,  1.93936238,
# ...

# %%
sns.distplot(x)
plt.show()
# Out:
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(x='total_bill', data=tips)

# %%
sns.displot(x='tip', data=tips)

# %%
sns.displot(x='tip', data=tips, kde=True)

# %%
sns.distplot(x=tips['tip'], kde=True, hist=False)
# Out:
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(x=tips['tip'], kde=True, hist=False, rug=True)
# Out:
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.groupby(['day', 'size']).count()['tip']
# Out:
# day   size
# Thur  1        1
#       2       48
#       3        4
#       4        5
#       5        1
#       6        3
# Fri   1        1
#       2       16
#       3        1
#       4        1
#       5        0
#       6        0
# Sat   1        2
#       2       53
#       3       18
#       4       13
#       5        1
#       6        0
# Sun   1        0
#       2       39
#       3       15
#       4       18
#       5        3
#       6        1
# Name: tip, dtype: int64

# %%
tmp = tips.groupby(['day', 'size']).mean()['tip'].unstack(1)
tmp
# Out:
# size     1         2         3         4         5    6
# day
# Thur  1.83  2.442500  2.692500  4.218000  5.000000  5.3
# Fri   1.92  2.644375  3.000000  4.730000       NaN  NaN
# Sat   1.00  2.517547  3.797778  4.123846  3.000000  NaN
# Sun    NaN  2.816923  3.120667  4.087778  4.046667  5.0

# %%
sns.heatmap(tmp, cmap='Blues')
# Out:
# <AxesSubplot:xlabel='size', ylabel='day'>

# %%
sns.pairplot(tips)

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.pairplot(tips, hue='size')

# %%
tips['total_bill'].sort_values()
# Out:
# 67      3.07
# 92      5.75
# 111     7.25
# 172     7.25
# 149     7.51
#        ...
# 182    45.35
# 156    48.17
# 59     48.27
# 212    48.33
# 170    50.81
# Name: total_bill, Length: 244, dtype: float64

# %%
tips.sort_values('total_bill', ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# ..          ...    ...     ...    ...   ...     ...   ...
# 149        7.51   2.00    Male     No  Thur   Lunch     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips, hue='size', palette="rainbow")
plt.show()

# %%
sns.jointplot(x="total_bill", y="tip", height=8, data=tips, kind="reg")
plt.show()

# %%
# plt, pandas는 집계를 구해놓고 그리는
# sns는 x축, y축으로 넣고 그리는
