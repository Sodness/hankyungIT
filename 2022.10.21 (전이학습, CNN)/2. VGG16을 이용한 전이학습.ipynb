# %%
#### 드라이브마운트

# %%
#### zip파일 압축해제
# %cd /content/drive/MyDrive/한경IT_5차/data
# %pwd
# Out:
# /content/drive/MyDrive/한경IT_5차/data
# '/content/drive/MyDrive/한경IT_5차/data'

# %%
# !ls
# Out:
# flower_photos.zip

# %%
# !unzip -qq "/content/drive/MyDrive/한경IT_5차/data/flower_photos.zip"

# %%
### 

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Input, models, layers, optimizers, metrics
from tensorflow.keras.layers import Dense, Flatten, Activation, Dropout
from tensorflow.keras.applications import VGG16
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
batch_size = 32   # 한셋트에 몇개의 자료를 넣을것인가? 기본 32로 많이하나 조정해도됨. 숫자를 적게할수록 처리속도가 느려짐
img_height = 180
img_width = 180

data_dir='/content/drive/MyDrive/한경IT_5차/data/flower_photos/'
# 전체 3670개의 이미지자료에서 80%의 2936개를 트레이닝(훈련)자료로 세팅함
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,   # 3670*80%=2936, subset이 training여서 1-0.2임
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)     # 2936개의이미지를 32개씩 세트해서 묶음. 즉 92개세트가 나옴 (92세트*32)

# 전체 3670개의 이미지자료에서 20%의 734개를 테스트데이터로 세팅함
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

# train_ds에 할당된 data_dir 폴더명
class_names = train_ds.class_names
print(class_names)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
data_augmentation = tf.keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
preprocess_input = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)

# %%
base_model = VGG16(input_shape=(180,180,3),
                   include_top=False,
                   weights='imagenet')
base_model.trainable = False

global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
prediction_layer = tf.keras.layers.Dense(5,activation='softmax')

# %%
inputs = tf.keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs =prediction_layer(x)

model = tf.keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  vgg16 (Functional)          (None, 5, 5, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 5)                 2565
#
# =================================================================
# Total params: 14,717,253
# Trainable params: 2,565
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy', # y값이 원핫인코딩이 안되어 있어서임
              metrics=['accuracy'])


# 모델 최적화를 위한 설정 구간입니다.

modelpath="'/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5"

checkpointer = ModelCheckpoint(filepath=modelpath, 
                               monitor='val_loss',       # val_loss값을 기준으로
                               verbose=1,                # 실행결과를 화면에 출력함. verbose=0하면 실행결과가 화면에 나타나지않음
                               save_best_only=True)  # 가장좋은(즉 loss숫자가 가장 낮은) 모델을 저장함

early_stopping_callback = EarlyStopping(monitor='val_loss', 
                                        patience=5) # 실행하다가 5번이상 더 좋은 결과가 없으면 중단

epochs=100
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[early_stopping_callback,checkpointer]
)
# Out:
# Epoch 1/100
# 92/92 [==============================] - ETA: 0s - loss: 1.5264 - accuracy: 0.3604
# Epoch 1: val_loss improved from inf to 1.29014, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 87s 907ms/step - loss: 1.5264 - accuracy: 0.3604 - val_loss: 1.2901 - val_accuracy: 0.6131
# Epoch 2/100
# 91/92 [============================>.] - ETA: 0s - loss: 1.2262 - accuracy: 0.5879
# Epoch 2: val_loss improved from 1.29014 to 1.09783, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 1.2265 - accuracy: 0.5886 - val_loss: 1.0978 - val_accuracy: 0.6689
# Epoch 3/100
# 92/92 [==============================] - ETA: 0s - loss: 1.0701 - accuracy: 0.6461
# Epoch 3: val_loss improved from 1.09783 to 0.98996, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 1.0701 - accuracy: 0.6461 - val_loss: 0.9900 - val_accuracy: 0.6921
# Epoch 4/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.9783 - accuracy: 0.6820
# Epoch 4: val_loss improved from 0.98996 to 0.92270, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.9778 - accuracy: 0.6822 - val_loss: 0.9227 - val_accuracy: 0.7153
# Epoch 5/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.9210 - accuracy: 0.6841
# Epoch 5: val_loss improved from 0.92270 to 0.87618, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.9216 - accuracy: 0.6843 - val_loss: 0.8762 - val_accuracy: 0.7275
# Epoch 6/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.8802 - accuracy: 0.7009
# Epoch 6: val_loss improved from 0.87618 to 0.83891, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.8792 - accuracy: 0.7010 - val_loss: 0.8389 - val_accuracy: 0.7275
# Epoch 7/100
# 92/92 [==============================] - ETA: 0s - loss: 0.8417 - accuracy: 0.7187
# Epoch 7: val_loss improved from 0.83891 to 0.81165, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.8417 - accuracy: 0.7187 - val_loss: 0.8117 - val_accuracy: 0.7425
# Epoch 8/100
# 92/92 [==============================] - ETA: 0s - loss: 0.8179 - accuracy: 0.7163
# Epoch 8: val_loss improved from 0.81165 to 0.78622, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.8179 - accuracy: 0.7163 - val_loss: 0.7862 - val_accuracy: 0.7493
# Epoch 9/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7951 - accuracy: 0.7238
# Epoch 9: val_loss improved from 0.78622 to 0.76552, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.7951 - accuracy: 0.7238 - val_loss: 0.7655 - val_accuracy: 0.7575
# Epoch 10/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.7726 - accuracy: 0.7291
# Epoch 10: val_loss improved from 0.76552 to 0.74614, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.7741 - accuracy: 0.7279 - val_loss: 0.7461 - val_accuracy: 0.7616
# Epoch 11/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7503 - accuracy: 0.7381
# Epoch 11: val_loss improved from 0.74614 to 0.73445, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.7503 - accuracy: 0.7381 - val_loss: 0.7345 - val_accuracy: 0.7684
# Epoch 12/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7398 - accuracy: 0.7439
# Epoch 12: val_loss improved from 0.73445 to 0.71602, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.7398 - accuracy: 0.7439 - val_loss: 0.7160 - val_accuracy: 0.7698
# Epoch 13/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7283 - accuracy: 0.7459
# Epoch 13: val_loss improved from 0.71602 to 0.70667, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.7283 - accuracy: 0.7459 - val_loss: 0.7067 - val_accuracy: 0.7711
# Epoch 14/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.7244 - accuracy: 0.7404
# Epoch 14: val_loss improved from 0.70667 to 0.69617, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.7239 - accuracy: 0.7415 - val_loss: 0.6962 - val_accuracy: 0.7820
# Epoch 15/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.7049 - accuracy: 0.7483
# Epoch 15: val_loss improved from 0.69617 to 0.68702, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.7051 - accuracy: 0.7480 - val_loss: 0.6870 - val_accuracy: 0.7793
# Epoch 16/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.7018 - accuracy: 0.7565
# Epoch 16: val_loss improved from 0.68702 to 0.67477, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.7021 - accuracy: 0.7558 - val_loss: 0.6748 - val_accuracy: 0.7861
# Epoch 17/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.6919 - accuracy: 0.7600
# Epoch 17: val_loss improved from 0.67477 to 0.67375, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.6916 - accuracy: 0.7599 - val_loss: 0.6737 - val_accuracy: 0.7779
# Epoch 18/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.6859 - accuracy: 0.7558
# Epoch 18: val_loss improved from 0.67375 to 0.66504, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 51ms/step - loss: 0.6854 - accuracy: 0.7554 - val_loss: 0.6650 - val_accuracy: 0.7820
# Epoch 19/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.6833 - accuracy: 0.7617
# Epoch 19: val_loss improved from 0.66504 to 0.65692, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.6822 - accuracy: 0.7623 - val_loss: 0.6569 - val_accuracy: 0.7956
# Epoch 20/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.6671 - accuracy: 0.7634
# Epoch 20: val_loss improved from 0.65692 to 0.65466, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.6687 - accuracy: 0.7626 - val_loss: 0.6547 - val_accuracy: 0.7834
# Epoch 21/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.6645 - accuracy: 0.7630
# Epoch 21: val_loss improved from 0.65466 to 0.64643, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.6651 - accuracy: 0.7629 - val_loss: 0.6464 - val_accuracy: 0.7929
# Epoch 22/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6665 - accuracy: 0.7711
# Epoch 22: val_loss improved from 0.64643 to 0.64237, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.6665 - accuracy: 0.7711 - val_loss: 0.6424 - val_accuracy: 0.7916
# Epoch 23/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.6538 - accuracy: 0.7679
# Epoch 23: val_loss improved from 0.64237 to 0.63778, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.6530 - accuracy: 0.7684 - val_loss: 0.6378 - val_accuracy: 0.7888
# Epoch 24/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.6437 - accuracy: 0.7720
# Epoch 24: val_loss improved from 0.63778 to 0.63187, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.6445 - accuracy: 0.7715 - val_loss: 0.6319 - val_accuracy: 0.7929
# Epoch 25/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.6395 - accuracy: 0.7788
# Epoch 25: val_loss improved from 0.63187 to 0.62680, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.6399 - accuracy: 0.7793 - val_loss: 0.6268 - val_accuracy: 0.7956
# Epoch 26/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6410 - accuracy: 0.7725
# Epoch 26: val_loss improved from 0.62680 to 0.62468, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.6410 - accuracy: 0.7725 - val_loss: 0.6247 - val_accuracy: 0.7929
# Epoch 27/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6315 - accuracy: 0.7725
# Epoch 27: val_loss improved from 0.62468 to 0.62138, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.6315 - accuracy: 0.7725 - val_loss: 0.6214 - val_accuracy: 0.7997
# Epoch 28/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6355 - accuracy: 0.7776
# Epoch 28: val_loss improved from 0.62138 to 0.61470, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.6355 - accuracy: 0.7776 - val_loss: 0.6147 - val_accuracy: 0.7956
# Epoch 29/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.6399 - accuracy: 0.7761
# Epoch 29: val_loss improved from 0.61470 to 0.61267, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.6386 - accuracy: 0.7766 - val_loss: 0.6127 - val_accuracy: 0.7943
# Epoch 30/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.6387 - accuracy: 0.7727
# Epoch 30: val_loss improved from 0.61267 to 0.61083, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.6369 - accuracy: 0.7742 - val_loss: 0.6108 - val_accuracy: 0.8038
# Epoch 31/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6220 - accuracy: 0.7786
# Epoch 31: val_loss improved from 0.61083 to 0.60671, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.6220 - accuracy: 0.7786 - val_loss: 0.6067 - val_accuracy: 0.7997
# Epoch 32/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.6137 - accuracy: 0.7830
# Epoch 32: val_loss did not improve from 0.60671
# 92/92 [==============================] - 4s 47ms/step - loss: 0.6123 - accuracy: 0.7837 - val_loss: 0.6083 - val_accuracy: 0.7984
# Epoch 33/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6178 - accuracy: 0.7790
# Epoch 33: val_loss improved from 0.60671 to 0.60020, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.6178 - accuracy: 0.7790 - val_loss: 0.6002 - val_accuracy: 0.7997
# Epoch 34/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.6137 - accuracy: 0.7826
# Epoch 34: val_loss did not improve from 0.60020
# 92/92 [==============================] - 5s 47ms/step - loss: 0.6129 - accuracy: 0.7830 - val_loss: 0.6004 - val_accuracy: 0.7943
# Epoch 35/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.6201 - accuracy: 0.7785
# Epoch 35: val_loss improved from 0.60020 to 0.59577, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.6190 - accuracy: 0.7793 - val_loss: 0.5958 - val_accuracy: 0.7984
# Epoch 36/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5920 - accuracy: 0.7888
# Epoch 36: val_loss did not improve from 0.59577
# 92/92 [==============================] - 5s 47ms/step - loss: 0.5921 - accuracy: 0.7881 - val_loss: 0.5979 - val_accuracy: 0.7956
# Epoch 37/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.6058 - accuracy: 0.7854
# Epoch 37: val_loss did not improve from 0.59577
# 92/92 [==============================] - 5s 47ms/step - loss: 0.6064 - accuracy: 0.7844 - val_loss: 0.5988 - val_accuracy: 0.8011
# Epoch 38/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6043 - accuracy: 0.7909
# Epoch 38: val_loss improved from 0.59577 to 0.58762, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.6043 - accuracy: 0.7909 - val_loss: 0.5876 - val_accuracy: 0.8025
# Epoch 39/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6155 - accuracy: 0.7779
# Epoch 39: val_loss did not improve from 0.58762
# 92/92 [==============================] - 4s 47ms/step - loss: 0.6155 - accuracy: 0.7779 - val_loss: 0.5908 - val_accuracy: 0.8011
# Epoch 40/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.6001 - accuracy: 0.7806
# Epoch 40: val_loss improved from 0.58762 to 0.58690, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.6051 - accuracy: 0.7793 - val_loss: 0.5869 - val_accuracy: 0.7902
# Epoch 41/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.6062 - accuracy: 0.7867
# Epoch 41: val_loss improved from 0.58690 to 0.58467, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.6054 - accuracy: 0.7875 - val_loss: 0.5847 - val_accuracy: 0.7984
# Epoch 42/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5963 - accuracy: 0.7970
# Epoch 42: val_loss improved from 0.58467 to 0.58001, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.5961 - accuracy: 0.7970 - val_loss: 0.5800 - val_accuracy: 0.8025
# Epoch 43/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5935 - accuracy: 0.7858
# Epoch 43: val_loss improved from 0.58001 to 0.57851, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.5935 - accuracy: 0.7858 - val_loss: 0.5785 - val_accuracy: 0.8038
# Epoch 44/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5901 - accuracy: 0.7891
# Epoch 44: val_loss did not improve from 0.57851
# 92/92 [==============================] - 4s 47ms/step - loss: 0.5896 - accuracy: 0.7892 - val_loss: 0.5815 - val_accuracy: 0.8011
# Epoch 45/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5878 - accuracy: 0.7871
# Epoch 45: val_loss did not improve from 0.57851
# 92/92 [==============================] - 4s 47ms/step - loss: 0.5878 - accuracy: 0.7871 - val_loss: 0.5824 - val_accuracy: 0.7997
# Epoch 46/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5912 - accuracy: 0.7854
# Epoch 46: val_loss did not improve from 0.57851
# 92/92 [==============================] - 4s 47ms/step - loss: 0.5912 - accuracy: 0.7854 - val_loss: 0.5854 - val_accuracy: 0.7943
# Epoch 47/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5820 - accuracy: 0.7936
# Epoch 47: val_loss improved from 0.57851 to 0.57191, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.5834 - accuracy: 0.7926 - val_loss: 0.5719 - val_accuracy: 0.8079
# Epoch 48/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5858 - accuracy: 0.7922
# Epoch 48: val_loss did not improve from 0.57191
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5846 - accuracy: 0.7926 - val_loss: 0.5745 - val_accuracy: 0.8038
# Epoch 49/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5724 - accuracy: 0.7922
# Epoch 49: val_loss did not improve from 0.57191
# 92/92 [==============================] - 4s 47ms/step - loss: 0.5724 - accuracy: 0.7922 - val_loss: 0.5722 - val_accuracy: 0.8038
# Epoch 50/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5812 - accuracy: 0.7998
# Epoch 50: val_loss improved from 0.57191 to 0.56987, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.5833 - accuracy: 0.7987 - val_loss: 0.5699 - val_accuracy: 0.8038
# Epoch 51/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5869 - accuracy: 0.7851
# Epoch 51: val_loss improved from 0.56987 to 0.56585, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.5869 - accuracy: 0.7851 - val_loss: 0.5659 - val_accuracy: 0.8093
# Epoch 52/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5846 - accuracy: 0.7885
# Epoch 52: val_loss did not improve from 0.56585
# 92/92 [==============================] - 4s 47ms/step - loss: 0.5846 - accuracy: 0.7885 - val_loss: 0.5669 - val_accuracy: 0.8106
# Epoch 53/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5682 - accuracy: 0.8005
# Epoch 53: val_loss did not improve from 0.56585
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5682 - accuracy: 0.8001 - val_loss: 0.5716 - val_accuracy: 0.8065
# Epoch 54/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5651 - accuracy: 0.7916
# Epoch 54: val_loss improved from 0.56585 to 0.56474, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.5647 - accuracy: 0.7916 - val_loss: 0.5647 - val_accuracy: 0.8147
# Epoch 55/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5781 - accuracy: 0.7902
# Epoch 55: val_loss did not improve from 0.56474
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5773 - accuracy: 0.7899 - val_loss: 0.5669 - val_accuracy: 0.8093
# Epoch 56/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5791 - accuracy: 0.7892
# Epoch 56: val_loss improved from 0.56474 to 0.56082, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.5791 - accuracy: 0.7892 - val_loss: 0.5608 - val_accuracy: 0.8147
# Epoch 57/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5718 - accuracy: 0.7973
# Epoch 57: val_loss did not improve from 0.56082
# 92/92 [==============================] - 4s 47ms/step - loss: 0.5718 - accuracy: 0.7973 - val_loss: 0.5677 - val_accuracy: 0.8065
# Epoch 58/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5596 - accuracy: 0.7974
# Epoch 58: val_loss did not improve from 0.56082
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5601 - accuracy: 0.7970 - val_loss: 0.5618 - val_accuracy: 0.8093
# Epoch 59/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5720 - accuracy: 0.7905
# Epoch 59: val_loss did not improve from 0.56082
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5719 - accuracy: 0.7905 - val_loss: 0.5655 - val_accuracy: 0.8147
# Epoch 60/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5557 - accuracy: 0.7984
# Epoch 60: val_loss improved from 0.56082 to 0.55930, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.5556 - accuracy: 0.7984 - val_loss: 0.5593 - val_accuracy: 0.8079
# Epoch 61/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5746 - accuracy: 0.7946
# Epoch 61: val_loss did not improve from 0.55930
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5746 - accuracy: 0.7946 - val_loss: 0.5610 - val_accuracy: 0.8161
# Epoch 62/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5635 - accuracy: 0.7997
# Epoch 62: val_loss did not improve from 0.55930
# 92/92 [==============================] - 4s 47ms/step - loss: 0.5635 - accuracy: 0.7997 - val_loss: 0.5595 - val_accuracy: 0.8147
# Epoch 63/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5633 - accuracy: 0.7902
# Epoch 63: val_loss did not improve from 0.55930
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5640 - accuracy: 0.7899 - val_loss: 0.5621 - val_accuracy: 0.8079
# Epoch 64/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5600 - accuracy: 0.8019
# Epoch 64: val_loss improved from 0.55930 to 0.55880, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.5597 - accuracy: 0.8018 - val_loss: 0.5588 - val_accuracy: 0.8147
# Epoch 65/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5672 - accuracy: 0.8065
# Epoch 65: val_loss improved from 0.55880 to 0.55663, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.5672 - accuracy: 0.8065 - val_loss: 0.5566 - val_accuracy: 0.8147
# Epoch 66/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5563 - accuracy: 0.8018
# Epoch 66: val_loss improved from 0.55663 to 0.55531, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 49ms/step - loss: 0.5563 - accuracy: 0.8018 - val_loss: 0.5553 - val_accuracy: 0.8106
# Epoch 67/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5599 - accuracy: 0.7977
# Epoch 67: val_loss improved from 0.55531 to 0.55175, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 51ms/step - loss: 0.5590 - accuracy: 0.7984 - val_loss: 0.5518 - val_accuracy: 0.8079
# Epoch 68/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5528 - accuracy: 0.8007
# Epoch 68: val_loss did not improve from 0.55175
# 92/92 [==============================] - 4s 47ms/step - loss: 0.5528 - accuracy: 0.8007 - val_loss: 0.5544 - val_accuracy: 0.8052
# Epoch 69/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5584 - accuracy: 0.8015
# Epoch 69: val_loss improved from 0.55175 to 0.54799, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.5598 - accuracy: 0.8004 - val_loss: 0.5480 - val_accuracy: 0.8147
# Epoch 70/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5665 - accuracy: 0.7963
# Epoch 70: val_loss did not improve from 0.54799
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5665 - accuracy: 0.7963 - val_loss: 0.5554 - val_accuracy: 0.8106
# Epoch 71/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5378 - accuracy: 0.8098
# Epoch 71: val_loss did not improve from 0.54799
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5391 - accuracy: 0.8096 - val_loss: 0.5494 - val_accuracy: 0.8106
# Epoch 72/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5529 - accuracy: 0.8067
# Epoch 72: val_loss did not improve from 0.54799
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5550 - accuracy: 0.8055 - val_loss: 0.5489 - val_accuracy: 0.8174
# Epoch 73/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5569 - accuracy: 0.7984
# Epoch 73: val_loss did not improve from 0.54799
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5579 - accuracy: 0.7984 - val_loss: 0.5481 - val_accuracy: 0.8106
# Epoch 74/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5487 - accuracy: 0.8063
# Epoch 74: val_loss improved from 0.54799 to 0.54394, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.5503 - accuracy: 0.8055 - val_loss: 0.5439 - val_accuracy: 0.8093
# Epoch 75/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5545 - accuracy: 0.8029
# Epoch 75: val_loss did not improve from 0.54394
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5538 - accuracy: 0.8031 - val_loss: 0.5468 - val_accuracy: 0.8147
# Epoch 76/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5522 - accuracy: 0.8049
# Epoch 76: val_loss did not improve from 0.54394
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5519 - accuracy: 0.8052 - val_loss: 0.5481 - val_accuracy: 0.8120
# Epoch 77/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5542 - accuracy: 0.8048
# Epoch 77: val_loss improved from 0.54394 to 0.54375, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.5542 - accuracy: 0.8048 - val_loss: 0.5437 - val_accuracy: 0.8106
# Epoch 78/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5420 - accuracy: 0.8053
# Epoch 78: val_loss did not improve from 0.54375
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5429 - accuracy: 0.8052 - val_loss: 0.5490 - val_accuracy: 0.8052
# Epoch 79/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5556 - accuracy: 0.7964
# Epoch 79: val_loss did not improve from 0.54375
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5563 - accuracy: 0.7963 - val_loss: 0.5474 - val_accuracy: 0.8079
# Epoch 80/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5543 - accuracy: 0.8014
# Epoch 80: val_loss improved from 0.54375 to 0.54371, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.5543 - accuracy: 0.8014 - val_loss: 0.5437 - val_accuracy: 0.8229
# Epoch 81/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5424 - accuracy: 0.8053
# Epoch 81: val_loss improved from 0.54371 to 0.53991, saving model to '/content/drive/MyDrive/한경IT_5차/model/flower_CNN_전이학습_에포크100.hdf5
# 92/92 [==============================] - 5s 48ms/step - loss: 0.5426 - accuracy: 0.8048 - val_loss: 0.5399 - val_accuracy: 0.8147
# Epoch 82/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5451 - accuracy: 0.8073
# Epoch 82: val_loss did not improve from 0.53991
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5450 - accuracy: 0.8072 - val_loss: 0.5433 - val_accuracy: 0.8161
# Epoch 83/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5458 - accuracy: 0.7933
# Epoch 83: val_loss did not improve from 0.53991
# 92/92 [==============================] - 4s 47ms/step - loss: 0.5438 - accuracy: 0.7939 - val_loss: 0.5456 - val_accuracy: 0.8188
# Epoch 84/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5486 - accuracy: 0.8039
# Epoch 84: val_loss did not improve from 0.53991
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5487 - accuracy: 0.8031 - val_loss: 0.5443 - val_accuracy: 0.8202
# Epoch 85/100
# 91/92 [============================>.] - ETA: 0s - loss: 0.5363 - accuracy: 0.8108
# Epoch 85: val_loss did not improve from 0.53991
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5360 - accuracy: 0.8106 - val_loss: 0.5402 - val_accuracy: 0.8215
# Epoch 86/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5489 - accuracy: 0.8076
# Epoch 86: val_loss did not improve from 0.53991
# 92/92 [==============================] - 4s 46ms/step - loss: 0.5489 - accuracy: 0.8076 - val_loss: 0.5433 - val_accuracy: 0.8161

# %%
## 차트작성함
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)

plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open('./독일교통표지판/새 폴더/1.png')
plt.imshow(img)
plt.show()
plt.imshow(img.resize((180,180)))
plt.show()
