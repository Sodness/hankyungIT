# %%
import re
import pandas as pd

# %%
morrie='''루게릭병을 앓으며 죽음을 앞두고 있는 한 저명한 사회학 교수가 있다. 보스턴의 어느 교외 지역, 그는 히비스커스 화분이 있는 서재에 앉아 숨을 들이쉬고 다음 내쉴 때까지 숫자를 헤아리면서 자신의 죽음이 어디까지 가까워졌는지를 가늠해 본다. 그리고 디트로이트의 한 신문사에서는 대학 시절 그의 수업을 하나도 빠짐없이 수강하며 열정적인 꿈을 꾸던 제자가 있다. 그는 바쁘게 돌아가는 일상 때문에 졸업식 이후에도 계속 연락하겠다던 스승과의 약속을 저버린 채 일에 끌려 다니며 하루하루를 보낸다. 우연히 텔레비전을 통해 삶을 끝마쳐 가는 옛 은사의 모습을 발견하지 못했더라면 그는 아마 지금도 사회적 성공과 야망을 향해 질주하고 있을 것이다.

『모리와 함께한 화요일』은 영혼의 결핍을 느끼던 그 제자 미치가 옛 스승을 찾아감으로써 시작된다. 미치는 서너 달에 걸쳐 매주 화요일마다 모리 교수와 함께 인생을 이야기한다. 그들의 대화 주제는 세상, 가족, 죽음, 자기 연민, 사랑 등이다. 이는 미치뿐만 아니라 이 세상 모두가 치열한 삶으로 인해 잃어버린 것들을 되찾아 가는 과정이기도 하다. 미국의 시인인 에머슨의 이 말은 모리 교수가 가진 스승으로서의 가치를 제대로 설명한다. 위대한 스승이란 인생의 의미를 깨우쳐 주고 상대를 변화하게 만드는 사람이기 때문이다. 모리 교수는 인생의 스승으로서 죽음 후에도 많은 사람의 삶과 관계를 맺고 있다. 이들이 삶에서 놓치고 있는 많은 것들을 되찾아 주는 교두보 역할을 하면서 말이다. 요컨대, 이 책은 우리가 삶에서 잃어버린 것들을 찾아가는 과정이다. 어느 때보다도 치열하고 경쟁적인 문화 속에서, 죽어 가는 모리 교수는 살아 있는 우리가 알아야 할 것들을 알려 준다.

문학가 > 현대문학가＞영미작가
미치 앨봄 저자 미치 앨봄은 에미상을 수상한 바 있는 방송가이자 칼럼니스트. 작품 속에서 평범한 사람들이 자기 연민과 고통을 넘어 삶의 숨겨진 의미를 깨달아 가는 과정을 감동적으로 형상화하여 각종 언론에서 ‘최고의 휴머니스트 작가’로 평가받고 있다. 스포츠 칼럼니스트로 이름을 알리기 시작한 이후 라디오와 ABC TV 등 여러 방송 매체에서 진행자로서 두각을 나타내던 앨봄은 우연히 대학 시절 은사인 모리 교수와 재회하게 되었다. 이것을 계기로 그는 세속적인 성공만 추구하던 삶에 변화를 겪었고, 현재는 여러 자선 단체에 소속되어 있으면서 글쓰기에만 전념하고 있다. 『모리와 함께한 화요일』 이외에도 『천국에서 만난 다섯 사람』 『단 하루만 더』 등 그의 작품들은 많은 나라에서 번역 출간되어 전 세계 독자들에게 감동을 주었다. 현재 앨봄은 미시간 주에서 아내 제닌과 함께 모리에게서 배운 것들을 가슴에 담고 새로운 인생을 살고 있다.

'''

# %%
print(morrie)
# Out:
# 루게릭병을 앓으며 죽음을 앞두고 있는 한 저명한 사회학 교수가 있다. 보스턴의 어느 교외 지역, 그는 히비스커스 화분이 있는 서재에 앉아 숨을 들이쉬고 다음 내쉴 때까지 숫자를 헤아리면서 자신의 죽음이 어디까지 가까워졌는지를 가늠해 본다. 그리고 디트로이트의 한 신문사에서는 대학 시절 그의 수업을 하나도 빠짐없이 수강하며 열정적인 꿈을 꾸던 제자가 있다. 그는 바쁘게 돌아가는 일상 때문에 졸업식 이후에도 계속 연락하겠다던 스승과의 약속을 저버린 채 일에 끌려 다니며 하루하루를 보낸다. 우연히 텔레비전을 통해 삶을 끝마쳐 가는 옛 은사의 모습을 발견하지 못했더라면 그는 아마 지금도 사회적 성공과 야망을 향해 질주하고 있을 것이다.
#
# 『모리와 함께한 화요일』은 영혼의 결핍을 느끼던 그 제자 미치가 옛 스승을 찾아감으로써 시작된다. 미치는 서너 달에 걸쳐 매주 화요일마다 모리 교수와 함께 인생을 이야기한다. 그들의 대화 주제는 세상, 가족, 죽음, 자기 연민, 사랑 등이다. 이는 미치뿐만 아니라 이 세상 모두가 치열한 삶으로 인해 잃어버린 것들을 되찾아 가는 과정이기도 하다. 미국의 시인인 에머슨의 이 말은 모리 교수가 가진 스승으로서의 가치를 제대로 설명한다. 위대한 스승이란 인생의 의미를 깨우쳐 주고 상대를 변화하게 만드는 사람이기 때문이다. 모리 교수는 인생의 스승으로서 죽음 후에도 많은 사람의 삶과 관계를 맺고 있다. 이들이 삶에서 놓치고 있는 많은 것들을 되찾아 주는 교두보 역할을 하면서 말이다. 요컨대, 이 책은 우리가 삶에서 잃어버린 것들을 찾아가는 과정이다. 어느 때보다도 치열하고 경쟁적인 문화 속에서, 죽어 가는 모리 교수는 살아 있는 우리가 알아야 할 것들을 알려 준다.
#
# 문학가 > 현대문학가＞영미작가
# ...

# %% [markdown]
# ### [미션1]
# - 교수가 포함된 문장을 추출하시오
#
# ![image.png](attachment:image.png)

# %%
re.findall('[가-힣a-zA-z ,]+교수[가-힣a-zA-z ,]+', morrie)
# Out:
# ['루게릭병을 앓으며 죽음을 앞두고 있는 한 저명한 사회학 교수가 있다',
#  ' 미치는 서너 달에 걸쳐 매주 화요일마다 모리 교수와 함께 인생을 이야기한다',
#  ' 미국의 시인인 에머슨의 이 말은 모리 교수가 가진 스승으로서의 가치를 제대로 설명한다',
#  ' 모리 교수는 인생의 스승으로서 죽음 후에도 많은 사람의 삶과 관계를 맺고 있다',
#  ' 어느 때보다도 치열하고 경쟁적인 문화 속에서, 죽어 가는 모리 교수는 살아 있는 우리가 알아야 할 것들을 알려 준다',
#  ' 스포츠 칼럼니스트로 이름을 알리기 시작한 이후 라디오와 ABC TV 등 여러 방송 매체에서 진행자로서 두각을 나타내던 앨봄은 우연히 대학 시절 은사인 모리 교수와 재회하게 되었다']

# %% [markdown]
# ### 1. 상호 추출

# %%
sample='''바비레드 강남본점 거리뷰 항공뷰  가격
서울특별시 강남구 봉은사로6길 39 지번
02-3452-1515  음식점 > 양식
 생방송오늘저녁 | 레드갈비파스타
'''

# %%
tmp = re.search('.+거리뷰', sample).group()
tmp[:-4]
# Out:
# '바비레드 강남본점'

# %%
#1.find함수 활용:find('찾을 문자')
#상호: '거리뷰' 앞까지 문자
sh=sample.find('거리뷰')-1
sample[:sh]
# Out:
# '바비레드 강남본점'

# %%
#2. 정규표현식: re.search()
#상호: '거리뷰' 앞까지 문자
sh2=re.search('거리뷰',sample).start()-1
sample[:sh2]
# Out:
# '바비레드 강남본점'

# %% [markdown]
# ### 2 .전화번호 추출

# %%
pe=re.compile('\d{2}-\d{4}-\d{4}')
pe.findall(sample)
# Out:
# ['02-3452-1515']

# %%
mask = re.compile('\d{2,3}-\d{4}-\d{4}')
mask.findall(txt)
# Out:
# ['02-3452-1515',
#  '070-4240-1116',
#  '070-4230-2233',
#  '070-8868-0150',
#  '02-3453-7697',
#  '02-2051-1477',
#  '070-8885-5199',
#  '02-6448-6110',
#  '02-6925-0087',
#  '02-6440-5500',
#  '02-3452-3441',
#  '02-2039-2275',
#  '02-3454-1009']

# %% [markdown]
# ### [미션 2] 상호와 전화번호를 모두 찾아 데이터프레임으로 저장하시오.
#
# ![image.png](attachment:image.png)

# %%
# 하나 안됨
tmp = re.split('즐겨찾기에 추가', txt)
res = []
for i in tmp:
    tmp = re.search('.+거리뷰', i).group()
    name = tmp[:-4]
    mask = re.compile('\d{2,3}-\d{3,4}-\d{4}')
    tel = mask.findall(i)
    if len(tel)==0:
        tel.append('-')
    res.append([name, tel[0]])

df = pd.DataFrame(res, columns = ['상호', '전화번호'])
df
# Out:
#                 상호           전화번호
# 0        바비레드 강남본점   02-3452-1515
# 1         마녀주방 강남점  070-4240-1116
# 2     프리모바치오바치 강남점    02-501-0885
# 3          고에몬 강남점    02-534-8036
# 4          토끼정 강남점  070-4230-2233
# 5               땀땀    02-554-8892
# 6   어글리스토브 신논현강남역점    02-558-8459
# 7    미즈컨테이너 강남 웨스트  070-8868-0150
# 8          아이해브어드림   02-3453-7697
# 9         갓덴스시 강남점   02-2051-1477
# 10       마키노차야 역삼점    02-565-1116
# 11            봉우화로    02-558-8452
# 12           AY라운지    02-552-8199
# 13        쉐이크쉑 강남점    02-553-5576
# 14     맥쓰세계치킨 강남역점    02-737-8292
# 15       타이거슈가 강남점              -
# 16   미즈컨테이너 강남 이스트  070-8885-5199
# 17       낙원타코 강남역점    02-595-1540
# 18        도치피자 강남점    02-556-8001
# 19          알부자알요리    02-508-4629
# 20      애슐리W 강남2호점    02-532-1592
# 21       에스프레소 퍼블릭    02-556-9317
# 22         스시오 강남점    02-538-9967
# 23      아트몬스터 강남역점   02-6448-6110
# 24         을밀대 강남점    02-552-1922
# 25              아쭈    02-558-5353
# ...

# %%
# 고침
tmp = re.split('즐겨찾기에 추가', txt)
res = []
for i in tmp:
    tmp = re.search('.+거리뷰', i).group()
    name = tmp[:-4]
    tel_str = re.search('.+>', i).group()
    tel = tel_str.split(' ')[0]
    res.append([name, tel])

df = pd.DataFrame(res, columns = ['상호', '전화번호'])
df
# Out:
#                 상호           전화번호
# 0        바비레드 강남본점   02-3452-1515
# 1         마녀주방 강남점  070-4240-1116
# 2     프리모바치오바치 강남점    02-501-0885
# 3          고에몬 강남점    02-534-8036
# 4          토끼정 강남점  070-4230-2233
# 5               땀땀    02-554-8892
# 6   어글리스토브 신논현강남역점    02-558-8459
# 7    미즈컨테이너 강남 웨스트  070-8868-0150
# 8          아이해브어드림   02-3453-7697
# 9         갓덴스시 강남점   02-2051-1477
# 10       마키노차야 역삼점    02-565-1116
# 11            봉우화로    02-558-8452
# 12           AY라운지    02-552-8199
# 13        쉐이크쉑 강남점    02-553-5576
강남점 거리뷰 항공뷰  가격
서울특별시 강남구 강남대로 358 1층 지번
02-2039-2275 도시락,컵밥 > 다이어트,샐러드
즐겨찾기에 추가
하루하루 코리아 강남 거리뷰 항공뷰  가격
서울특별시 서초구 서초대로77길 3 아라타워 지번
02-595-4952  일식 > 샤브샤브
 모닝와이드 | 이색샤부샤부
즐겨찾기에 추가
엠마앤리아 거리뷰 항공뷰  가격
서울특별시 강남구 강남대로92길 13 제리스플래닛빌딩 1층 지번
02-555-4207  음식점 > 카페,디저트
즐겨찾기에 추가
더플라잉팬레드 거리뷰 항공뷰  가격
서울특별시 서초구 서초대로 411 지티타워 지하1층 지번
02-590-2488  카페,디저트 > 카페
즐겨찾기에 추가
파파야리프 거리뷰 항공뷰  가격
서울특별시 강남구 강남대로102길 29 지번
02-566-6178  음식점 > 아시아음식
즐겨찾기에 추가
창고43 강남점 거리뷰 항공뷰  가격 예약
서울특별시 강남구 강남대로 362 대륭강남타워 지하1층 지번
02-508-0043  한식 > 소고기구이
즐겨찾기에 추가
자연별곡 강남역점 거리뷰 항공뷰  가격 예약
서울특별시 강남구 테헤란로 117 KB손해보험빌딩 지하1층 지번
02-564-0540  음식점 > 한식뷔페
즐겨찾기에 추가
두끼떡볶이 강남점 거리뷰 항공뷰  가격
서울특별시 강남구 강남대로94길 11 2층 지번
02-3454-1009  음식점 > 분식
즐겨찾기에 추가
로리스 더 프라임 립 거리뷰 항공뷰  가격 예약
서울특별시 서초구 서초대로 411 GT TOWER 지번
02-590-2800  음식점 > 스테이크,립
 수요미식회 | 프라임립
즐겨찾기에 추가
설빙 강남역점 거리뷰 항공뷰  가격
서울특별시 강남구 강남대로102길 14 장연빌딩 지번
02-558-7708  카페,디저트 > 빙수
즐겨찾기에 추가
무차초 서울 거리뷰 항공뷰  가격
서울특별시 강남구 봉은사로4길 37 지하1층 지번
02-538-8854 음식점 > 멕시코,남미음식
'''

# %%
import pandas as pd 

name=re.compile('[가-힣 ]+(?= 거리뷰)')
res1=name.findall(txt)
tel=re.compile('\d+-\d+-\d+')
res2=tel.findall(txt)

df1=pd.DataFrame(res1)
df2=pd.DataFrame(res2)

df=pd.concat([df1,df2],axis=1)
df.columns=['상호','전화번호']
display(df)
# Out:
#                 상호           전화번호
# 0        바비레드 강남본점   02-3452-1515
# 1         마녀주방 강남점  070-4240-1116
# 2     프리모바치오바치 강남점    02-501-0885
# 3          고에몬 강남점    02-534-8036
# 4          토끼정 강남점  070-4230-2233
# 5               땀땀    02-554-8892
# 6   어글리스토브 신논현강남역점    02-558-8459
# 7    미즈컨테이너 강남 웨스트  070-8868-0150
# 8          아이해브어드림   02-3453-7697
# 9         갓덴스시 강남점   02-2051-1477
# 10             알베르    02-566-6181
# 11       마키노차야 역삼점    02-565-1116
# 12            봉우화로    02-558-8452
# 13             라운지    02-552-8199
# 14        쉐이크쉑 강남점    02-553-5576
# 15     맥쓰세계치킨 강남역점    02-737-8292
# 16       타이거슈가 강남점  070-8885-5199
# 17   미즈컨테이너 강남 이스트    02-595-1540
# 18       낙원타코 강남역점    02-556-8001
# 19        도치피자 강남점    02-508-4665
# 20             아실라    02-508-4629
# 21          알부자알요리    02-532-1592
# 22              호점    02-556-9317
# 23       에스프레소 퍼블릭    02-538-9967
# 24         스시오 강남점   02-6448-6110
# 25      아트몬스터 강남역점    02-552-1922
# ...

# %% [markdown]
# #### [Step 1] 엔터키 기준으로 나누기(split)

# %%
txt_enter_split=txt.split('\n')

# %%
txt.split('\n')
# Out:
# ['바비레드 강남본점 거리뷰 항공뷰  가격',
#  '서울특별시 강남구 봉은사로6길 39 지번',
#  '02-3452-1515  음식점 > 양식',
#  ' 생방송오늘저녁 | 레드갈비파스타',
#  '즐겨찾기에 추가',
#  '마녀주방 강남점 거리뷰 항공뷰  가격 예약',
#  '서울특별시 강남구 강남대로94길 9 지번',
#  '070-4240-1116 양식 > 이탈리아음식',
#  ' 생방송오늘저녁 | 파스타',
#  '즐겨찾기에 추가',
#  '프리모바치오바치 강남점 거리뷰 항공뷰  가격',
#  '서울특별시 강남구 강남대로 416 창림빌딩 지번',
#  '02-501-0885  양식 > 이탈리아음식',
#  '즐겨찾기에 추가',
#  '고에몬 강남점 거리뷰 항공뷰  가격',
#  '서울특별시 서초구 서초대로77길 7 서초빌딩 1층 지번',
#  '02-534-8036 이탈리아음식 > 스파게티,파스타전문',
#  ' 생활의달인 | 수플레오믈렛',
#  '즐겨찾기에 추가',
#  '토끼정 강남점 거리뷰 항공뷰  가격',
#  '서울특별시 강남구 봉은사로6길 32 지번',
#  '070-4230-2233  일식 > 일식당',
#  ' 찾아라맛있는TV | 카레나베',
#  '즐겨찾기에 추가',
#  '땀땀 거리뷰 항공뷰  가격',
#  '서울특별시 강남구 강남대로98길 12-5 지번',
#  '02-554-8892  음식점 > 베트남음식',
#  ' 생방송오늘저녁 | 곱창쌀국수/불타는쌀국수',
#  '즐겨찾기에 추가',
#  '어글리스토브 신논현강남역점 거리뷰  가격 예약',
#  '서울특별시 강남구 강남대로98길 20 지번',
#  '02-558-8459  양식 > 브런치',
#  '즐겨찾기에 추가',
#  '미즈컨테이너 강남 웨스트 거리뷰 항공뷰  가격',
#  '서울특별시 서초구 서초대로73길 9 타임빌딩 1층 지번',
#  '070-8868-0150 양식 > 이탈리아음식',
#  '즐겨찾기에 추가',
# ...

# %% [markdown]
# #### [Stip2] '즐겨찾기'까지 리스트에 담기

# %%
# Out:
#                 상호           전화번호
# 0        바비레드 강남본점   02-3452-1515
# 1         마녀주방 강남점  070-4240-1116
# 2     프리모바치오바치 강남점    02-501-0885
# 3          고에몬 강남점    02-534-8036
# 4          토끼정 강남점  070-4230-2233
# 5               땀땀    02-554-8892
# 6   어글리스토브 신논현강남역점    02-558-8459
# 7    미즈컨테이너 강남 웨스트  070-8868-0150
# 8          아이해브어드림   02-3453-7697
# 9         갓덴스시 강남점   02-2051-1477
# 10       마키노차야 역삼점    02-565-1116
# 11            봉우화로    02-558-8452
# 12           AY라운지    02-552-8199
# 13        쉐이크쉑 강남점    02-553-5576
# 14     맥쓰세계치킨 강남역점    02-737-8292
# 15       타이거슈가 강남점      1668-3696
# 16   미즈컨테이너 강남 이스트  070-8885-5199
# 17       낙원타코 강남역점    02-595-1540
# 18        도치피자 강남점    02-556-8001
# 19          알부자알요리    02-508-4629
# 20      애슐리W 강남2호점    02-532-1592
# 21       에스프레소 퍼블릭    02-556-9317
# 22         스시오 강남점    02-538-9967
# 23      아트몬스터 강남역점   02-6448-6110
# 24         을밀대 강남점    02-552-1922
# 25              아쭈    02-558-5353
# ...
