# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ggcode

# %%
df = pd.read_csv('./data/02. crime_in_Seoul.csv', encoding='euc-kr')

# %%
df.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생 절도 검거  폭력 발생  폭력 검거
# 0   중부서      2      2      3      2    105     65  1,395   477  1,355  1,170
# 1   종로서      3      3      6      5    115     98  1,070   413  1,278  1,070
# 2  남대문서      1      0      6      4     65     46  1,153   382    869    794
# 3  서대문서      2      2      5      4    154    124  1,812   738  2,056  1,711
# 4   혜화서      3      2      5      4     96     63  1,114   424  1,015    861

# %%
df.dtypes
# Out:
# 관서명      object
# 살인 발생     int64
# 살인 검거     int64
# 강도 발생     int64
# 강도 검거     int64
# 강간 발생     int64
# 강간 검거     int64
# 절도 발생    object
# 절도 검거    object
# 폭력 발생    object
# 폭력 검거    object
# dtype: object

# %%
df = pd.read_csv('./data/02. crime_in_Seoul.csv', encoding='euc-kr', thousands=',')

# %%
df.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 0   중부서      2      2      3      2    105     65   1395    477   1355   1170
# 1   종로서      3      3      6      5    115     98   1070    413   1278   1070
# 2  남대문서      1      0      6      4     65     46   1153    382    869    794
# 3  서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 4   혜화서      3      2      5      4     96     63   1114    424   1015    861

# %%
df.dtypes
# Out:
# 관서명      object
# 살인 발생     int64
# 살인 검거     int64
# 강도 발생     int64
# 강도 검거     int64
# 강간 발생     int64
# 강간 검거     int64
# 절도 발생     int64
# 절도 검거     int64
# 폭력 발생     int64
# 폭력 검거     int64
# dtype: object

# %%
tmp = '서울'+df['관서명'].str[:-1] + '경찰서'

# %%
tmp
# Out:
# 0      서울중부경찰서
# 1      서울종로경찰서
# 2     서울남대문경찰서
# 3     서울서대문경찰서
# 4      서울혜화경찰서
# 5      서울용산경찰서
# 6      서울성북경찰서
# 7     서울동대문경찰서
# 8      서울마포경찰서
# 9     서울영등포경찰서
# 10     서울성동경찰서
# 11     서울동작경찰서
# 12     서울광진경찰서
# 13     서울서부경찰서
# 14     서울강북경찰서
# 15     서울금천경찰서
# 16     서울중랑경찰서
# 17     서울강남경찰서
# 18     서울관악경찰서
# 19     서울강서경찰서
# 20     서울강동경찰서
# 21     서울종암경찰서
# 22     서울구로경찰서
# 23     서울서초경찰서
# 24     서울양천경찰서
# 25     서울송파경찰서
# 26     서울노원경찰서
# 27     서울방배경찰서
# 28     서울은평경찰서
# 29     서울도봉경찰서
# 30     서울수서경찰서
# Name: 관서명, dtype: object

# %%
df['경찰서'] = tmp
df.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 0   중부서      2      2      3      2    105     65   1395    477   1355   1170
# 1   종로서      3      3      6      5    115     98   1070    413   1278   1070
# 2  남대문서      1      0      6      4     65     46   1153    382    869    794
# 3  서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 4   혜화서      3      2      5      4     96     63   1114    424   1015    861
#
#         경찰서
# 0   서울중부경찰서
# 1   서울종로경찰서
# 2  서울남대문경찰서
# 3  서울서대문경찰서
# 4   서울혜화경찰서

# %%
tmp = df['경찰서'].map(ggcode.get_addr)

# %%
df['주소'] = tmp
df.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 0   중부서      2      2      3      2    105     65   1395    477   1355   1170
# 1   종로서      3      3      6      5    115     98   1070    413   1278   1070
# 2  남대문서      1      0      6      4     65     46   1153    382    869    794
# 3  서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 4   혜화서      3      2      5      4     96     63   1114    424   1015    861
#
#         경찰서                          주소
# 0   서울중부경찰서        대한민국 서울특별시 중구 수표로 27
# 1   서울종로경찰서       대한민국 서울특별시 종로구 율곡로 46
# 2  서울남대문경찰서      대한민국 서울특별시 중구 한강대로 410
# 3  서울서대문경찰서     대한민국 서울특별시 서대문구 통일로 113
# 4   서울혜화경찰서  대한민국 서울특별시 종로구 창경궁로 112-16

# %%
df['위도'] = df['경찰서'].map(ggcode.get_lat)
df['경도'] = df['경찰서'].map(ggcode.get_lng)

# %%
df.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 0   중부서      2      2      3      2    105     65   1395    477   1355   1170
# 1   종로서      3      3      6      5    115     98   1070    413   1278   1070
# 2  남대문서      1      0      6      4     65     46   1153    382    869    794
# 3  서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 4   혜화서      3      2      5      4     96     63   1114    424   1015    861
#
#         경찰서                          주소         위도          경도
# 0   서울중부경찰서        대한민국 서울특별시 중구 수표로 27  37.563617  126.989652
# 1   서울종로경찰서       대한민국 서울특별시 종로구 율곡로 46  37.575548  126.984747
# 2  서울남대문경찰서      대한민국 서울특별시 중구 한강대로 410  37.554758  126.973498
# 3  서울서대문경찰서     대한민국 서울특별시 서대문구 통일로 113  37.564744  126.966770
# 4   서울혜화경찰서  대한민국 서울특별시 종로구 창경궁로 112-16  37.571968  126.998957

# %%
df['주소'].str.rfind('구')
# Out:
# 0     12
# 1     13
# 2     12
# 3     14
# 4     13
# 5     13
# 6     13
# 7     14
# 8     13
# 9     14
# 10    13
# 11    13
# 12    15
# 13    13
# 14    13
# 15    13
# 16    13
# 17    13
# 18    13
# 19    13
# 20    13
# 21    13
# 22    13
# 23    13
# 24    13
# 25    13
# 26    13
# 27    13
# 28    13
# 29    13
# 30    13
# Name: 주소, dtype: int64

# %%
res = []
for i in df['주소'].str.rfind('구'):
    res.append(df['주소'].str[:i+2])
tmp = res

# %%
res = []
for i in df['주소'].str.rfind('구'):
    res.append(df['주소'].str[:i+2])
res
# Out:
# [0     대한민국 서울특별시 중구
#  1     대한민국 서울특별시 종로구
#  2     대한민국 서울특별시 중구
#  3     대한민국 서울특별시 서대문
#  4     대한민국 서울특별시 종로구
#  5     대한민국 서울특별시 용산구
#  6     대한민국 서울특별시 성북구
#  7     대한민국 서울특별시 동대문
#  8     대한민국 서울특별시 마포구
#  9     대한민국 서울특별시 영등포
#  10    대한민국 서울특별시 성동구
#  11    대한민국 서울특별시 동작구
#  12    대한민국 서울특별시 광진구
#  13    대한민국 서울특별시 은평구
#  14    대한민국 서울특별시 강북구
#  15    대한민국 서울특별시 금천구
#  16    대한민국 서울특별시 중랑구
#  17    대한민국 서울특별시 강남구
#  18    대한민국 서울특별시 관악구
#  19    대한민국 서울특별시 강서구
#  20    대한민국 서울특별시 강동구
#  21    대한민국 서울특별시 성북구
#  22    대한민국 서울특별시 구로구
#  23    대한민국 서울특별시 서초구
#  24    대한민국 서울특별시 양천구
#  25    대한민국 서울특별시 송파구
#  26    대한민국 서울특별시 노원구
#  27    대한민국 서울특별시 서초구
#  28    대한민국 서울특별시 은평구
#  29    대한민국 서울특별시 도봉구
#  30    대한민국 서울특별시 강남구
#  Name: 주소, dtype: object,
#  0     대한민국 서울특별시 중구 수
#  1     대한민국 서울특별시 종로구
#  2     대한민국 서울특별시 중구 한
#  3     대한민국 서울특별시 서대문구
#  4     대한민국 서울특별시 종로구
#  5     대한민국 서울특별시 용산구
#  6     대한민국 서울특별시 성북구
#  7     대한민국 서울특별시 동대문구
#  8     대한민국 서울특별시 마포구
# ...

# %%
[i.split()[2] for i in df['주소']]
# Out:
# ['중구',
#  '종로구',
#  '중구',
#  '서대문구',
#  '종로구',
#  '용산구',
#  '성북구',
#  '동대문구',
#  '마포구',
#  '영등포구',
#  '성동구',
#  '동작구',
#  '광진구',
#  '은평구',
#  '강북구',
#  '금천구',
#  '중랑구',
#  '강남구',
#  '관악구',
#  '강서구',
#  '강동구',
#  '성북구',
#  '구로구',
#  '서초구',
#  '양천구',
#  '송파구',
#  '노원구',
#  '서초구',
#  '은평구',
#  '도봉구',
#  '강남구']

# %%
df['구별'] = [i.split()[2] for i in df['주소']]
df.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 0   중부서      2      2      3      2    105     65   1395    477   1355   1170
# 1   종로서      3      3      6      5    115     98   1070    413   1278   1070
# 2  남대문서      1      0      6      4     65     46   1153    382    869    794
# 3  서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 4   혜화서      3      2      5      4     96     63   1114    424   1015    861
#
#         경찰서                          주소         위도          경도    구별
# 0   서울중부경찰서        대한민국 서울특별시 중구 수표로 27  37.563617  126.989652    중구
# 1   서울종로경찰서       대한민국 서울특별시 종로구 율곡로 46  37.575548  126.984747   종로구
# 2  서울남대문경찰서      대한민국 서울특별시 중구 한강대로 410  37.554758  126.973498    중구
# 3  서울서대문경찰서     대한민국 서울특별시 서대문구 통일로 113  37.564744  126.966770  서대문구
# 4   서울혜화경찰서  대한민국 서울특별시 종로구 창경궁로 112-16  37.571968  126.998957   종로구

# %%
df[df['관서명']=='금천서']
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 15  금천서      3      4      6      6    151    122   1567    888   2054   1776
#
#         경찰서                         주소         위도          경도   구별
# 15  서울금천경찰서  대한민국 서울특별시 금천구 시흥대로73길 50  37.456872  126.897043  금천구

# %%
df[df['관서명']=='금천서']['구별'] = '연습'
# Out:
# C:\Users\hjk70\AppData\Local\Temp\ipykernel_18144\2134238773.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['관서명']=='금천서']['구별'] = '연습'

# %%
df[df['관서명']=='금천서'].loc[,'구별'] = '연습'
# Out:
#   Input In [23]
#     df[df['관서명']=='금천서'].loc[,'구별'] = '연습'
#                              ^
# SyntaxError: invalid syntax

# %%
df.loc[df['관서명']=='금천서', '구별']
# Out:
# 15    금천구
# Name: 구별, dtype: object

# %%
df.loc[df['관서명']=='금천서', '구별'] = '연습'

# %%
df[df['관서명']=='금천서']
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 15  금천서      3      4      6      6    151    122   1567    888   2054   1776
#
#         경찰서                         주소         위도          경도  구별
# 15  서울금천경찰서  대한민국 서울특별시 금천구 시흥대로73길 50  37.456872  126.897043  연습

# %%
df.loc[df['관서명']=='금천서', '구별'] = '금천구'

# %%
df[df['관서명']=='금천서']
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 15  금천서      3      4      6      6    151    122   1567    888   2054   1776
#
#         경찰서                         주소         위도          경도   구별
# 15  서울금천경찰서  대한민국 서울특별시 금천구 시흥대로73길 50  37.456872  126.897043  금천구

# %%
df.groupby('구별').sum()
# Out:
#       살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 구별
# 강남구      13     10     21     18    449    349   3850   1650   4284   3705
# 강동구       4      3      6      8    156    123   2366    789   2712   2248
# 강북구       7      8     14     13    153    126   1434    618   2649   2348
# 강서구       7      8     13     13    262    191   2096   1260   3207   2718
# 관악구       9      8     12     14    320    221   2706    827   3298   2642
# 광진구       4      4     14     26    240    220   3026   1277   2625   2180
# 구로구       8      6     15     11    281    164   2335    889   3007   2432
# 금천구       3      4      6      6    151    122   1567    888   2054   1776
# 노원구      10     10      7      7    197    121   2193    801   2723   2329
# 도봉구       3      3      9     10    102    106   1063    478   1487   1303
# 동대문구      5      5     13     13    173    146   1981    814   2548   2227
# ...

# %%
df1 = df.groupby('구별').sum()

# %%
df1['살인검거율'] = df1['살인 검거'] / df1['살인 발생'] * 100
df1['강도검거율'] = df1['강도 검거'] / df1['강도 발생'] * 100
df1['강간검거율'] = df1['강간 검거'] / df1['강간 발생'] * 100
df1['절도검거율'] = df1['절도 검거'] / df1['절도 발생'] * 100
df1['폭력검거율'] = df1['폭력 검거'] / df1['폭력 발생'] * 100

# %%
df1.head()
# Out:
#      살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 구별
# 강남구     13     10     21     18    449    349   3850   1650   4284   3705
# 강동구      4      3      6      8    156    123   2366    789   2712   2248
# 강북구      7      8     14     13    153    126   1434    618   2649   2348
# 강서구      7      8     13     13    262    191   2096   1260   3207   2718
# 관악구      9      8     12     14    320    221   2706    827   3298   2642
#
#             위도          경도       살인검거율       강도검거율      강간검거율      절도검거율  \
# 구별
# 강남구  75.002925  254.144170   76.923077   85.714286  77.728285  42.857143
# 강동구  37.528511  127.126822   75.000000  133.333333  78.846154  33.347422
# 강북구  37.637304  127.027340  114.285714   92.857143  82.352941  43.096234
# 강서구  37.551284  126.850038  114.285714  100.000000  72.900763  60.114504
# 관악구  37.474395  126.951349   88.888889  116.666667  69.062500  30.561715
#
#          폭력검거율
# 구별
# 강남구  86.484594
# 강동구  82.890855
# 강북구  88.637222
# ...

# %%
df2 = df1.iloc[:,-5:]
df2.head()
# Out:
#           살인검거율       강도검거율      강간검거율      절도검거율      폭력검거율
# 구별
# 강남구   76.923077   85.714286  77.728285  42.857143  86.484594
# 강동구   75.000000  133.333333  78.846154  33.347422  82.890855
# 강북구  114.285714   92.857143  82.352941  43.096234  88.637222
# 강서구  114.285714  100.000000  72.900763  60.114504  84.752105
# 관악구   88.888889  116.666667  69.062500  30.561715  80.109157

# %%
df1.describe()
# Out:
#            살인 발생      살인 검거      강도 발생      강도 검거       강간 발생       강간 검거  \
# count  25.000000  25.000000  25.000000  25.000000   25.000000   25.000000
# mean    6.520000   6.120000  11.040000  10.120000  217.960000  163.640000
# std     3.513308   2.976575   4.439219   5.433845   86.322786   57.535409
# min     2.000000   2.000000   5.000000   3.000000  102.000000  105.000000
# 25%     4.000000   4.000000   9.000000   6.000000  154.000000  123.000000
# 50%     5.000000   5.000000  11.000000   9.000000  194.000000  146.000000
# 75%     8.000000   8.000000  14.000000  13.000000  281.000000  183.000000
# max    14.000000  12.000000  22.000000  26.000000  449.000000  349.000000
#
#              절도 발생        절도 검거        폭력 발생        폭력 검거         위도  \
# count    25.000000    25.000000    25.000000    25.000000  25.000000
# mean   2212.280000   861.360000  2608.240000  2206.480000  46.565143
# std     629.943881   257.311238   630.870185   527.633484  16.373891
# ...

# %%
df1.columns
# Out:
# Index(['살인 발생', '살인 검거', '강도 발생', '강도 검거', '강간 발생', '강간 검거', '절도 발생', '절도 검거',
#        '폭력 발생', '폭력 검거', '위도', '경도', '살인검거율', '강도검거율', '강간검거율', '절도검거율',
#        '폭력검거율'],
#       dtype='object')

# %%
cols = ['살인검거율', '강도검거율', '강간검거율', '절도검거율', '폭력검거율']

# %%
df1[cols]
# Out:
#            살인검거율       강도검거율       강간검거율      절도검거율      폭력검거율
# 구별
# 강남구    76.923077   85.714286   77.728285  42.857143  86.484594
# 강동구    75.000000  133.333333   78.846154  33.347422  82.890855
# 강북구   114.285714   92.857143   82.352941  43.096234  88.637222
# 강서구   114.285714  100.000000   72.900763  60.114504  84.752105
# 관악구    88.888889  116.666667   69.062500  30.561715  80.109157
# 광진구   100.000000  185.714286   91.666667  42.200925  83.047619
# 구로구    75.000000   73.333333   58.362989  38.072805  80.877951
# 금천구   133.333333  100.000000   80.794702  56.668794  86.465433
# 노원구   100.000000  100.000000   61.421320  36.525308  85.530665
# 도봉구   100.000000  111.111111  103.921569  44.967074  87.626093
# 동대문구  100.000000  100.000000   84.393064  41.090358  87.401884
# 동작구   100.000000   55.555556   48.771930  35.442359  83.089005
# 마포구   100.000000   71.428571   84.013605  31.819961  84.445189
# 서대문구  100.000000   80.000000   80.519481  40.728477  83.219844
# ...

# %%
df1[cols] > 100
# Out:
#       살인검거율  강도검거율  강간검거율  절도검거율  폭력검거율
# 구별
# 강남구   False  False  False  False  False
# 강동구   False   True  False  False  False
# 강북구    True  False  False  False  False
# 강서구    True  False  False  False  False
# 관악구   False   True  False  False  False
# 광진구   False   True  False  False  False
# 구로구   False  False  False  False  False
# 금천구    True  False  False  False  False
# 노원구   False  False  False  False  False
# 도봉구   False   True   True  False  False
# 동대문구  False  False  False  False  False
# 동작구   False  False  False  False  False
# 마포구   False  False  False  False  False
# 서대문구  False  False  False  False  False
# 서초구   False  False  False  False  False
# 성동구   False  False  False  False  False
# 성북구   False  False  False  False  False
# 송파구   False  False  False  False  False
# 양천구    True  False  False  False  False
# 영등포구  False  False  False  False  False
# 용산구   False  False  False  False  False
# 은평구   False  False  False  False  False
# ...

# %%
df1[cols][df1[cols] > 100]
# Out:
#            살인검거율       강도검거율       강간검거율  절도검거율  폭력검거율
# 구별
# 강남구          NaN         NaN         NaN    NaN    NaN
# 강동구          NaN  133.333333         NaN    NaN    NaN
# 강북구   114.285714         NaN         NaN    NaN    NaN
# 강서구   114.285714         NaN         NaN    NaN    NaN
# 관악구          NaN  116.666667         NaN    NaN    NaN
# 광진구          NaN  185.714286         NaN    NaN    NaN
# 구로구          NaN         NaN         NaN    NaN    NaN
# 금천구   133.333333         NaN         NaN    NaN    NaN
# 노원구          NaN         NaN         NaN    NaN    NaN
# 도봉구          NaN  111.111111  103.921569    NaN    NaN
# 동대문구         NaN         NaN         NaN    NaN    NaN
# 동작구          NaN         NaN         NaN    NaN    NaN
# 마포구          NaN         NaN         NaN    NaN    NaN
# 서대문구         NaN         NaN         NaN    NaN    NaN
# 서초구          NaN         NaN         NaN    NaN    NaN
# 성동구          NaN         NaN         NaN    NaN    NaN
# ...

# %%
df1[cols][df1[cols] > 100].values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 df1[cols][df1[cols] > 100].values()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
[100 if i>100 else i for i in df1['살인검거율']]
# Out:
# [76.92307692307693,
#  75.0,
#  100,
#  100,
#  88.88888888888889,
#  100.0,
#  75.0,
#  100,
#  100.0,
#  100.0,
#  100.0,
#  100.0,
#  100.0,
#  100.0,
#  75.0,
#  100.0,
#  100.0,
#  90.9090909090909,
#  100,
#  85.71428571428571,
#  100.0,
#  100.0,
#  83.33333333333334,
#  66.66666666666666,
#  92.3076923076923]

# %%
for col in cols:
    df1[col] = [100 if i>100 else i for i in df1[col]]

# %%
df1.head()
# Out:
#      살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 구별
# 강남구     13     10     21     18    449    349   3850   1650   4284   3705
# 강동구      4      3      6      8    156    123   2366    789   2712   2248
# 강북구      7      8     14     13    153    126   1434    618   2649   2348
# 강서구      7      8     13     13    262    191   2096   1260   3207   2718
# 관악구      9      8     12     14    320    221   2706    827   3298   2642
#
#             위도          경도       살인검거율       강도검거율      강간검거율      절도검거율  \
# 구별
# 강남구  75.002925  254.144170   76.923077   85.714286  77.728285  42.857143
# 강동구  37.528511  127.126822   75.000000  100.000000  78.846154  33.347422
# 강북구  37.637304  127.027340  100.000000   92.857143  82.352941  43.096234
# 강서구  37.551284  126.850038  100.000000  100.000000  72.900763  60.114504
# 관악구  37.474395  126.951349   88.888889  100.000000  69.062500  30.561715
#
#          폭력검거율
# 구별
# 강남구  86.484594
# 강동구  82.890855
# 강북구  88.637222
# ...

# %%
df1.describe()
# Out:
#            살인 발생      살인 검거      강도 발생      강도 검거       강간 발생       강간 검거  \
# count  25.000000  25.000000  25.000000  25.000000   25.000000   25.000000
# mean    6.520000   6.120000  11.040000  10.120000  217.960000  163.640000
# std     3.513308   2.976575   4.439219   5.433845   86.322786   57.535409
# min     2.000000   2.000000   5.000000   3.000000  102.000000  105.000000
# 25%     4.000000   4.000000   9.000000   6.000000  154.000000  123.000000
# 50%     5.000000   5.000000  11.000000   9.000000  194.000000  146.000000
# 75%     8.000000   8.000000  14.000000  13.000000  281.000000  183.000000
# max    14.000000  12.000000  22.000000  26.000000  449.000000  349.000000
#
#              절도 발생        절도 검거        폭력 발생        폭력 검거         위도  \
# count    25.000000    25.000000    25.000000    25.000000  25.000000
# mean   2212.280000   861.360000  2608.240000  2206.480000  46.565143
# std     629.943881   257.311238   630.870185   527.633484  16.373891
# ...

# %%
del df1['위도']
del df1['경도']

# %%
df1.head()
# Out:
#      살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 구별
# 강남구     13     10     21     18    449    349   3850   1650   4284   3705
# 강동구      4      3      6      8    156    123   2366    789   2712   2248
# 강북구      7      8     14     13    153    126   1434    618   2649   2348
# 강서구      7      8     13     13    262    191   2096   1260   3207   2718
# 관악구      9      8     12     14    320    221   2706    827   3298   2642
#
#           살인검거율       강도검거율      강간검거율      절도검거율      폭력검거율
# 구별
# 강남구   76.923077   85.714286  77.728285  42.857143  86.484594
# 강동구   75.000000  100.000000  78.846154  33.347422  82.890855
# 강북구  100.000000   92.857143  82.352941  43.096234  88.637222
# 강서구  100.000000  100.000000  72.900763  60.114504  84.752105
# 관악구   88.888889  100.000000  69.062500  30.561715  80.109157

# %%
df1.columns
# Out:
# Index(['살인 발생', '살인 검거', '강도 발생', '강도 검거', '강간 발생', '강간 검거', '절도 발생', '절도 검거',
#        '폭력 발생', '폭력 검거', '살인검거율', '강도검거율', '강간검거율', '절도검거율', '폭력검거율'],
#       dtype='object')

# %%
df1[['살인 발생', '강도 발생', '강간 발생', '절도 발생', '폭력 발생', '살인검거율', '강도검거율', '강간검거율', '절도검거율', '폭력검거율']]
# Out:
#       살인 발생  강도 발생  강간 발생  절도 발생  폭력 발생       살인검거율       강도검거율       강간검거율  \
# 구별
# 강남구      13     21    449   3850   4284   76.923077   85.714286   77.728285
# 강동구       4      6    156   2366   2712   75.000000  100.000000   78.846154
# 강북구       7     14    153   1434   2649  100.000000   92.857143   82.352941
# 강서구       7     13    262   2096   3207  100.000000  100.000000   72.900763
# 관악구       9     12    320   2706   3298   88.888889  100.000000   69.062500
# 광진구       4     14    240   3026   2625  100.000000  100.000000   91.666667
# 구로구       8     15    281   2335   3007   75.000000   73.333333   58.362989
# 금천구       3      6    151   1567   2054  100.000000  100.000000   80.794702
# 노원구      10      7    197   2193   2723  100.000000  100.000000   61.421320
# 도봉구       3      9    102   1063   1487  100.000000  100.000000  100.000000
# 동대문구      5     13    173   1981   2548  100.000000  100.000000   84.393064
# ...

# %%
df1 = df1[['살인 발생', '강도 발생', '강간 발생', '절도 발생', '폭력 발생', '살인검거율', '강도검거율', '강간검거율', '절도검거율', '폭력검거율']]

# %%
df1.columns = ['살인', '강도', '강간', '절도', '폭력', '살인검거율', '강도검거율', '강간검거율', '절도검거율', '폭력검거율']

# %%
df1.head()
# Out:
#      살인  강도   강간    절도    폭력       살인검거율       강도검거율      강간검거율      절도검거율  \
# 구별
# 강남구  13  21  449  3850  4284   76.923077   85.714286  77.728285  42.857143
# 강동구   4   6  156  2366  2712   75.000000  100.000000  78.846154  33.347422
# 강북구   7  14  153  1434  2649  100.000000   92.857143  82.352941  43.096234
# 강서구   7  13  262  2096  3207  100.000000  100.000000  72.900763  60.114504
# 관악구   9  12  320  2706  3298   88.888889  100.000000  69.062500  30.561715
#
#          폭력검거율
# 구별
# 강남구  86.484594
# 강동구  82.890855
# 강북구  88.637222
# 강서구  84.752105
# 관악구  80.109157

# %%
df_cctv = pd.read_csv('./data/01. CCTV_result.csv')
df_cctv.head()
# Out:
#     구별    소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 0  강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 1  강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 2  강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 3  강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 4  관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#        고령자비율    CCTV비율           오차
# 0  11.072217  0.487292  1388.055355
# 1  12.051638  0.170552   465.422892
# 2  16.600342  0.226535   329.342026
# 3  12.015794  0.146413   551.503155
# 4  12.955291  0.284673   162.948104

# %%
df1.reset_index()
# Out:
#       구별  살인  강도   강간    절도    폭력       살인검거율       강도검거율       강간검거율  \
# 0    강남구  13  21  449  3850  4284   76.923077   85.714286   77.728285
# 1    강동구   4   6  156  2366  2712   75.000000  100.000000   78.846154
# 2    강북구   7  14  153  1434  2649  100.000000   92.857143   82.352941
# 3    강서구   7  13  262  2096  3207  100.000000  100.000000   72.900763
# 4    관악구   9  12  320  2706  3298   88.888889  100.000000   69.062500
# 5    광진구   4  14  240  3026  2625  100.000000  100.000000   91.666667
# 6    구로구   8  15  281  2335  3007   75.000000   73.333333   58.362989
# 7    금천구   3   6  151  1567  2054  100.000000  100.000000   80.794702
# 8    노원구  10   7  197  2193  2723  100.000000  100.000000   61.421320
# 9    도봉구   3   9  102  1063  1487  100.000000  100.000000  100.000000
# 10  동대문구   5  13  173  1981  2548  100.000000  100.000000   84.393064
# 11   동작구   5   9  285  1865  1910  100.000000   55.555556   48.771930
# ...

# %%
df1 = df1.reset_index()

# %%
pd.merge(left=df1, right=df_cctv[['구별','인구수','소계']], on='구별', how='left')
# Out:
#       구별  살인  강도   강간    절도    폭력       살인검거율       강도검거율       강간검거율  \
# 0    강남구  13  21  449  3850  4284   76.923077   85.714286   77.728285
# 1    강동구   4   6  156  2366  2712   75.000000  100.000000   78.846154
# 2    강북구   7  14  153  1434  2649  100.000000   92.857143   82.352941
# 3    강서구   7  13  262  2096  3207  100.000000  100.000000   72.900763
# 4    관악구   9  12  320  2706  3298   88.888889  100.000000   69.062500
# 5    광진구   4  14  240  3026  2625  100.000000  100.000000   91.666667
# 6    구로구   8  15  281  2335  3007   75.000000   73.333333   58.362989
# 7    금천구   3   6  151  1567  2054  100.000000  100.000000   80.794702
# 8    노원구  10   7  197  2193  2723  100.000000  100.000000   61.421320
# 9    도봉구   3   9  102  1063  1487  100.000000  100.000000  100.000000
# 10  동대문구   5  13  173  1981  2548  100.000000  100.000000   84.393064
# 11   동작구   5   9  285  1865  1910  100.000000   55.555556   48.771930
# ...

# %%
df1 = pd.merge(left=df1, right=df_cctv[['구별','인구수','소계']], on='구별', how='left')

# %%
df1.head()
# Out:
#     구별  살인  강도   강간    절도    폭력       살인검거율       강도검거율      강간검거율      절도검거율  \
# 0  강남구  13  21  449  3850  4284   76.923077   85.714286  77.728285  42.857143
# 1  강동구   4   6  156  2366  2712   75.000000  100.000000  78.846154  33.347422
# 2  강북구   7  14  153  1434  2649  100.000000   92.857143  82.352941  43.096234
# 3  강서구   7  13  262  2096  3207  100.000000  100.000000  72.900763  60.114504
# 4  관악구   9  12  320  2706  3298   88.888889  100.000000  69.062500  30.561715
#
#        폭력검거율       인구수    소계
# 0  86.484594  570500.0  2780
# 1  82.890855  453233.0   773
# 2  88.637222  330192.0   748
# 3  84.752105  603772.0   884
# 4  80.109157  525515.0  1496

# %%
df1.columns
# Out:
# Index(['구별', '살인', '강도', '강간', '절도', '폭력', '살인검거율', '강도검거율', '강간검거율', '절도검거율',
#        '폭력검거율', '인구수', '소계'],
#       dtype='object')

# %%
df1.columns = ['구별', '살인', '강도', '강간', '절도', '폭력', '살인검거율', '강도검거율', '강간검거율', '절도검거율','폭력검거율', '인구수', 'CCTV']

# %%
df1.head()
# Out:
#     구별  살인  강도   강간    절도    폭력       살인검거율       강도검거율      강간검거율      절도검거율  \
# 0  강남구  13  21  449  3850  4284   76.923077   85.714286  77.728285  42.857143
# 1  강동구   4   6  156  2366  2712   75.000000  100.000000  78.846154  33.347422
# 2  강북구   7  14  153  1434  2649  100.000000   92.857143  82.352941  43.096234
# 3  강서구   7  13  262  2096  3207  100.000000  100.000000  72.900763  60.114504
# 4  관악구   9  12  320  2706  3298   88.888889  100.000000  69.062500  30.561715
#
#        폭력검거율       인구수  CCTV
# 0  86.484594  570500.0  2780
# 1  82.890855  453233.0   773
# 2  88.637222  330192.0   748
# 3  84.752105  603772.0   884
# 4  80.109157  525515.0  1496

# %%
df1.iloc[:,1:6].sum(axis=1)
# Out:
# 0     8617
# 1     5244
# 2     4257
# 3     5585
# 4     6345
# 5     5909
# 6     5646
# 7     3781
# 8     5130
# 9     2664
# 10    4720
# 11    4074
# 12    5854
# 13    4029
# 14    5444
# 15    3358
# 16    4154
# 17    6778
# 18    4528
# 19    6867
# 20    3820
# 21    4745
# 22    4705
# 23    4954
# 24    5193
# dtype: int64

# %%
df1['범죄'] = df1.iloc[:,1:6].sum(axis=1)

# %%
df1.head()
# Out:
#     구별  살인  강도   강간    절도    폭력       살인검거율       강도검거율      강간검거율      절도검거율  \
# 0  강남구  13  21  449  3850  4284   76.923077   85.714286  77.728285  42.857143
# 1  강동구   4   6  156  2366  2712   75.000000  100.000000  78.846154  33.347422
# 2  강북구   7  14  153  1434  2649  100.000000   92.857143  82.352941  43.096234
# 3  강서구   7  13  262  2096  3207  100.000000  100.000000  72.900763  60.114504
# 4  관악구   9  12  320  2706  3298   88.888889  100.000000  69.062500  30.561715
#
#        폭력검거율       인구수  CCTV    범죄
# 0  86.484594  570500.0  2780  8617
# 1  82.890855  453233.0   773  5244
# 2  88.637222  330192.0   748  4257
# 3  84.752105  603772.0   884  5585
# 4  80.109157  525515.0  1496  6345

# %%
df1['검거'] = df1.iloc[:,6:11].sum(axis=1)

# %%
df1.head()
# Out:
#     구별  살인  강도   강간    절도    폭력       살인검거율       강도검거율      강간검거율      절도검거율  \
# 0  강남구  13  21  449  3850  4284   76.923077   85.714286  77.728285  42.857143
# 1  강동구   4   6  156  2366  2712   75.000000  100.000000  78.846154  33.347422
# 2  강북구   7  14  153  1434  2649  100.000000   92.857143  82.352941  43.096234
# 3  강서구   7  13  262  2096  3207  100.000000  100.000000  72.900763  60.114504
# 4  관악구   9  12  320  2706  3298   88.888889  100.000000  69.062500  30.561715
#
#        폭력검거율       인구수  CCTV    범죄          검거
# 0  86.484594  570500.0  2780  8617  369.707384
# 1  82.890855  453233.0   773  5244  370.084431
# 2  88.637222  330192.0   748  4257  406.943540
# 3  84.752105  603772.0   884  5585  417.767372
# 4  80.109157  525515.0  1496  6345  368.622261

# %%
def test(s):
    res=[]
    for i in s:
        min_=s.min()
        max_=s.max()
        result=(i-min_)/(max_-min_)
        res.append(result)
    return res

# %%
cols = ['살인', '강도', '강간', '절도', '폭력']
df1[cols].apply(test)
# Out:
#           살인        강도        강간        절도        폭력
# 0   0.916667  0.941176  1.000000  1.000000  1.000000
# 1   0.166667  0.058824  0.155620  0.467528  0.437969
# 2   0.416667  0.529412  0.146974  0.133118  0.415445
# 3   0.416667  0.470588  0.461095  0.370649  0.614945
# 4   0.583333  0.411765  0.628242  0.589523  0.647479
# 5   0.166667  0.529412  0.397695  0.704342  0.406864
# 6   0.500000  0.588235  0.515850  0.456405  0.543439
# 7   0.083333  0.058824  0.141210  0.180840  0.202717
# 8   0.666667  0.117647  0.273775  0.405454  0.441902
# 9   0.083333  0.235294  0.000000  0.000000  0.000000
# 10  0.250000  0.470588  0.204611  0.329386  0.379335
# 11  0.250000  0.235294  0.527378  0.287765  0.151233
# 12  0.500000  0.529412  0.553314  0.535343  0.534859
# 13  0.000000  0.000000  0.149856  0.268748  0.203432
# 14  0.500000  0.235294  0.838617  0.564047  0.326064
# 15  0.166667  0.235294  0.069164  0.195192  0.044691
# 16  0.250000  0.000000  0.138329  0.259060  0.258134
# ...

# %%
df1.head()
# Out:
#     구별  살인  강도   강간    절도    폭력       살인검거율       강도검거율      강간검거율      절도검거율  \
# 0  강남구  13  21  449  3850  4284   76.923077   85.714286  77.728285  42.857143
# 1  강동구   4   6  156  2366  2712   75.000000  100.000000  78.846154  33.347422
# 2  강북구   7  14  153  1434  2649  100.000000   92.857143  82.352941  43.096234
# 3  강서구   7  13  262  2096  3207  100.000000  100.000000  72.900763  60.114504
# 4  관악구   9  12  320  2706  3298   88.888889  100.000000  69.062500  30.561715
#
#        폭력검거율       인구수  CCTV    범죄          검거
# 0  86.484594  570500.0  2780  8617  369.707384
# 1  82.890855  453233.0   773  5244  370.084431
# 2  88.637222  330192.0   748  4257  406.943540
# 3  84.752105  603772.0   884  5585  417.767372
# 4  80.109157  525515.0  1496  6345  368.622261

# %%
df1[cols]=df1[cols].apply(test)

# %%
df1.head()
# Out:
#     구별        살인        강도        강간        절도        폭력       살인검거율  \
# 0  강남구  0.916667  0.941176  1.000000  1.000000  1.000000   76.923077
# 1  강동구  0.166667  0.058824  0.155620  0.467528  0.437969   75.000000
# 2  강북구  0.416667  0.529412  0.146974  0.133118  0.415445  100.000000
# 3  강서구  0.416667  0.470588  0.461095  0.370649  0.614945  100.000000
# 4  관악구  0.583333  0.411765  0.628242  0.589523  0.647479   88.888889
#
#         강도검거율      강간검거율      절도검거율      폭력검거율       인구수  CCTV    범죄  \
# 0   85.714286  77.728285  42.857143  86.484594  570500.0  2780  8617
# 1  100.000000  78.846154  33.347422  82.890855  453233.0   773  5244
# 2   92.857143  82.352941  43.096234  88.637222  330192.0   748  4257
# 3  100.000000  72.900763  60.114504  84.752105  603772.0   884  5585
# 4  100.000000  69.062500  30.561715  80.109157  525515.0  1496  6345
#
#            검거
# 0  369.707384
# 1  370.084431
# 2  406.943540
# 3  417.767372
# 4  368.622261

# %%
sns.pairplot(df1)
# Out:
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 49332 (\N{HANGUL SYLLABLE SAL}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
import matplotlib
matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

# %%
sns.pairplot(df1, vars=cols, kind='reg')

# %%
sns.pairplot(df1, x_vars=['인구수','CCTV'], y_vars=['폭력검거율', '살인검거율'], kind='reg')

# %%
cols = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']
df1[cols]
# Out:
#          강간검거율       강도검거율       살인검거율      절도검거율      폭력검거율
# 0    77.728285   85.714286   76.923077  42.857143  86.484594
# 1    78.846154  100.000000   75.000000  33.347422  82.890855
# 2    82.352941   92.857143  100.000000  43.096234  88.637222
# 3    72.900763  100.000000  100.000000  60.114504  84.752105
# 4    69.062500  100.000000   88.888889  30.561715  80.109157
# 5    91.666667  100.000000  100.000000  42.200925  83.047619
# 6    58.362989   73.333333   75.000000  38.072805  80.877951
# 7    80.794702  100.000000  100.000000  56.668794  86.465433
# 8    61.421320  100.000000  100.000000  36.525308  85.530665
# 9   100.000000  100.000000  100.000000  44.967074  87.626093
# 10   84.393064  100.000000  100.000000  41.090358  87.401884
# 11   48.771930   55.555556  100.000000  35.442359  83.089005
# 12   84.013605   71.428571  100.000000  31.819961  84.445189
# 13   80.519481   80.000000  100.000000  40.728477  83.219844
# ...

# %%
sns.heatmap(df1[cols])
# Out:
# <AxesSubplot:>

# %%
df1.head()
# Out:
#     구별        살인        강도        강간        절도        폭력       살인검거율  \
# 0  강남구  0.916667  0.941176  1.000000  1.000000  1.000000   76.923077
# 1  강동구  0.166667  0.058824  0.155620  0.467528  0.437969   75.000000
# 2  강북구  0.416667  0.529412  0.146974  0.133118  0.415445  100.000000
# 3  강서구  0.416667  0.470588  0.461095  0.370649  0.614945  100.000000
# 4  관악구  0.583333  0.411765  0.628242  0.589523  0.647479   88.888889
#
#         강도검거율      강간검거율      절도검거율      폭력검거율       인구수  CCTV    범죄  \
# 0   85.714286  77.728285  42.857143  86.484594  570500.0  2780  8617
# 1  100.000000  78.846154  33.347422  82.890855  453233.0   773  5244
# 2   92.857143  82.352941  43.096234  88.637222  330192.0   748  4257
# 3  100.000000  72.900763  60.114504  84.752105  603772.0   884  5585
# 4  100.000000  69.062500  30.561715  80.109157  525515.0  1496  6345
#
#            검거
# 0  369.707384
# 1  370.084431
# 2  406.943540
# 3  417.767372
# 4  368.622261

# %%
df1.loc[:,'살인':'폭력'].sum(axis=1)
# Out:
# 0     4.857843
# 1     1.286607
# 2     1.641616
# 3     2.333944
# 4     2.860342
# 5     2.204979
# 6     2.603930
# 7     0.666924
# 8     1.905445
# 9     0.318627
# 10    1.633921
# 11    1.451670
# 12    2.652927
# 13    0.622036
# 14    2.464022
# 15    0.711008
# 16    0.905522
# 17    2.987821
# 18    0.856156
# 19    3.983733
# 20    1.423080
# 21    1.225287
# 22    1.690786
# 23    1.310920
# 24    2.385443
# dtype: float64

# %%
df1['범죄'] = df1.loc[:,'살인':'폭력'].sum(axis=1)

# %%
df1.head()
# Out:
#     구별        살인        강도        강간        절도        폭력       살인검거율  \
# 0  강남구  0.916667  0.941176  1.000000  1.000000  1.000000   76.923077
# 1  강동구  0.166667  0.058824  0.155620  0.467528  0.437969   75.000000
# 2  강북구  0.416667  0.529412  0.146974  0.133118  0.415445  100.000000
# 3  강서구  0.416667  0.470588  0.461095  0.370649  0.614945  100.000000
# 4  관악구  0.583333  0.411765  0.628242  0.589523  0.647479   88.888889
#
#         강도검거율      강간검거율      절도검거율      폭력검거율       인구수  CCTV        범죄  \
# 0   85.714286  77.728285  42.857143  86.484594  570500.0  2780  4.857843
# 1  100.000000  78.846154  33.347422  82.890855  453233.0   773  1.286607
# 2   92.857143  82.352941  43.096234  88.637222  330192.0   748  1.641616
# 3  100.000000  72.900763  60.114504  84.752105  603772.0   884  2.333944
# 4  100.000000  69.062500  30.561715  80.109157  525515.0  1496  2.860342
#
#            검거
# 0  369.707384
# 1  370.084431
# 2  406.943540
# 3  417.767372
# 4  368.622261

# %%
df1.sort_values('검거', ascending=False)
# Out:
#       구별        살인        강도        강간        절도        폭력       살인검거율  \
# 9    도봉구  0.083333  0.235294  0.000000  0.000000  0.000000  100.000000
# 7    금천구  0.083333  0.058824  0.141210  0.180840  0.202717  100.000000
# 3    강서구  0.416667  0.470588  0.461095  0.370649  0.614945  100.000000
# 5    광진구  0.166667  0.529412  0.397695  0.704342  0.406864  100.000000
# 10  동대문구  0.250000  0.470588  0.204611  0.329386  0.379335  100.000000
# 20   용산구  0.250000  0.529412  0.265130  0.177252  0.201287  100.000000
# 15   성동구  0.166667  0.235294  0.069164  0.195192  0.044691  100.000000
# 2    강북구  0.416667  0.529412  0.146974  0.133118  0.415445  100.000000
# 16   성북구  0.250000  0.000000  0.138329  0.259060  0.258134  100.000000
# 13  서대문구  0.000000  0.000000  0.149856  0.268748  0.203432  100.000000
# 8    노원구  0.666667  0.117647  0.273775  0.405454  0.441902  100.000000
# 24   중랑구  0.916667  0.352941  0.244957  0.384643  0.486235   92.307692
# ...

# %%
df1['검거']/df1['검거'].sum() * 100
# Out:
# 0     3.907994
# 1     3.911980
# 2     4.301599
# 3     4.416013
# 4     3.896524
# 5     4.407005
# 6     3.442255
# 7     4.481144
# 8     4.053549
# 9     4.572729
# 10    4.364407
# 11    3.412782
# 12    3.929135
# 13    4.064019
# 14    3.529310
# 15    4.302426
# 16    4.102984
# 17    3.891532
# 18    3.741582
# 19    3.747752
# 20    4.333886
# 21    3.971067
# 22    3.847578
# 23    3.389428
# 24    3.981322
# Name: 검거, dtype: float64

# %%
df1['검거1'] = df1['검거']/df1['검거'].sum() * 100

# %%
df1.head()
# Out:
#     구별        살인        강도        강간        절도        폭력       살인검거율  \
# 0  강남구  0.916667  0.941176  1.000000  1.000000  1.000000   76.923077
# 1  강동구  0.166667  0.058824  0.155620  0.467528  0.437969   75.000000
# 2  강북구  0.416667  0.529412  0.146974  0.133118  0.415445  100.000000
# 3  강서구  0.416667  0.470588  0.461095  0.370649  0.614945  100.000000
# 4  관악구  0.583333  0.411765  0.628242  0.589523  0.647479   88.888889
#
#         강도검거율      강간검거율      절도검거율      폭력검거율       인구수  CCTV        범죄  \
# 0   85.714286  77.728285  42.857143  86.484594  570500.0  2780  4.857843
# 1  100.000000  78.846154  33.347422  82.890855  453233.0   773  1.286607
# 2   92.857143  82.352941  43.096234  88.637222  330192.0   748  1.641616
# 3  100.000000  72.900763  60.114504  84.752105  603772.0   884  2.333944
# 4  100.000000  69.062500  30.561715  80.109157  525515.0  1496  2.860342
#
#            검거       검거1
# 0  369.707384  3.907994
# 1  370.084431  3.911980
# 2  406.943540  4.301599
# ...

# %%
df1.sort_values('검거1', ascending=False)
# Out:
#       구별        살인        강도        강간        절도        폭력       살인검거율  \
# 9    도봉구  0.083333  0.235294  0.000000  0.000000  0.000000  100.000000
# 7    금천구  0.083333  0.058824  0.141210  0.180840  0.202717  100.000000
# 3    강서구  0.416667  0.470588  0.461095  0.370649  0.614945  100.000000
# 5    광진구  0.166667  0.529412  0.397695  0.704342  0.406864  100.000000
# 10  동대문구  0.250000  0.470588  0.204611  0.329386  0.379335  100.000000
# 20   용산구  0.250000  0.529412  0.265130  0.177252  0.201287  100.000000
# 15   성동구  0.166667  0.235294  0.069164  0.195192  0.044691  100.000000
# 2    강북구  0.416667  0.529412  0.146974  0.133118  0.415445  100.000000
# 16   성북구  0.250000  0.000000  0.138329  0.259060  0.258134  100.000000
# 13  서대문구  0.000000  0.000000  0.149856  0.268748  0.203432  100.000000
# 8    노원구  0.666667  0.117647  0.273775  0.405454  0.441902  100.000000
# 24   중랑구  0.916667  0.352941  0.244957  0.384643  0.486235   92.307692
# ...

# %%
df1_sort = df1.sort_values('검거1', ascending=False)

# %%
df1_sort.head()
# Out:
#       구별        살인        강도        강간        절도        폭력  살인검거율  강도검거율  \
# 9    도봉구  0.083333  0.235294  0.000000  0.000000  0.000000  100.0  100.0
# 7    금천구  0.083333  0.058824  0.141210  0.180840  0.202717  100.0  100.0
# 3    강서구  0.416667  0.470588  0.461095  0.370649  0.614945  100.0  100.0
# 5    광진구  0.166667  0.529412  0.397695  0.704342  0.406864  100.0  100.0
# 10  동대문구  0.250000  0.470588  0.204611  0.329386  0.379335  100.0  100.0
#
#          강간검거율      절도검거율      폭력검거율       인구수  CCTV        범죄          검거  \
# 9   100.000000  44.967074  87.626093  348646.0   485  0.318627  432.593167
# 7    80.794702  56.668794  86.465433  255082.0  1015  0.666924  423.928929
# 3    72.900763  60.114504  84.752105  603772.0   884  2.333944  417.767372
# 5    91.666667  42.200925  83.047619  372164.0   707  2.204979  416.915211
# 10   84.393064  41.090358  87.401884  369496.0  1294  1.633921  412.885306
#
#          검거1
# 9   4.572729
# 7   4.481144
# 3   4.416013
# 5   4.407005
# ...

# %%
cols
# Out:
# ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']

# %%
sns.heatmap(df1_sort[cols], annot=True)
# Out:
# <AxesSubplot:>

# %%
df1_sort.set_index('구별')
# Out:
#             살인        강도        강간        절도        폭력       살인검거율  \
# 구별
# 도봉구   0.083333  0.235294  0.000000  0.000000  0.000000  100.000000
# 금천구   0.083333  0.058824  0.141210  0.180840  0.202717  100.000000
# 강서구   0.416667  0.470588  0.461095  0.370649  0.614945  100.000000
# 광진구   0.166667  0.529412  0.397695  0.704342  0.406864  100.000000
# 동대문구  0.250000  0.470588  0.204611  0.329386  0.379335  100.000000
# 용산구   0.250000  0.529412  0.265130  0.177252  0.201287  100.000000
# 성동구   0.166667  0.235294  0.069164  0.195192  0.044691  100.000000
# 강북구   0.416667  0.529412  0.146974  0.133118  0.415445  100.000000
# 성북구   0.250000  0.000000  0.138329  0.259060  0.258134  100.000000
# 서대문구  0.000000  0.000000  0.149856  0.268748  0.203432  100.000000
# 노원구   0.666667  0.117647  0.273775  0.405454  0.441902  100.000000
# 중랑구   0.916667  0.352941  0.244957  0.384643  0.486235   92.307692
# 은평구   0.083333  0.235294  0.184438  0.305346  0.416875  100.000000
# ...

# %%
df1_sort = df1_sort.set_index('구별')

# %%
sns.heatmap(df1_sort[cols], annot=True)
# Out:
# <AxesSubplot:ylabel='구별'>

# %% [markdown]
# # 여기서 부터 과제

# %%
df1.head()
# Out:
#     구별        살인        강도        강간        절도        폭력       살인검거율  \
# 0  강남구  0.916667  0.941176  1.000000  1.000000  1.000000   76.923077
# 1  강동구  0.166667  0.058824  0.155620  0.467528  0.437969   75.000000
# 2  강북구  0.416667  0.529412  0.146974  0.133118  0.415445  100.000000
# 3  강서구  0.416667  0.470588  0.461095  0.370649  0.614945  100.000000
# 4  관악구  0.583333  0.411765  0.628242  0.589523  0.647479   88.888889
#
#         강도검거율      강간검거율      절도검거율      폭력검거율       인구수  CCTV        범죄  \
# 0   85.714286  77.728285  42.857143  86.484594  570500.0  2780  4.857843
# 1  100.000000  78.846154  33.347422  82.890855  453233.0   773  1.286607
# 2   92.857143  82.352941  43.096234  88.637222  330192.0   748  1.641616
# 3  100.000000  72.900763  60.114504  84.752105  603772.0   884  2.333944
# 4  100.000000  69.062500  30.561715  80.109157  525515.0  1496  2.860342
#
#            검거       검거1
# 0  369.707384  3.907994
# 1  370.084431  3.911980
# 2  406.943540  4.301599
# ...

# %%
# !pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 95.0/95.0 kB ? eta 0:00:00
# ...

# %%
import json
import folium

# %%
geo_path = './data/02. skorea_municipalities_geo_simple.json'
f = open(geo_path, 'r',encoding="utf-8")
geo_str = json.load(f)
# 파일을 읽을때는 load를 쓴다.
# 문자열을 읽을때는 loads를 쓴다.

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')
map.choropleth(geo_data=geo_str, 
               data=df1, 
               columns=['구별','살인'], 
               fill_color='PuRd',
               key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')
map.choropleth(geo_data=geo_str, 
               data=df1, 
               columns=['구별','강간'], 
               fill_color='PuRd',
               key_on='feature.id')
map
# Out:
# C:\Users\hjk70\AppData\Roaming\Python\Python39\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles='Stamen Toner')
map.choropleth(geo_data=geo_str, 
               data=df1, 
               columns=['구별','범죄'], 
               fill_color='PuRd',
               key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df1.head()
# Out:
#     구별        살인        강도        강간        절도        폭력       살인검거율  \
# 0  강남구  0.916667  0.941176  1.000000  1.000000  1.000000   76.923077
# 1  강동구  0.166667  0.058824  0.155620  0.467528  0.437969   75.000000
# 2  강북구  0.416667  0.529412  0.146974  0.133118  0.415445  100.000000
# 3  강서구  0.416667  0.470588  0.461095  0.370649  0.614945  100.000000
# 4  관악구  0.583333  0.411765  0.628242  0.589523  0.647479   88.888889
#
#         강도검거율      강간검거율      절도검거율      폭력검거율       인구수  CCTV        범죄  \
# 0   85.714286  77.728285  42.857143  86.484594  570500.0  2780  4.857843
# 1  100.000000  78.846154  33.347422  82.890855  453233.0   773  1.286607
# 2   92.857143  82.352941  43.096234  88.637222  330192.0   748  1.641616
# 3  100.000000  72.900763  60.114504  84.752105  603772.0   884  2.333944
# 4  100.000000  69.062500  30.561715  80.109157  525515.0  1496  2.860342
#
#            검거       검거1
# 0  369.707384  3.907994
# 1  370.084431  3.911980
# 2  406.943540  4.301599
# ...

# %%
df.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 0   중부서      2      2      3      2    105     65   1395    477   1355   1170
# 1   종로서      3      3      6      5    115     98   1070    413   1278   1070
# 2  남대문서      1      0      6      4     65     46   1153    382    869    794
# 3  서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 4   혜화서      3      2      5      4     96     63   1114    424   1015    861
#
#         경찰서                          주소         위도          경도    구별
# 0   서울중부경찰서        대한민국 서울특별시 중구 수표로 27  37.563617  126.989652    중구
# 1   서울종로경찰서       대한민국 서울특별시 종로구 율곡로 46  37.575548  126.984747   종로구
# 2  서울남대문경찰서      대한민국 서울특별시 중구 한강대로 410  37.554758  126.973498    중구
# 3  서울서대문경찰서     대한민국 서울특별시 서대문구 통일로 113  37.564744  126.966770  서대문구
# 4   서울혜화경찰서  대한민국 서울특별시 종로구 창경궁로 112-16  37.571968  126.998957   종로구

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)

for n in df.index:
    folium.Marker([df['위도'][n], df['경도'][n]]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df1['위도'] = df['위도']
df1['경도'] = df['경도']
df1.head()
# Out:
#     구별        살인        강도        강간        절도        폭력       살인검거율  \
# 0  강남구  0.916667  0.941176  1.000000  1.000000  1.000000   76.923077
# 1  강동구  0.166667  0.058824  0.155620  0.467528  0.437969   75.000000
# 2  강북구  0.416667  0.529412  0.146974  0.133118  0.415445  100.000000
# 3  강서구  0.416667  0.470588  0.461095  0.370649  0.614945  100.000000
# 4  관악구  0.583333  0.411765  0.628242  0.589523  0.647479   88.888889
#
#         강도검거율      강간검거율      절도검거율      폭력검거율       인구수  CCTV        범죄  \
# 0   85.714286  77.728285  42.857143  86.484594  570500.0  2780  4.857843
# 1  100.000000  78.846154  33.347422  82.890855  453233.0   773  1.286607
# 2   92.857143  82.352941  43.096234  88.637222  330192.0   748  1.641616
# 3  100.000000  72.900763  60.114504  84.752105  603772.0   884  2.333944
# 4  100.000000  69.062500  30.561715  80.109157  525515.0  1496  2.860342
#
#            검거       검거1         위도          경도
# 0  369.707384  3.907994  37.563617  126.989652
# ...

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)

for n in df1.index:
    folium.CircleMarker([df1['위도'][n], df1['경도'][n]],
                        radius=df1['검거1'][n]*10,
                        color='#3186cc', 
                        fill_color='#3186cc').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)

map.choropleth(geo_data=geo_str, 
               data=df1, 
               columns=['구별','범죄'], 
               fill_color='PuRd',
               key_on='feature.id')

for n in df1.index:
    folium.CircleMarker([df1['위도'][n], df1['경도'][n]],
                        radius=df1['검거1'][n]*10,
                        color='#3186cc', 
                        fill_color='#3186cc').add_to(map)

map
# Out:
# C:\Users\hjk70\AppData\Roaming\Python\Python39\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...

# %%
df1.sort_values('CCTV', ascending=False)[['구별', 'CCTV']]
# Out:
#       구별  CCTV
# 0    강남구  2780
# 18   양천구  2034
# 14   서초구  1930
# 21   은평구  1873
# 20   용산구  1624
# 6    구로구  1561
# 4    관악구  1496
# 16   성북구  1464
# 10  동대문구  1294
# 8    노원구  1265
# 11   동작구  1091
# 15   성동구  1062
# 7    금천구  1015
# 22   종로구  1002
# 13  서대문구   962
# 19  영등포구   904
# 3    강서구   884
# 1    강동구   773
# 2    강북구   748
# 5    광진구   707
# 23    중구   671
# 24   중랑구   660
# 17   송파구   618
# 12   마포구   574
# 9    도봉구   485

# %%
df1.sort_values('범죄')[['구별', '범죄']]
# Out:
#       구별        범죄
# 9    도봉구  0.318627
# 13  서대문구  0.622036
# 7    금천구  0.666924
# 15   성동구  0.711008
# 18   양천구  0.856156
# 16   성북구  0.905522
# 21   은평구  1.225287
# 1    강동구  1.286607
# 23    중구  1.310920
# 20   용산구  1.423080
# 11   동작구  1.451670
# 10  동대문구  1.633921
# 2    강북구  1.641616
# 22   종로구  1.690786
# 8    노원구  1.905445
# 5    광진구  2.204979
# 3    강서구  2.333944
# 24   중랑구  2.385443
# 14   서초구  2.464022
# 6    구로구  2.603930
# 12   마포구  2.652927
# 4    관악구  2.860342
# 17   송파구  2.987821
# 19  영등포구  3.983733
# 0    강남구  4.857843
