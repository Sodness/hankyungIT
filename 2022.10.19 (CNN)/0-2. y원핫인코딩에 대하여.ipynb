# %% [markdown]
# ### 원핫인코딩이란?
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.preprocessing import LabelEncoder
yList=['가방','가방','신발','핸드폰','티셔츠','핸드폰']
e=LabelEncoder()
e.fit(yList)              # 이 작업이 끝나면 글자의 중복을 제거한 '가방','신발','티셔츠','핸드폰'으로 순서가정의된 목록이 생성됨(가나다라순)
ydata=e.transform(yList)
ydata
# Out:
# array([0, 0, 1, 3, 2, 3])

# %%
e.fit(yList).classes_
# Out:
# array(['가방', '신발', '티셔츠', '핸드폰'], dtype='<U3')
