# %%
import cv2
import numpy as np


# 카메라 열기
cap = cv2.VideoCapture(0) #장치ID가 아닌 동영상 파일명만 바꾸면 됨
fourcc = cv2.VideoWriter_fourcc(*'DIVX') #코덱 설정
out = cv2.VideoWriter('output(1).avi', fourcc, 25.0, (640,480)) #영상을 저장할 객체 생성

# cap.set(cv2.CAP_PROP_FRAME_WIDTH,640)
# cap.set(cv2.CAP_PROP_FRAME_HEIGHT,480)

# 카메라 프레임 처리
while True:
    ret, frame = cap.read() #카메라로부터 정상적으로 프레임을 받아 오면 ret-> True, frame-> 해당 프레임저장

    if not ret:
        break
    
    cv2.rectangle(frame, (170, 50), (450, 350), (0,255,0), 3)
    mosaic_loc = frame[50:350, 170:450]
    mosaic_loc = cv2.blur(mosaic_loc,(50,50))
    frame[50:350, 170:450] = mosaic_loc

    out.write(frame)
    cv2.imshow('frame', frame)
    if cv2.waitKey(20) == 27:  # 일정시간 (예,10ms) 후 다음 프레임 읽음, 만약 ESC(27)키를 누르면 break
        break
cap.release() # 사용한 자원 해제
out.release()
cv2.destroyAllWindows()

# %%
import cv2


# 카메라 열기
cap = cv2.VideoCapture('./video1.mp4') #장치ID가 아닌 동영상 파일명만 바꾸면 됨


# 카메라 프레임 처리
while True:
    ret, frame = cap.read() #카메라로부터 정상적으로 프레임을 받아 오면 ret-> True, frame-> 해당 프레임저장

    if cap.get(cv2.CAP_PROP_POS_FRAMES) == cap.get(cv2.CAP_PROP_FRAME_COUNT):
        cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
#         tmp = frame[0:720, 0:600]
#         frame[0:720, 200:800] = tmp
    
    tmp = frame[0:720, 200:620]
    tmp1 = frame[0:720, 180:620]
    #cv2.imshow('1', frame)
    #cv2.imshow('test', tmp)
    frame[0:720, 860:1280] = tmp
    #cv2.imshow('2', frame)
    frame[0:720, 440:860] = tmp
    #cv2.imshow('3', frame)
    frame[0:720, 0:440] = tmp1
    cv2.imshow('frame', frame)
    if cv2.waitKey(20) == 27:  # 일정시간 (예,10ms) 후 다음 프레임 읽음, 만약 ESC(27)키를 누르면 break
        break
cap.release() # 사용한 자원 해제
cv2.destroyAllWindows()

# %%
import cv2


# 카메라 열기
cap = cv2.VideoCapture(0) #장치ID가 아닌 동영상 파일명만 바꾸면 됨



# 카메라 프레임 처리
while True:
    ret, frame = cap.read() #카메라로부터 정상적으로 프레임을 받아 오면 ret-> True, frame-> 해당 프레임저장

    if not ret:
        break
        
    # frame[100:400, 300:600] = frame[100:400, 300:600] * [0.1,0.1,1]
    cv2.rectangle(frame, (300,100),(600,400), (0,255,0), 2, 8)
    
    frame[100:400, 300:600] = cv2.blur(frame[100:400, 300:600], (30,30), anchor=(-1,-1), borderType=cv2.BORDER_DEFAULT)
    
    tmp=cv2.resize(frame[100:400, 300:600], (20, 20))
    w=abs(300)
    h=abs(300)
    frame[100:400, 300:600]=cv2.resize(tmp,(w,h))
    
    cv2.imshow('frame', frame)
    if cv2.waitKey(20) == 27:  # 일정시간 (예,10ms) 후 다음 프레임 읽음, 만약 ESC(27)키를 누르면 break
        break
cap.release() # 사용한 자원 해제
cv2.destroyAllWindows()

# %%
tmp=cv2.resize(image[300:600, 100:400], (10, 10))
w=abs(300)
h=abs(300)
image[300:600, 100:400]=cv2.resize(tmp,(w,h))
