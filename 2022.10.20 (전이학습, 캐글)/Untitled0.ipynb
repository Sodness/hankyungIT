# %%
# !git clone https://github.com/gilbutITbook/080324
# Out:
# Cloning into '080324'...
# remote: Enumerating objects: 776, done.
# remote: Total 776 (delta 0), reused 0 (delta 0), pack-reused 776
# Receiving objects: 100% (776/776), 46.63 MiB | 12.37 MiB/s, done.
# Resolving deltas: 100% (300/300), done.

# %%
from PIL import Image
Image.open('/content/dog.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x600 at 0x7F2FBBC23C10>

# %%
# %cd '/content/drive/MyDrive'
# Out:
# /content/drive/MyDrive

# %%
! git clone https://github.com/gilbutITbook/080324
# Out:
# Cloning into '080324'...
# remote: Enumerating objects: 776, done.
# remote: Total 776 (delta 0), reused 0 (delta 0), pack-reused 776
# Receiving objects: 100% (776/776), 46.63 MiB | 10.95 MiB/s, done.
# Resolving deltas: 100% (300/300), done.
# Checking out files: 100% (368/368), done.
