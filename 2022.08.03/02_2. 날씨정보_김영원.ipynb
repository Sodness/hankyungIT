# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'#한글 깨짐 해결
plt.rcParams['axes.unicode_minus'] = False  #- 깨짐 해결

# %%
key = '3stAbv9xb2DXsahAa8m%2BKk3IbrtFKuJERl1J94cP13IWHoRG4OiNDa2nBScTx0PicBTTDFVBTgfjv0hWpV6cBg%3D%3D'
startDt = '20220101'
endDt = '20220131'
stnIds = '108'

url1 = 'https://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey='+key
url2 = '&pageNo=1&numOfRows=999&dataType=XML&dataCd=ASOS&dateCd=DAY&startDt='+startDt
url3 = '&endDt='+endDt
url4 = '&stnIds='+stnIds

url = url1 + url2 + url3 + url4
print(url)
# Out:
# https://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey=3stAbv9xb2DXsahAa8m%2BKk3IbrtFKuJERl1J94cP13IWHoRG4OiNDa2nBScTx0PicBTTDFVBTgfjv0hWpV6cBg%3D%3D&pageNo=1&numOfRows=999&dataType=XML&dataCd=ASOS&dateCd=DAY&startDt=20220101&endDt=20220131&stnIds=108

# %%
# !pip install --upgrade certifi
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.2 requires ruamel-yaml, which is not installed.

# %%
# !pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   WARNING: The scripts pip.exe, pip3.9.exe and pip3.exe are installed in 'C:\Users\hjk70\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
xml=requests.get(url, verify = False)
soup=bs(xml.text,'html.parser')
data=soup.find_all('item')

items=['stnid', 'tm', 'avgta', 'minta', 'maxta', 'sumrn', 'maxws', 'avgws']

res=[]
for i in data:
    ls={}
    for j in items:
        try:
            ls[j]=i.find(j).text
        except:
            ls[j]=None
    res.append(ls)

df=pd.DataFrame(res)
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'apis.data.go.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
#    stnid          tm avgta  minta maxta sumrn maxws avgws
# 0    108  2022-01-01  -4.3  -10.2   2.3         2.8   1.5
# ...

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'#한글 깨짐 해결
plt.rcParams['axes.unicode_minus'] = False  #- 깨짐 해결
import warnings
warnings.filterwarnings('ignore')

KEY='2cEINdHyQva8gLZV3f60g86MwuvFmRscrEqPByci4qmrdaauq07ryNDP5eSxQV5O4h8VcKV87fcsnCvw3w235Q%3D%3D'
startDate='20220101'
endDate='20220131'
num='108'

url1='https://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey=' +KEY
url2='&numOfRows=999&dataType=XML&dataCd=ASOS&dateCd=DAY&startDt='+startDate
url3='&endDt='+endDate
url4='&stnIds='+num
url=url1+url2+url3+url4
print(url)

xml=requests.get(url, verify = False)
soup=bs(xml.text,'html.parser')
soup.find_all('tm')
# Out:
# https://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey=2cEINdHyQva8gLZV3f60g86MwuvFmRscrEqPByci4qmrdaauq07ryNDP5eSxQV5O4h8VcKV87fcsnCvw3w235Q%3D%3D&numOfRows=999&dataType=XML&dataCd=ASOS&dateCd=DAY&startDt=20220101&endDt=20220131&stnIds=108
# [<tm>2022-01-01</tm>,
#  <tm>2022-01-02</tm>,
#  <tm>2022-01-03</tm>,
#  <tm>2022-01-04</tm>,
#  <tm>2022-01-05</tm>,
#  <tm>2022-01-06</tm>,
#  <tm>2022-01-07</tm>,
#  <tm>2022-01-08</tm>,
#  <tm>2022-01-09</tm>,
#  <tm>2022-01-10</tm>,
#  <tm>2022-01-11</tm>,
#  <tm>2022-01-12</tm>,
#  <tm>2022-01-13</tm>,
#  <tm>2022-01-14</tm>,
#  <tm>2022-01-15</tm>,
#  <tm>2022-01-16</tm>,
#  <tm>2022-01-17</tm>,
#  <tm>2022-01-18</tm>,
#  <tm>2022-01-19</tm>,
#  <tm>2022-01-20</tm>,
#  <tm>2022-01-21</tm>,
#  <tm>2022-01-22</tm>,
#  <tm>2022-01-23</tm>,
#  <tm>2022-01-24</tm>,
#  <tm>2022-01-25</tm>,
#  <tm>2022-01-26</tm>,
#  <tm>2022-01-27</tm>,
#  <tm>2022-01-28</tm>,
#  <tm>2022-01-29</tm>,
#  <tm>2022-01-30</tm>,
# ...

# %%
# json으로 기상청 api 자료 받기
import requests
import json
import pandas as pd
import time

key = '3stAbv9xb2DXsahAa8m%2BKk3IbrtFKuJERl1J94cP13IWHoRG4OiNDa2nBScTx0PicBTTDFVBTgfjv0hWpV6cBg%3D%3D'
startDt = '20220101'
endDt = '20220131'
stnIds = '108'

url1 = 'http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey='+key
url2 = '&pageNo=1&numOfRows=999&dataType=JSON&dataCd=ASOS&dateCd=DAY&startDt='+startDt
url3 = '&endDt='+endDt
url4 = '&stnIds='+stnIds

url = url1 + url2 + url3 + url4

response = requests.get(url)
start = time.time()
json_obj = json.loads(response.text)

type(json.loads(response.text))

json_obj

json_obj['response']

json_obj['response']['body']

json_obj['response']['body']['items']

json_obj['response']['body']['items']['item']

len(json_obj['response']['body']['items']['item'])

items = json_obj['response']['body']['items']['item']
df = pd.DataFrame(items)

df_res = df[['stnid', 'tm', 'avgta', 'minta', 'maxta', 'sumrn', 'maxws', 'avgws']]
display(df_res)
print(time.time()-start)
# Out:
#    stnid          tm avgta  minta maxta sumrn maxws avgws
# 0    108  2022-01-01  -4.3  -10.2   2.3         2.8   1.5
# 1    108  2022-01-02  -1.3   -5.2   3.0   0.3   4.6   2.3
# 2    108  2022-01-03  -1.9   -8.0   2.5   0.0   4.1   1.8
# 3    108  2022-01-04  -2.5   -5.6   1.0   0.0   4.2   2.4
# 4    108  2022-01-05  -2.8   -7.8   1.9         2.9   1.7
# 5    108  2022-01-06  -2.2   -5.9   3.3         4.6   2.3
# 6    108  2022-01-07  -1.6   -5.9   4.5         3.0   1.5
# 7    108  2022-01-08   0.3   -5.0   3.7   0.0   3.5   1.7
# 8    108  2022-01-09   1.3   -1.2   5.6         2.8   1.7
# 9    108  2022-01-10   0.5   -3.4   4.4   0.9   3.4   2.0
# 10   108  2022-01-11  -7.4  -10.3   0.3   0.2   7.2   4.0
# 11   108  2022-01-12  -7.7  -11.3  -3.4         4.2   2.4
# 12   108  2022-01-13  -6.4   -8.9  -3.1         7.6   3.3
# 13   108  2022-01-14  -4.8  -10.1   1.3         3.2   1.7
# 14   108  2022-01-15  -1.0   -5.3   1.8   0.0   3.1   1.9
# ...
