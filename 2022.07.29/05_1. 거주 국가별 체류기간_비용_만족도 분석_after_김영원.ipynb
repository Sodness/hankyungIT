# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import os
import seaborn as sns
if os.name == 'nt':
    font_family = "Malgun Gothic"
else:
    font_family = "AppleGothic"
    
sns.set(font=font_family, rc={"axes.unicode_minus" : False })

# %%
df = pd.read_csv('./data/ftour.csv', encoding='euc-kr')
df.head()
# Out:
# C:\Users\hjk70\AppData\Local\Temp\ipykernel_19152\2540204886.py:1: DtypeWarning: Columns (2,73,76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/ftour.csv', encoding='euc-kr')
#     id  gender age edu job   nat other count  month  info1  ... accom shop1  \
# 0  584       2   0   1   8    일본           1      3      3  ...     1     7
# 1  840       1   3   2   2  싱가포르     1    18     11      3  ...     1     7
# 2  524       1   1   3   8   프랑스           1      6      3  ...     3     6
# 3  282       1   1   2   8    미국           2      2      2  ...     4     4
# 4  562       1   2   3   6    미국     1     1      8      3  ...     2    12
#
#    shop2  shop3 prd1 prd2 prd3     expense     card        cash
# 0     11           5   19       480.975000    0.000  480.975000
# 1                  5            646.888000  323.444  323.444000
# 2      7      8    9   10   11  560.650000    0.000  560.650000
# ...

# %%
df.shape
# Out:
# (13501, 82)

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'edu', 'job', 'nat', 'other', 'count', 'month',
#        'info1', 'info2', 'info3', 'decision', 'object', 'mov1', 'mov2', 'mov3',
#        'member', 'number', 'tourtype', 'period', 'overal', 'sat1', 'sat2',
#        'sat3', 'sat4', 'sat5', 'sat6', 'sat7', 'sat8', 'sat9', 'sat10',
#        'bf_img', 'af_img', 'revisit', 'recom', 'district1', 'district2',
#        'district3', 'district4', 'district5', 'district6', 'district7',
#        'district8', 'district9', 'district10', 'district11', 'district12',
#        'district13', 'district14', 'district15', 'district16', 'district17',
#        'district18', 'district19', 'zone1', 'zone2', 'zone3', 'zone4', 'zone5',
#        'zone6', 'zone7', 'zone8', 'zone9', 'zone10', 'bestspot1', 'bestspot2',
#        'bestspot3', 'act1', 'act2', 'act3', 'bestact', 'accom', 'shop1',
#        'shop2', 'shop3', 'prd1', 'prd2', 'prd3', 'expense', 'card', 'cash'],
#       dtype='object')

# %%
df.columns.sort_values()
# Out:
# Index(['accom', 'act1', 'act2', 'act3', 'af_img', 'age', 'bestact',
#        'bestspot1', 'bestspot2', 'bestspot3', 'bf_img', 'card', 'cash',
#        'count', 'decision', 'district1', 'district10', 'district11',
#        'district12', 'district13', 'district14', 'district15', 'district16',
#        'district17', 'district18', 'district19', 'district2', 'district3',
#        'district4', 'district5', 'district6', 'district7', 'district8',
#        'district9', 'edu', 'expense', 'gender', 'id', 'info1', 'info2',
#        'info3', 'job', 'member', 'month', 'mov1', 'mov2', 'mov3', 'nat',
#        'number', 'object', 'other', 'overal', 'period', 'prd1', 'prd2', 'prd3',
#        'recom', 'revisit', 'sat1', 'sat10', 'sat2', 'sat3', 'sat4', 'sat5',
#        'sat6', 'sat7', 'sat8', 'sat9', 'shop1', 'shop2', 'shop3', 'tourtype',
#        'zone1', 'zone10', 'zone2', 'zone3', 'zone4', 'zone5', 'zone6', 'zone7',
#        'zone8', 'zone9'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13501 entries, 0 to 13500
# Data columns (total 82 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          13501 non-null  int64
#  1   gender      13501 non-null  int64
#  2   age         13501 non-null  object
#  3   edu         13501 non-null  object
#  4   job         13501 non-null  object
#  5   nat         13501 non-null  object
#  6   other       13501 non-null  object
#  7   count       13501 non-null  object
#  8   month       13501 non-null  int64
#  9   info1       13501 non-null  int64
#  10  info2       13501 non-null  object
#  11  info3       13501 non-null  object
#  12  decision    13501 non-null  int64
#  13  object      13501 non-null  int64
#  14  mov1        13501 non-null  object
#  15  mov2        13501 non-null  object
#  16  mov3        13501 non-null  object
#  17  member      13501 non-null  object
#  18  number      13501 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id        gender         month         info1      decision  \
# count  13501.000000  13501.000000  13501.000000  13501.000000  13501.000000
# mean     689.991482      1.521369      6.469299      2.962151      3.329235
# std      621.187845      0.499562      3.451768      1.778965      3.517612
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%      290.000000      1.000000      3.000000      2.000000      1.000000
# 50%      588.000000      2.000000      6.000000      3.000000      2.000000
# 75%      890.000000      2.000000      9.000000      3.000000      4.000000
# max     7007.000000      2.000000     12.000000      9.000000     72.000000
#
#              object        number        period        overal          sat1  \
# count  13501.000000  13501.000000  13501.000000  13501.000000  13501.000000
# mean       3.170876      3.006666     14.616399      4.406118      4.325457
# ...

# %%
df.describe()[['period','overal','expense']]
# Out:
#              period        overal       expense
# count  13501.000000  13501.000000  1.350100e+04
# mean      14.616399      4.406118  4.767706e+03
# std       34.456984      0.590684  1.297740e+05
# min        1.000000      1.000000  1.013000e-01
# 25%        4.000000      4.000000  6.018940e+02
# 50%        5.000000      4.000000  1.017800e+03
# 75%        8.000000      5.000000  1.792000e+03
# max      365.000000      5.000000  1.355000e+07

# %%
plt.scatter(df.index, df['period'])

# %%
plt.scatter(df.index, df['period'])
plt.show()
plt.boxplot(df['period'])
plt.show()

# %%
plt.subplot(1,2,1)
plt.scatter(df.index, df['period'])
plt.subplot(1,2,2)
plt.boxplot(df['period'])
plt.show()

# %%
a=[1,2,3,4]
b=[5,6,7,8]
plt.plot(a)
plt.plot(b)

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.scatter(df.index, df['period'])
plt.subplot(1,2,2)
plt.boxplot(df['period'])
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.title('산점도')
plt.scatter(df.index, df['period'])
plt.subplot(1,2,2)
plt.boxplot(df['period'])
plt.title('박스')
plt.savefig('./test.jpg')
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.subplot(121)
plt.scatter(df.index, df['expense'])
plt.subplot(122)
plt.boxplot(df['expense'])
plt.show()

# %%
df[['period', 'expense', 'overal']].describe()
# Out:
#              period       expense        overal
# count  13501.000000  1.350100e+04  13501.000000
# mean      14.616399  4.767706e+03      4.406118
# std       34.456984  1.297740e+05      0.590684
# min        1.000000  1.013000e-01      1.000000
# 25%        4.000000  6.018940e+02      4.000000
# 50%        5.000000  1.017800e+03      4.000000
# 75%        8.000000  1.792000e+03      5.000000
# max      365.000000  1.355000e+07      5.000000

# %%
plt.figure(figsize=(15,6))
plt.subplot(121)
plt.scatter(df.index, df['overal'])
plt.subplot(122)
plt.boxplot(df['overal'])
plt.show()

# %%
df[df['overal'] <= 2]['nat'].sort_values()
# Out:
# 995         독일
# 744        러시아
# 395      말레이시아
# 2258     말레이시아
# 7928       베트남
# 7922       베트남
# 7921       베트남
# 5177      싱가포르
# 8824        인도
# 13056    인도네시아
# 858      인도네시아
# 6393        일본
# 11106       중국
# 10151       중국
# 9607        중국
# 9499        중국
# 13223       중국
# 6777        중국
# 5084        중국
# 10005      캐나다
# 6628       캐나다
# 6330        태국
# 1392        호주
# 12771       호주
# 8857        호주
# 8974        홍콩
# 7255        홍콩
# Name: nat, dtype: object

# %%
df[df['overal'] <= 2]['nat'].value_counts()
# Out:
# 중국       7
# 호주       3
# 베트남      3
# 말레이시아    2
# 인도네시아    2
# 캐나다      2
# 홍콩       2
# 러시아      1
# 독일       1
# 싱가포르     1
# 태국       1
# 일본       1
# 인도       1
# Name: nat, dtype: int64

# %%
df[df['overal'] <= 2]['nat'].value_counts().sum()
# Out:
# 27

# %%
len(df)
# Out:
# 13501

# %%
27 / 13501
# Out:
# 0.001999851862824976

# %%
ls = ['period', 'expense', 'overal']
for i in ls:
    plt.figure(figsize=(15,6))
    plt.subplot(121)
    plt.scatter(df.index, df[i])
    plt.title(f'{i}')
    plt.subplot(122)
    plt.boxplot(df[i])
    plt.show()

# %%
tmp = df.groupby('nat')['period'].sum()
tmp
# Out:
# nat
# 대만        8010
# 독일        7035
# 러시아       9199
# 말레이시아     5458
# 미국       15975
# 베트남      20516
# 싱가포르      4164
# 영국        5981
# 인도        8916
# 인도네시아     4062
# 일본        7837
# 중국       51715
# 중동       13185
# 캐나다       7371
# 태국        5674
# 프랑스       7877
# 필리핀       4483
# 호주        5059
# 홍콩        4819
# Name: period, dtype: int64

# %%
tmp.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='nat'>

# %%
tmp = df.groupby('nat')['period'].sum().sort_values(ascending=False)
tmp
# Out:
# nat
# 중국       51715
# 베트남      20516
# 미국       15975
# 중동       13185
# 러시아       9199
# 인도        8916
# 대만        8010
# 프랑스       7877
# 일본        7837
# 캐나다       7371
# 독일        7035
# 영국        5981
# 태국        5674
# 말레이시아     5458
# 호주        5059
# 홍콩        4819
# 필리핀       4483
# 싱가포르      4164
# 인도네시아     4062
# Name: period, dtype: int64

# %%
tmp.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='nat'>

# %%
df.groupby('nat')['period'].sum().sort_values().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='nat'>

# %%
plt.figure(figsize=(10,5))
plt.subplot(131)
df.groupby('nat')['period'].mean().sort_values().plot(kind='barh')
plt.subplot(132)
df.groupby('nat')['expense'].mean().sort_values().plot(kind='barh')
plt.subplot(133)
df.groupby('nat')['overal'].mean().sort_values().plot(kind='barh')
plt.tight_layout()

# %%
tmp = df[df['period'] <= 30]
tmp
# Out:
#          id  gender age edu job   nat other count  month  info1  ... accom  \
# 0       584       2   0   1   8    일본           1      3      3  ...     1
# 1       840       1   3   2   2  싱가포르     1    18     11      3  ...     1
# 2       524       1   1   3   8   프랑스           1      6      3  ...     3
# 3       282       1   1   2   8    미국           2      2      2  ...     4
# 4       562       1   2   3   6    미국     1     1      8      3  ...     2
# ...     ...     ...  ..  ..  ..   ...   ...   ...    ...    ...  ...   ...
# 13496  7003       2   2   2   3    일본           1     12      1  ...     1
# 13497  7004       2   4   1   7    일본           1     12      1  ...     1
# 13498  7005       1   4   1   7    일본           3     12      9  ...     2
# 13499  7006       2   4   1   9    일본           1     12      1  ...     1
# 13500  7007       2   3   2   3    일본           1     12      1  ...     1
#
# ...

# %%
plt.figure(figsize=(10,5))
plt.subplot(131)
tmp.groupby('nat')['period'].mean().sort_values().plot(kind='barh')
plt.subplot(132)
tmp.groupby('nat')['expense'].mean().sort_values().plot(kind='barh')
plt.subplot(133)
tmp.groupby('nat')['overal'].mean().sort_values().plot(kind='barh')
plt.tight_layout()

# %%
# 각 나라별 'period','expense','overal' 산점도(scatter)차트 그리기
# 나라명 중복제거 (tmp2['nat'].unique())
# 각 나라별 필터링한 후
# 'period','expense','overal' 산점도(scatter)차트 작성함

# %%
g_p = df.groupby('nat')['period']
list(g_p)[0]
# Out:
# ('대만',
#  104      7
#  131      5
#  152      4
#  251      5
#  422      6
#          ..
#  13487    4
#  13488    4
#  13490    4
#  13492    5
#  13493    4
#  Name: period, Length: 947, dtype: int64)

# %%
g_p = df.groupby('nat')['period']
g_e = df.groupby('nat')['expense']
g_o = df.groupby('nat')['overal']

for idx,nat,data in enumerate(g_p):
    plt.subplot(311)
    plt.title(f'{nat}period')
    plt.scatter(idx, data)

# %%
names = df['nat'].unique()
ls = ['period', 'expense', 'overal']
for name in names:
    tmp = df[df['nat']==name]
    plt.figure(figsize=(15,3))
    for idx,i in enumerate(ls):
        plt.subplot(1,3,idx+1)
        plt.scatter(tmp.index, tmp[i])
        plt.title(f'{name}의 {i}차트')
