# %%
import googlemaps

# %%
# 딕셔너리로 가져오기 (keys)
gmaps_key = 'AIzaSyBj6OzihwNo481ZAW94ldwLwaigqn1vvWc'
gmaps = googlemaps.Client(key=gmaps_key)
loc = gmaps.geocode('경복궁', language='ko')
loc
# Out:
# [{'address_components': [{'long_name': '１６１',
#     'short_name': '１６１',
#     'types': ['premise']},
#    {'long_name': '사직로',
#     'short_name': '사직로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '종로구',
#     'short_name': '종로구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '110-050',
#     'short_name': '110-050',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 종로구 사직로 161',
#   'geometry': {'location': {'lat': 37.579617, 'lng': 126.977041},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5809659802915,
#      'lng': 126.9783899802915},
#     'southwest': {'lat': 37.5782680197085, 'lng': 126.9756920197085}}},
# ...

# %%
loc[0].keys()
# Out:
# dict_keys(['address_components', 'formatted_address', 'geometry', 'partial_match', 'place_id', 'plus_code', 'types'])

# %%
loc[0]['address_components']
# Out:
# [{'long_name': '１６１', 'short_name': '１６１', 'types': ['premise']},
#  {'long_name': '사직로',
#   'short_name': '사직로',
#   'types': ['political', 'sublocality', 'sublocality_level_4']},
#  {'long_name': '종로구',
#   'short_name': '종로구',
#   'types': ['political', 'sublocality', 'sublocality_level_1']},
#  {'long_name': '서울특별시',
#   'short_name': '서울특별시',
#   'types': ['administrative_area_level_1', 'political']},
#  {'long_name': '대한민국', 'short_name': 'KR', 'types': ['country', 'political']},
#  {'long_name': '110-050', 'short_name': '110-050', 'types': ['postal_code']}]

# %%
loc[0]['address_components'][1].keys()
# Out:
# dict_keys(['long_name', 'short_name', 'types'])

# %%
types = loc[0]['address_components'][2]['types']
types
# Out:
# ['political', 'sublocality', 'sublocality_level_1']

# %%
short_name = loc[0]['address_components'][4]['short_name']
short_name
# Out:
# 'KR'

# %%
loc[0].keys()
# Out:
# dict_keys(['address_components', 'formatted_address', 'geometry', 'partial_match', 'place_id', 'plus_code', 'types'])

# %%
plus_code = loc[0]['plus_code']
plus_code
# Out:
# {'compound_code': 'HXHG+RR 대한민국 서울특별시', 'global_code': '8Q98HXHG+RR'}

# %%
print(types)
print(short_name)
print(plus_code)
# Out:
# ['political', 'sublocality', 'sublocality_level_1']
# KR
# {'compound_code': 'HXHG+RR 대한민국 서울특별시', 'global_code': '8Q98HXHG+RR'}

# %%
# JSON 뷰어로 가져오기
loc
# Out:
# [{'address_components': [{'long_name': '１６１',
#     'short_name': '１６１',
#     'types': ['premise']},
#    {'long_name': '사직로',
#     'short_name': '사직로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '종로구',
#     'short_name': '종로구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '110-050',
#     'short_name': '110-050',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 종로구 사직로 161',
#   'geometry': {'location': {'lat': 37.579617, 'lng': 126.977041},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5809659802915,
#      'lng': 126.9783899802915},
#     'southwest': {'lat': 37.5782680197085, 'lng': 126.9756920197085}}},
# ...

# %%
import json

# %%
json.dumps(loc, ensure_ascii=False)
# Out:
# '[{"address_components": [{"long_name": "１６１", "short_name": "１６１", "types": ["premise"]}, {"long_name": "사직로", "short_name": "사직로", "types": ["political", "sublocality", "sublocality_level_4"]}, {"long_name": "종로구", "short_name": "종로구", "types": ["political", "sublocality", "sublocality_level_1"]}, {"long_name": "서울특별시", "short_name": "서울특별시", "types": ["administrative_area_level_1", "political"]}, {"long_name": "대한민국", "short_name": "KR", "types": ["country", "political"]}, {"long_name": "110-050", "short_name": "110-050", "types": ["postal_code"]}], "formatted_address": "대한민국 서울특별시 종로구 사직로 161", "geometry": {"location": {"lat": 37.579617, "lng": 126.977041}, "location_type": "ROOFTOP", "viewport": {"northeast": {"lat": 37.5809659802915, "lng": 126.9783899802915}, "southwest": {"lat": 37.5782680197085, "lng": 126.9756920197085}}}, "partial_match": true, "place_id": "ChIJod7tSseifDUR9hXHLFNGMIs", "plus_code": {"compound_code": "HXHG+RR 대한민국 서울특별시", "global_code": "8Q98HXHG+RR"}, "ty
# ...

# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %%
types1 = loc[0]['address_components'][2]['types']
types1
# Out:
# ['political', 'sublocality', 'sublocality_level_1']

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %%
short_name1 = loc[0]['address_components'][4]['short_name']
short_name1
# Out:
# 'KR'

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %%
plus_code1 = loc[0]['plus_code']
plus_code1
# Out:
# {'compound_code': 'HXHG+RR 대한민국 서울특별시', 'global_code': '8Q98HXHG+RR'}

# %%
print(types1)
print(short_name1)
print(plus_code1)
# Out:
# ['political', 'sublocality', 'sublocality_level_1']
# KR
# {'compound_code': 'HXHG+RR 대한민국 서울특별시', 'global_code': '8Q98HXHG+RR'}
