# %% [markdown]
# # 구글지도 API로 주소와 지도좌표 가져오기
#
# ## 1. googlemaps 패키지
#
# 설치가 되어있지 않다면 아래의 코드로 설치합니다
#
# ### !pip install googlemaps
#
# ### [참고자료]
# 1. https://github.com/googlemaps/google-maps-services-python
# 2. help(googlemaps)
# 3. 구글 앱 활용 : https://happist.com/568746/%EA%B5%AC%EA%B8%80%EB%A7%B5-%ED%99%9C%EC%9A%A9%EB%B2%95-%EA%B5%AC%EA%B8%80%EB%A7%B5-api-key-%EB%B0%9C%EA%B8%89%EB%B0%A9%EB%B2%95
#
# 4. 구글 맵 플랫폼 바로가기 : https://mapsplatform.google.com/

# %%
import googlemaps

# %% [markdown]
# ## 2. 구글maps api에서 지도 정보가져오기

# %%
gmaps_key = "AIzaSyCZvnX7q7qlQxNNy3wnLKHxlz2xo6sStSI" # 자신의 key를 사용합니다.
gmaps = googlemaps.Client(key=gmaps_key) #구글maps Api 웹 서비스를 요청합니다.

# %%
gmaps.geocode('경복궁', language='ko') #경복궁 지도 정보를 가져옵니다.
# Out:
# [{'address_components': [{'long_name': '１６１',
#     'short_name': '１６１',
#     'types': ['premise']},
#    {'long_name': '사직로',
#     'short_name': '사직로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '종로구',
#     'short_name': '종로구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '110-050',
#     'short_name': '110-050',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 종로구 사직로 161',
#   'geometry': {'location': {'lat': 37.579617, 'lng': 126.977041},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5809659802915,
#      'lng': 126.9783899802915},
#     'southwest': {'lat': 37.5782680197085, 'lng': 126.9756920197085}}},
# ...

# %% [markdown]
# ## 3. 지도정보 확인하기

# %%
import json

# %%
tmp=gmaps.geocode('경복궁', language='ko') #'서울 시청지도 정보를 가져옴'

# %%
obj=json.dumps(tmp, ensure_ascii=False)

# %%
obj
# Out:
# '[{"address_components": [{"long_name": "１６１", "short_name": "１６１", "types": ["premise"]}, {"long_name": "사직로", "short_name": "사직로", "types": ["political", "sublocality", "sublocality_level_4"]}, {"long_name": "종로구", "short_name": "종로구", "types": ["political", "sublocality", "sublocality_level_1"]}, {"long_name": "서울특별시", "short_name": "서울특별시", "types": ["administrative_area_level_1", "political"]}, {"long_name": "대한민국", "short_name": "KR", "types": ["country", "political"]}, {"long_name": "110-050", "short_name": "110-050", "types": ["postal_code"]}], "formatted_address": "대한민국 서울특별시 종로구 사직로 161", "geometry": {"location": {"lat": 37.579617, "lng": 126.977041}, "location_type": "ROOFTOP", "viewport": {"northeast": {"lat": 37.5809659802915, "lng": 126.9783899802915}, "southwest": {"lat": 37.5782680197085, "lng": 126.9756920197085}}}, "partial_match": true, "place_id": "ChIJod7tSseifDUR9hXHLFNGMIs", "plus_code": {"compound_code": "HXHG+RR 대한민국 서울특별시", "global_code": "8Q98HXHG+RR"}, "ty
# ...

# %%
obj = json.dumps(tmp, ensure_ascii=False) #json으로 변환 후 json viewer로 자료 확인 (http://jsonviewer.stack.hu/)

# %%
obj
# Out:
# '[{"address_components": [{"long_name": "１６１", "short_name": "１６１", "types": ["premise"]}, {"long_name": "사직로", "short_name": "사직로", "types": ["political", "sublocality", "sublocality_level_4"]}, {"long_name": "종로구", "short_name": "종로구", "types": ["political", "sublocality", "sublocality_level_1"]}, {"long_name": "서울특별시", "short_name": "서울특별시", "types": ["administrative_area_level_1", "political"]}, {"long_name": "대한민국", "short_name": "KR", "types": ["country", "political"]}, {"long_name": "110-050", "short_name": "110-050", "types": ["postal_code"]}], "formatted_address": "대한민국 서울특별시 종로구 사직로 161", "geometry": {"location": {"lat": 37.579617, "lng": 126.977041}, "location_type": "ROOFTOP", "viewport": {"northeast": {"lat": 37.5809659802915, "lng": 126.9783899802915}, "southwest": {"lat": 37.5782680197085, "lng": 126.9756920197085}}}, "partial_match": true, "place_id": "ChIJod7tSseifDUR9hXHLFNGMIs", "plus_code": {"compound_code": "HXHG+RR 대한민국 서울특별시", "global_code": "8Q98HXHG+RR"}, "ty
# ...

# %% [markdown]
# ## 4. 주소, 위도, 경도의 값만 파싱합니다.
# ### 1) 주소 가져오기

# %%
tmp[0]['formatted_address']
# Out:
# '대한민국 서울특별시 종로구 사직로 161'

# %%
tmp[0]['geometry']['location']['lat']
# Out:
# 37.579617

# %%
tmp[0].keys()
# Out:
# dict_keys(['address_components', 'formatted_address', 'geometry', 'partial_match', 'place_id', 'plus_code', 'types'])

# %%
tmp[0]['formatted_address']
# Out:
# '대한민국 서울특별시 종로구 사직로 161'

# %%
addr=tmp[0]['formatted_address']

# %%
lat=tmp[0]['geometry']['location']['lat']
lng=tmp[0]['geometry']['location']['lng']

# %%
print('경복궁 주소 => ',addr, '위도:', lat, '경도:',lng)
# Out:
# 경복궁 주소 =>  대한민국 서울특별시 종로구 사직로 161 위도: 37.579617 경도: 126.977041

# %% [markdown]
# ### 2) 'geometry'에서 'lat','lng' 값 가져오기

# %%
lat=tmp[0]['geometry']['location']['lat'] #lat 가져오기
lat
# Out:
# 37.579617

# %%
lng=tmp[0]['geometry']['location']['lng'] #lng 가져오기
lng
# Out:
# 126.977041

# %% [markdown]
# ### 3) 주소, 위도, 경도 표시하기

# %%
#주소(addr), 위도(lat), 경도(lng)를 각각의 변수에 저장합니다.
#주소(addr), 위도(lat), 경도(lng)를 각각의 변수에 저장합니다.
print('▶ 경복궁 주소: '+addr+', [지도좌표] '+ str(lat)+','+str(lng))
# Out:
# ▶ 경복궁 주소: 대한민국 서울특별시, [지도좌표] 37.579617,126.977041

# %%
import pandas as pd

# %%
df=pd.read_csv('../교재data/DataScience-master/data/02. crime_in_Seoul.csv',thousands=',', encoding='cp949')

# %%
df.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 0   중부서      2      2      3      2    105     65   1395    477   1355   1170
# 1   종로서      3      3      6      5    115     98   1070    413   1278   1070
# 2  남대문서      1      0      6      4     65     46   1153    382    869    794
# 3  서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 4   혜화서      3      2      5      4     96     63   1114    424   1015    861

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   관서명     31 non-null     object
#  1   살인 발생   31 non-null     int64
#  2   살인 검거   31 non-null     int64
#  3   강도 발생   31 non-null     int64
#  4   강도 검거   31 non-null     int64
#  5   강간 발생   31 non-null     int64
#  6   강간 검거   31 non-null     int64
#  7   절도 발생   31 non-null     int64
#  8   절도 검거   31 non-null     int64
#  9   폭력 발생   31 non-null     int64
#  10  폭력 검거   31 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 2.8+ KB

# %%
station_name='서울'+df['관서명'].str[:-1]+'경찰서'

# %%
station_addr=[]
station_lat=[]
station_lng=[]

for name in station_name:
    tmp=gmaps.geocode(name, language='ko')
    station_addr.append(tmp[0]['formatted_address'])
    station_lat.append(tmp[0]['geometry']['location']['lat'])
    station_lng.append(tmp[0]['geometry']['location']['lng'])

# %%
df['구별']=[i.split()[2] for i in station_addr]

# %%
df.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 0   중부서      2      2      3      2    105     65   1395    477   1355   1170
# 1   종로서      3      3      6      5    115     98   1070    413   1278   1070
# 2  남대문서      1      0      6      4     65     46   1153    382    869    794
# 3  서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 4   혜화서      3      2      5      4     96     63   1114    424   1015    861
#
#      구별
# 0    중구
# 1   종로구
# 2    중구
# 3  서대문구
# 4   종로구

# %%
df[df['관서명'].str.contains('금천')]
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 15  금천서      3      4      6      6    151    122   1567    888   2054   1776
#
#      구별
# 15  금천구

# %%
df[df['구별']=='강남구']
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 17  강남서      3      3     15     12    300    225   2411    984   2465   2146
# 30  수서서     10      7      6      6    149    124   1439    666   1819   1559
#
#      구별
# 17  강남구
# 30  강남구

# %%
df.set_index('구별')
# Out:
#        관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  \
# 구별
# 중구     중부서      2      2      3      2    105     65   1395    477   1355
# 종로구    종로서      3      3      6      5    115     98   1070    413   1278
# 중구    남대문서      1      0      6      4     65     46   1153    382    869
# 서대문구  서대문서      2      2      5      4    154    124   1812    738   2056
# 종로구    혜화서      3      2      5      4     96     63   1114    424   1015
# 용산구    용산서      5      5     14     14    194    173   1557    587   2050
# 성북구    성북서      2      2      2      1     86     71    953    409   1194
# 동대문구  동대문서      5      5     13     13    173    146   1981    814   2548
# 마포구    마포서      8      8     14     10    294    247   2555    813   2983
# 영등포구  영등포서     14     12     22     20    295    183   2964    978   3572
# 성동구    성동서      4      4      9      8    126    119   1607    597   1612
# 동작구    동작서      5      5      9      5    285    139   1865    661   1910
# ...

# %%
df.set_index('구별')
# Out:
#        관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  \
# 구별
# 중구     중부서      2      2      3      2    105     65   1395    477   1355
# 종로구    종로서      3      3      6      5    115     98   1070    413   1278
# 중구    남대문서      1      0      6      4     65     46   1153    382    869
# 서대문구  서대문서      2      2      5      4    154    124   1812    738   2056
# 종로구    혜화서      3      2      5      4     96     63   1114    424   1015
# 용산구    용산서      5      5     14     14    194    173   1557    587   2050
# 성북구    성북서      2      2      2      1     86     71    953    409   1194
# 동대문구  동대문서      5      5     13     13    173    146   1981    814   2548
# 마포구    마포서      8      8     14     10    294    247   2555    813   2983
# 영등포구  영등포서     14     12     22     20    295    183   2964    978   3572
# 성동구    성동서      4      4      9      8    126    119   1607    597   1612
# 동작구    동작서      5      5      9      5    285    139   1865    661   1910
# ...

# %%
df.groupby('구별').sum()
# Out:
#       살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 구별
# 강남구      13     10     21     18    449    349   3850   1650   4284   3705
# 강동구       4      3      6      8    156    123   2366    789   2712   2248
# 강북구       7      8     14     13    153    126   1434    618   2649   2348
# 강서구       7      8     13     13    262    191   2096   1260   3207   2718
# 관악구       9      8     12     14    320    221   2706    827   3298   2642
# 광진구       4      4     14     26    240    220   3026   1277   2625   2180
# 구로구       8      6     15     11    281    164   2335    889   3007   2432
# 금천구       3      4      6      6    151    122   1567    888   2054   1776
# 노원구      10     10      7      7    197    121   2193    801   2723   2329
# 도봉구       3      3      9     10    102    106   1063    478   1487   1303
# 동대문구      5      5     13     13    173    146   1981    814   2548   2227
# ...

# %%
data = {
    "도시": ["서울", "서울", "서울", "부산", "부산", "부산", "인천", "인천"],
    "연도": ["2015", "2010", "2005", "2015", "2010", "2005", "2015", "2010"],
    "인구": [9904312, 9631482, 9762546, 3448737, 3393191, 3512547, 2890451, 263203],
    "지역": ["수도권", "수도권", "수도권", "경상권", "경상권", "경상권", "수도권", "수도권"]
}
columns = ["도시", "연도", "인구", "지역"]
df1 = pd.DataFrame(data, columns=columns)
df1
# Out:
#    도시    연도       인구   지역
# 0  서울  2015  9904312  수도권
# 1  서울  2010  9631482  수도권
# 2  서울  2005  9762546  수도권
# 3  부산  2015  3448737  경상권
# 4  부산  2010  3393191  경상권
# 5  부산  2005  3512547  경상권
# 6  인천  2015  2890451  수도권
# 7  인천  2010   263203  수도권

# %%
 df1.set_index(['도시','연도'])[['인구']].unstack(1)
# Out:
#            인구
# 연도       2005       2010       2015
# 도시
# 부산  3512547.0  3393191.0  3448737.0
# 서울  9762546.0  9631482.0  9904312.0
# 인천        NaN   263203.0  2890451.0

# %%
df1.groupby(['도시','연도']).sum().unstack(1)
# Out:
#            인구
# 연도       2005       2010       2015
# 도시
# 부산  3512547.0  3393191.0  3448737.0
# 서울  9762546.0  9631482.0  9904312.0
# 인천        NaN   263203.0  2890451.0

# %%
df1.pivot('도시','연도','인구')
# Out:
# 연도       2005       2010       2015
# 도시
# 부산  3512547.0  3393191.0  3448737.0
# 서울  9762546.0  9631482.0  9904312.0
# 인천        NaN   263203.0  2890451.0

# %%
df1
# Out:
#    도시    연도       인구   지역
# 0  서울  2015  9904312  수도권
# 1  서울  2010  9631482  수도권
# 2  서울  2005  9762546  수도권
# 3  부산  2015  3448737  경상권
# 4  부산  2010  3393191  경상권
# 5  부산  2005  3512547  경상권
# 6  인천  2015  2890451  수도권
# 7  인천  2010   263203  수도권

# %%
import numpy as np

# %%
pd.pivot_table(df,index='구별', aggfunc='sum')
# Out:
#       강간 검거  강간 발생  강도 검거  강도 발생  살인 검거  살인 발생  절도 검거  절도 발생  폭력 검거  폭력 발생
# 구별
# 강남구     349    449     18     21     10     13   1650   3850   3705   4284
# 강동구     123    156      8      6      3      4    789   2366   2248   2712
# 강북구     126    153     13     14      8      7    618   1434   2348   2649
# 강서구     191    262     13     13      8      7   1260   2096   2718   3207
# 관악구     221    320     14     12      8      9    827   2706   2642   3298
# 광진구     220    240     26     14      4      4   1277   3026   2180   2625
# 구로구     164    281     11     15      6      8    889   2335   2432   3007
# 금천구     122    151      6      6      4      3    888   1567   1776   2054
# 노원구     121    197      7      7     10     10    801   2193   2329   2723
# 도봉구     106    102     10      9      3      3    478   1063   1303   1487
# 동대문구    146    173     13     13      5      5    814   1981   2227   2548
# ...

# %%
df.head()
# Out:
#     관서명  살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 0   중부서      2      2      3      2    105     65   1395    477   1355   1170
# 1   종로서      3      3      6      5    115     98   1070    413   1278   1070
# 2  남대문서      1      0      6      4     65     46   1153    382    869    794
# 3  서대문서      2      2      5      4    154    124   1812    738   2056   1711
# 4   혜화서      3      2      5      4     96     63   1114    424   1015    861
#
#      구별
# 0    중구
# 1   종로구
# 2    중구
# 3  서대문구
# 4   종로구

# %%
df0=df.groupby('구별').sum()

# %%
df0.head()
# Out:
#      살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 구별
# 강남구     13     10     21     18    449    349   3850   1650   4284   3705
# 강동구      4      3      6      8    156    123   2366    789   2712   2248
# 강북구      7      8     14     13    153    126   1434    618   2649   2348
# 강서구      7      8     13     13    262    191   2096   1260   3207   2718
# 관악구      9      8     12     14    320    221   2706    827   3298   2642

# %%
names=[i[:2] for i in df0.columns]

# %%
df0.head()
# Out:
#      살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거
# 구별
# 강남구     13     10     21     18    449    349   3850   1650   4284   3705
# 강동구      4      3      6      8    156    123   2366    789   2712   2248
# 강북구      7      8     14     13    153    126   1434    618   2649   2348
# 강서구      7      8     13     13    262    191   2096   1260   3207   2718
# 관악구      9      8     12     14    320    221   2706    827   3298   2642

# %%
for i in range(0,len(df0.columns),2):
    name=df0.columns[i][:2]+'검거율'
    tmp=df0.iloc[:,i+1]/df0.iloc[:,i]*100
    df0[name]=tmp

# %%
df0
# Out:
#       살인 발생  살인 검거  강도 발생  강도 검거  강간 발생  강간 검거  절도 발생  절도 검거  폭력 발생  폭력 검거  \
# 구별
# 강남구      13     10     21     18    449    349   3850   1650   4284   3705
# 강동구       4      3      6      8    156    123   2366    789   2712   2248
# 강북구       7      8     14     13    153    126   1434    618   2649   2348
# 강서구       7      8     13     13    262    191   2096   1260   3207   2718
# 관악구       9      8     12     14    320    221   2706    827   3298   2642
# 광진구       4      4     14     26    240    220   3026   1277   2625   2180
# 구로구       8      6     15     11    281    164   2335    889   3007   2432
# 금천구       3      4      6      6    151    122   1567    888   2054   1776
# 노원구      10     10      7      7    197    121   2193    801   2723   2329
# 도봉구       3      3      9     10    102    106   1063    478   1487   1303
# 동대문구      5      5     13     13    173    146   1981    814   2548   2227
# ...

# %%
df0.columns
# Out:
# Index(['살인 발생', '살인 검거', '강도 발생', '강도 검거', '강간 발생', '강간 검거', '절도 발생', '절도 검거',
#        '폭력 발생', '폭력 검거', '살인검거율', '강도검거율', '강간검거율', '절도검거율', '폭력검거율'],
#       dtype='object')

# %%
df0=df0[['살인 발생', '강도 발생',  '강간 발생', '절도 발생', '폭력 발생', '폭력 검거', '살인검거율', '강도검거율', '강간검거율', '절도검거율', '폭력검거율']]

# %%
df0.columns=['살인', '강도', '강간', '절도', '폭력', '폭력 검거', '살인검거율', '강도검거율',
       '강간검거율', '절도검거율', '폭력검거율']

# %%
df0.head()
# Out:
#      살인  강도   강간    절도    폭력  폭력 검거       살인검거율       강도검거율      강간검거율  \
# 구별
# 강남구  13  21  449  3850  4284   3705   76.923077   85.714286  77.728285
# 강동구   4   6  156  2366  2712   2248   75.000000  133.333333  78.846154
# 강북구   7  14  153  1434  2649   2348  114.285714   92.857143  82.352941
# 강서구   7  13  262  2096  3207   2718  114.285714  100.000000  72.900763
# 관악구   9  12  320  2706  3298   2642   88.888889  116.666667  69.062500
#
#          절도검거율      폭력검거율
# 구별
# 강남구  42.857143  86.484594
# 강동구  33.347422  82.890855
# 강북구  43.096234  88.637222
# 강서구  60.114504  84.752105
# 관악구  30.561715  80.109157

# %%
df0.columns=['강간', '강도', '살인', '절도', '폭력']

# %%
[i[:2] for i in df0.columns]
# Out:
# ['강간', '강도', '살인', '절도', '폭력']

# %%
df0.head()
# Out:
#             강간          강도          살인         절도         폭력
# 구별
# 강남구  77.728285   85.714286   76.923077  42.857143  86.484594
# 강동구  78.846154  133.333333   75.000000  33.347422  82.890855
# 강북구  82.352941   92.857143  114.285714  43.096234  88.637222
# 강서구  72.900763  100.000000  114.285714  60.114504  84.752105
# 관악구  69.062500  116.666667   88.888889  30.561715  80.109157

# %%
df0.head()
# Out:
#      살인  강도   강간    절도    폭력  폭력 검거       살인검거율       강도검거율      강간검거율  \
# 구별
# 강남구  13  21  449  3850  4284   3705   76.923077   85.714286  77.728285
# 강동구   4   6  156  2366  2712   2248   75.000000  133.333333  78.846154
# 강북구   7  14  153  1434  2649   2348  114.285714   92.857143  82.352941
# 강서구   7  13  262  2096  3207   2718  114.285714  100.000000  72.900763
# 관악구   9  12  320  2706  3298   2642   88.888889  116.666667  69.062500
#
#          절도검거율      폭력검거율
# 구별
# 강남구  42.857143  86.484594
# 강동구  33.347422  82.890855
# 강북구  43.096234  88.637222
# 강서구  60.114504  84.752105
# 관악구  30.561715  80.109157

# %%
pwd
# Out:
# 'D:\\py\\_한경닷컴\\수업자료\\02 구글API'

# %%
resul_CCTV=pd.read_csv('../교재data/DataScience-master/data/01. CCTV_result.csv')

# %%
resul_CCTV.head()
# Out:
#     구별    소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 0  강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 1  강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 2  강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 3  강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 4  관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#        고령자비율    CCTV비율           오차
# 0  11.072217  0.487292  1388.055355
# 1  12.051638  0.170552   465.422892
# 2  16.600342  0.226535   329.342026
# 3  12.015794  0.146413   551.503155
# 4  12.955291  0.284673   162.948104

# %%
df0=pd.merge(df0, resul_CCTV[['구별','인구수','소계']], on='구별', how='left')

# %%
df0.columns=['구별', '살인', '강도', '강간', '절도', '폭력', '폭력 검거', '살인검거율', '강도검거율', '강간검거율',
       '절도검거율', '폭력검거율', '인구수', 'CCTV']

# %%
df0.head()
# Out:
#     구별  살인  강도   강간    절도    폭력  폭력 검거       살인검거율       강도검거율      강간검거율  \
# 0  강남구  13  21  449  3850  4284   3705   76.923077   85.714286  77.728285
# 1  강동구   4   6  156  2366  2712   2248   75.000000  133.333333  78.846154
# 2  강북구   7  14  153  1434  2649   2348  114.285714   92.857143  82.352941
# 3  강서구   7  13  262  2096  3207   2718  114.285714  100.000000  72.900763
# 4  관악구   9  12  320  2706  3298   2642   88.888889  116.666667  69.062500
#
#        절도검거율      폭력검거율       인구수  CCTV
# 0  42.857143  86.484594  570500.0  2780
# 1  33.347422  82.890855  453233.0   773
# 2  43.096234  88.637222  330192.0   748
# 3  60.114504  84.752105  603772.0   884
# 4  30.561715  80.109157  525515.0  1496

# %%
def minmax(x):
    max_=max(x)
    min_=min(x)
    res=(x-min_)/(max_-min_)
    return res

# %%
df0['강간'].map(minmax)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [248], in <cell line: 1>()
# ----> 1 df0['강간'].map(minmax)
#
# File ~\miniconda3\envs\hmh\lib\site-packages\pandas\core\series.py:4237, in Series.map(self, arg, na_action)
#    4162 def map(self, arg, na_action=None) -> Series:
#    4163     """
#    4164     Map values of Series according to an input mapping or function.
#    4165
#    (...)
#    4235     dtype: object
#    4236     """
# -> 4237     new_values = self._map_values(arg, na_action=na_action)
#    4238     return self._constructor(new_values, index=self.index).__finalize__(
#    4239         self, method="map"
#    4240     )
#
# File ~\miniconda3\envs\hmh\lib\site-packages\pandas\core\base.py:880, in IndexOpsMixin._map_values(self, mapper, na_action)
#     877         raise ValueError(msg)
#     879 # mapper is a function
# ...

# %%
df0[['강간','강도','살인','절도']].apply(minmax)
# Out:
#           강간        강도        살인        절도
# 0   1.000000  0.941176  0.916667  1.000000
# 1   0.155620  0.058824  0.166667  0.467528
# 2   0.146974  0.529412  0.416667  0.133118
# 3   0.461095  0.470588  0.416667  0.370649
# 4   0.628242  0.411765  0.583333  0.589523
# 5   0.397695  0.529412  0.166667  0.704342
# 6   0.515850  0.588235  0.500000  0.456405
# 7   0.141210  0.058824  0.083333  0.180840
# 8   0.273775  0.117647  0.666667  0.405454
# 9   0.000000  0.235294  0.083333  0.000000
# 10  0.204611  0.470588  0.250000  0.329386
# 11  0.527378  0.235294  0.250000  0.287765
# 12  0.553314  0.529412  0.500000  0.535343
# 13  0.149856  0.000000  0.000000  0.268748
# 14  0.838617  0.235294  0.500000  0.564047
# 15  0.069164  0.235294  0.166667  0.195192
# 16  0.138329  0.000000  0.250000  0.259060
# 17  0.340058  0.470588  0.750000  0.780768
# 18  0.051873  0.058824  0.083333  0.296735
# 19  0.556196  1.000000  1.000000  0.682095
# 20  0.265130  0.529412  0.250000  0.177252
# ...

# %%
def abc(x):
    print(type(x))
    print(x)

df0[['강간']].apply(abc)
# Out:
# <class 'pandas.core.series.Series'>
# 0     449
# 1     156
# 2     153
# 3     262
# 4     320
# 5     240
# 6     281
# 7     151
# 8     197
# 9     102
# 10    173
# 11    285
# 12    294
# 13    154
# 14    393
# 15    126
# 16    150
# 17    220
# 18    120
# 19    295
# 20    194
# 21    166
# 22    211
# 23    170
# 24    187
# Name: 강간, dtype: int64
# 강간    None
# dtype: object
