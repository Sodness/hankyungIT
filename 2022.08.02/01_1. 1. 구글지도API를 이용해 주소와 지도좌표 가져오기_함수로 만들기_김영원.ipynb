# %%
import googlemaps

gmaps_key = "AIzaSyBj6OzihwNo481ZAW94ldwLwaigqn1vvWc"    # 자신의 key를 사용합니다.
gmaps = googlemaps.Client(key=gmaps_key)                 # 구글maps Api 웹 서비스를 요청합니다.

def get_ggcode(text):
    tmp = gmaps.geocode(text, language='ko')             # 경복궁 지도 정보를 가져옵니다.
    addr = tmp[0]['formatted_address']
    lat = tmp[0]['geometry']['location']['lat']
    lng = tmp[0]['geometry']['location']['lng']
    
    return addr, lat, lng

# %%
get_ggcode('경복궁')
# Out:
# ('대한민국 서울특별시 종로구 사직로 161', 37.579617, 126.977041)

# %%
ls = ['서울시청', '부산시청', '대전시청', '인천시청']
for i in ls:
    print(get_ggcode(i))
# Out:
# ('대한민국 서울특별시', 37.566535, 126.9779692)
# ('대한민국 부산광역시 시청역', 35.179992, 129.076815)
# ('대한민국 대전광역시', 36.3504119, 127.3845475)
# ('대한민국 인천광역시 남동구 정각로 29', 37.4560897, 126.7059157)

# %%
import pandas as pd

# %%
df = pd.read_excel('./data/crime_2017_1.xls')
df.head()
# Out:
#       자치구  살인  강도  강제추생    절도    폭력
# 0   중부경찰서   7  10   253  1644  2143
# 1   중구경찰서   1   9   267  1846  2061
# 2  용산구경찰서   1   5   327  1346  2381
# 3  성동구경찰서   1   3   132  1072  1559
# 4  광진구경찰서   6  13   261  2220  2146

# %%
ls = ['서울시청', '인천시청', '부산시청']
주소 = [get_ggcode(i)[0] for i in ls]
위도 = [get_ggcode(i)[1] for i in ls]
경도 = [get_ggcode(i)[2] for i in ls]

# %%
print(주소)
print(위도)
print(경도)
# Out:
# ['대한민국 서울특별시', '대한민국 인천광역시 남동구 정각로 29', '대한민국 부산광역시 시청역']
# [37.566535, 37.4560897, 35.179992]
# [126.9779692, 126.7059157, 129.076815]

# %%
list(map(get_ggcode, ls))
# Out:
# [('대한민국 서울특별시', 37.566535, 126.9779692),
#  ('대한민국 인천광역시 남동구 정각로 29', 37.4560897, 126.7059157),
#  ('대한민국 부산광역시 시청역', 35.179992, 129.076815)]

# %%
df.head()
# Out:
#       자치구  살인  강도  강제추생    절도    폭력
# 0   중부경찰서   7  10   253  1644  2143
# 1   중구경찰서   1   9   267  1846  2061
# 2  용산구경찰서   1   5   327  1346  2381
# 3  성동구경찰서   1   3   132  1072  1559
# 4  광진구경찰서   6  13   261  2220  2146

# %%
df['자치구']
# Out:
# 0       중부경찰서
# 1       중구경찰서
# 2      용산구경찰서
# 3      성동구경찰서
# 4      광진구경찰서
# 5     동대문구경찰서
# 6      중랑구경찰서
# 7      성북구경찰서
# 8      강북구경찰서
# 9      도봉구경찰서
# 10     노원구경찰서
# 11     은평구경찰서
# 12    서대문구경찰서
# 13     마포구경찰서
# 14     양천구경찰서
# 15     강서구경찰서
# 16     구로구경찰서
# 17     금천구경찰서
# 18    영등포구경찰서
# 19     동작구경찰서
# 20     관악구경찰서
# 21     서초구경찰서
# 22     강남구경찰서
# 23     송파구경찰서
# 24     강동구경찰서
# Name: 자치구, dtype: object

# %%
주소 = []
위도 = []
경도 = []

for i in df['자치구']:
    주소.append(get_ggcode(i)[0])
    위도.append(get_ggcode(i)[1])
    경도.append(get_ggcode(i)[2])
주소
# Out:
# 중부경찰서
# 중구경찰서
# 용산구경찰서
# 성동구경찰서
# 광진구경찰서
# 동대문구경찰서
# 중랑구경찰서
# 성북구경찰서
# 강북구경찰서
# 도봉구경찰서
# 노원구경찰서
# 은평구경찰서
# 서대문구경찰서
# 마포구경찰서
# 양천구경찰서
# 강서구경찰서
# 구로구경찰서
# 금천구경찰서
# 영등포구경찰서
# 동작구경찰서
# 관악구경찰서
# 서초구경찰서
# 강남구경찰서
# 송파구경찰서
# 강동구경찰서
# []

# %%
df['주소'] = [get_ggcode(i)[0] for i in df['자치구']]
df.head()
# Out:
#         자치구  살인  강도  강제추생    절도    폭력                          주소
# 0     중부경찰서   7  10   253  1644  2143        대한민국 서울특별시 중구 수표로 27
# 1     중구경찰서   1   9   267  1846  2061        대한민국 서울특별시 중구 수표로 27
# 2    용산구경찰서   1   5   327  1346  2381              대한민국 서울특별시 용산구
# 3    성동구경찰서   1   3   132  1072  1559              대한민국 서울특별시 성동구
# 4    광진구경찰서   6  13   261  2220  2146              대한민국 서울특별시 광진구
# 5   동대문구경찰서  11   3   165  1547  2249  대한민국 서울특별시 동대문구 약령시로21길 29
# 6    중랑구경찰서   5   3   172  1533  2858              대한민국 서울특별시 중랑구
# 7    성북구경찰서   7   8   173  1344  1902              대한민국 서울특별시 성북구
# 8    강북구경찰서   8   7   208  1014  2156              대한민국 서울특별시 강북구
# 9    도봉구경찰서   1   3   104   633  1258              대한민국 서울특별시 도봉구
# 10   노원구경찰서   4   9   180  1538  2478              대한민국 서울특별시 노원구
# 11   은평구경찰서   6   4   230  1387  2256              대한민국 서울특별시 은평구
# 12  서대문구경찰서   4   1   202  1230  1676     대한민국 서울특별시 서대문구 통일로 113
# ...

# %%
df['위도'] = [get_ggcode(i)[1] for i in df['자치구']]
df['경도'] = [get_ggcode(i)[2] for i in df['자치구']]
df.head()
# Out:
#       자치구  살인  강도  강제추생    절도    폭력                    주소         위도  \
# 0   중부경찰서   7  10   253  1644  2143  대한민국 서울특별시 중구 수표로 27  37.563617
# 1   중구경찰서   1   9   267  1846  2061  대한민국 서울특별시 중구 수표로 27  37.563617
# 2  용산구경찰서   1   5   327  1346  2381        대한민국 서울특별시 용산구  37.538427
# 3  성동구경찰서   1   3   132  1072  1559        대한민국 서울특별시 성동구  37.563341
# 4  광진구경찰서   6  13   261  2220  2146        대한민국 서울특별시 광진구  37.538484
#
#            경도
# 0  126.989652
# 1  126.989652
# 2  126.965444
# 3  127.037103
# 4  127.082294

# %%
df['자치구'].map(get_ggcode)
# Out:
# 0     (대한민국 서울특별시 중구 수표로 27, 37.56361709999999, 126....
# 1     (대한민국 서울특별시 중구 수표로 27, 37.56361709999999, 126....
# 2             (대한민국 서울특별시 용산구, 37.5384272, 126.9654442)
# 3             (대한민국 서울특별시 성동구, 37.5633415, 127.0371025)
# 4             (대한민국 서울특별시 광진구, 37.5384843, 127.0822938)
# 5     (대한민국 서울특별시 동대문구 약령시로21길 29, 37.58506149999999...
# 6             (대한민국 서울특별시 중랑구, 37.6065602, 127.0926519)
# 7              (대한민국 서울특별시 성북구, 37.589116, 127.0182146)
# 8             (대한민국 서울특별시 강북구, 37.6396099, 127.0256575)
# 9             (대한민국 서울특별시 도봉구, 37.6687738, 127.0470706)
# 10             (대한민국 서울특별시 노원구, 37.6541917, 127.056793)
# 11            (대한민국 서울특별시 은평구, 37.6026957, 126.9291119)
# 12    (대한민국 서울특별시 서대문구 통일로 113, 37.5647439, 126.9667...
# 13            (대한민국 서울특별시 마포구, 37.5637561, 126.9084211)
# 14            (대한민국 서울특별시 양천구, 37.5168721, 126.8663985)
# 15            (대한민국 서울특별시 강서구, 37.5509786, 126.8495382)
# 16             (대한민국 서울특별시 구로구, 37.4954031, 126.887369)
# ...

# %%
df['자치구'].map(get_ggcode).str[0]
# Out:
# 0           대한민국 서울특별시 중구 수표로 27
# 1           대한민국 서울특별시 중구 수표로 27
# 2                 대한민국 서울특별시 용산구
# 3                 대한민국 서울특별시 성동구
# 4                 대한민국 서울특별시 광진구
# 5     대한민국 서울특별시 동대문구 약령시로21길 29
# 6                 대한민국 서울특별시 중랑구
# 7                 대한민국 서울특별시 성북구
# 8                 대한민국 서울특별시 강북구
# 9                 대한민국 서울특별시 도봉구
# 10                대한민국 서울특별시 노원구
# 11                대한민국 서울특별시 은평구
# 12       대한민국 서울특별시 서대문구 통일로 113
# 13                대한민국 서울특별시 마포구
# 14                대한민국 서울특별시 양천구
# 15                대한민국 서울특별시 강서구
# 16                대한민국 서울특별시 구로구
# 17                대한민국 서울특별시 금천구
# 18      대한민국 서울특별시 영등포구 국회대로 608
# 19                대한민국 서울특별시 동작구
# 20                대한민국 서울특별시 관악구
# 21                대한민국 서울특별시 서초구
# 22                대한민국 서울특별시 강남구
# 23                대한민국 서울특별시 송파구
# 24                대한민국 서울특별시 강동구
# Name: 자치구, dtype: object
