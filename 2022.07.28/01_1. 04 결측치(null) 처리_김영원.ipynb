# %%
import pandas as pd

# %%
df = pd.read_csv('./data/korean-idol.csv')
df1 = df
df1.head()
# Out:
#      이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0    지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 1  지드래곤     빅뱅   YG  남자  1988-08-18  177.0   A   9916947
# 2  강다니엘    NaN  커넥트  남자  1996-12-10  180.0   A   8273745
# 3     뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 4    화사    마마무  RBW  여자  1995-07-23  162.1   A   7650928

# %%
df1.shape
# Out:
# (15, 8)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   이름       15 non-null     object
#  1   그룹       14 non-null     object
#  2   소속사      15 non-null     object
#  3   성별       15 non-null     object
#  4   생년월일     15 non-null     object
#  5   키        13 non-null     float64
#  6   혈액형      15 non-null     object
#  7   브랜드평판지수  15 non-null     int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.1+ KB

# %%
df1.isnull()
# Out:
#        이름     그룹    소속사     성별   생년월일      키    혈액형  브랜드평판지수
# 0   False  False  False  False  False  False  False    False
# 1   False  False  False  False  False  False  False    False
# 2   False   True  False  False  False  False  False    False
# 3   False  False  False  False  False  False  False    False
# 4   False  False  False  False  False  False  False    False
# 5   False  False  False  False  False  False  False    False
# 6   False  False  False  False  False  False  False    False
# 7   False  False  False  False  False   True  False    False
# 8   False  False  False  False  False  False  False    False
# 9   False  False  False  False  False  False  False    False
# 10  False  False  False  False  False   True  False    False
# 11  False  False  False  False  False  False  False    False
# 12  False  False  False  False  False  False  False    False
# 13  False  False  False  False  False  False  False    False
# ...

# %%
df1.isnull().sum()
# Out:
# 이름         0
# 그룹         1
# 소속사        0
# 성별         0
# 생년월일       0
# 키          2
# 혈액형        0
# 브랜드평판지수    0
# dtype: int64

# %%
df1['키'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# Name: 키, dtype: bool

# %%
df1[df1['키'].isnull()]
# Out:
#     이름    그룹 소속사  성별        생년월일   키 혈액형  브랜드평판지수
# 7   소연   아이들  큐브  여자  1998-08-26 NaN   B  4668615
# 10  태연  소녀시대  SM  여자  1989-03-09 NaN   A  3918661

# %%
df1[df1['그룹'].isnull()]
# Out:
#      이름   그룹  소속사  성별        생년월일      키 혈액형  브랜드평판지수
# 2  강다니엘  NaN  커넥트  남자  1996-12-10  180.0   A  8273745

# %%
df1[df1['키'].notnull()]
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# 14    슈가  방탄소년단      빅히트  남자  1993-03-09  174.0   O   2925442

# %%
df1.isnull().sum()
# Out:
# 이름         0
# 그룹         1
# 소속사        0
# 성별         0
# 생년월일       0
# 키          2
# 혈액형        0
# 브랜드평판지수    0
# dtype: int64

# %%
len(df1)
# Out:
# 15

# %%
df1.isnull().sum() / len(df1) * 100
# Out:
# 이름          0.000000
# 그룹          6.666667
# 소속사         0.000000
# 성별          0.000000
# 생년월일        0.000000
# 키          13.333333
# 혈액형         0.000000
# 브랜드평판지수     0.000000
# dtype: float64

# %%
import matplotlib.pyplot as plt
import os
import seaborn as sns
if os.name == 'nt':
    font_family = "Malgun Gothic"
else:
    font_family = "AppleGothic"
    
sns.set(font=font_family, rc={"axes.unicode_minus" : False })

# %%
(df1.isnull().sum() / len(df1) * 100).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
(df1.isnull().sum() / len(df1) * 100).plot(kind='bar')
plt.ylim(0, 100)
# Out:
# (0.0, 100.0)

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
df0 = df1.set_index('이름')
df0
# Out:
#          그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 이름
# 지민    방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 뷔     방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 화사      마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 정국    방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 민현     뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 소연      아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 진     방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 하성운      핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 태연     소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 차은우    아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 백호     뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# JR     뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# 슈가    방탄소년단      빅히트  남자  1993-03-09  174.0   O   2925442

# %%
sns.heatmap(df0.isnull())
# Out:
# <AxesSubplot:ylabel='이름'>

# %%
# !pip install missingno
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import missingno as msno

msno.matrix(df0)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df0)
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(df0)
# Out:
# <AxesSubplot:>

# %%
df0.isnull().any()
# Out:
# 그룹          True
# 소속사        False
# 성별         False
# 생년월일       False
# 키           True
# 혈액형        False
# 브랜드평판지수    False
# dtype: bool

# %%
df0[df0.isnull().any(axis=1)]
# Out:
#         그룹  소속사  성별        생년월일      키 혈액형  브랜드평판지수
# 이름
# 강다니엘   NaN  커넥트  남자  1996-12-10  180.0   A  8273745
# 소연     아이들   큐브  여자  1998-08-26    NaN   B  4668615
# 태연    소녀시대   SM  여자  1989-03-09    NaN   A  3918661

# %%
df0[df0['키'].isnull()]
# Out:
#       그룹 소속사  성별        생년월일   키 혈액형  브랜드평판지수
# 이름
# 소연   아이들  큐브  여자  1998-08-26 NaN   B  4668615
# 태연  소녀시대  SM  여자  1989-03-09 NaN   A  3918661

# %%
df0.dropna()
# Out:
#          그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 이름
# 지민    방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 뷔     방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 화사      마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 정국    방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 민현     뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 진     방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 하성운      핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 차은우    아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 백호     뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# JR     뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# 슈가    방탄소년단      빅히트  남자  1993-03-09  174.0   O   2925442

# %%
df0
# Out:
#          그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 이름
# 지민    방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 뷔     방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 화사      마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 정국    방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 민현     뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 소연      아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 진     방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 하성운      핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 태연     소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 차은우    아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 백호     뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# JR     뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# 슈가    방탄소년단      빅히트  남자  1993-03-09  174.0   O   2925442

# %%
res = [None if i=='빅뱅' or i=='뉴이스트' else i for i in df0['그룹'] ]
res
# Out:
# ['방탄소년단',
#  None,
#  nan,
#  '방탄소년단',
#  '마마무',
#  '방탄소년단',
#  None,
#  '아이들',
#  '방탄소년단',
#  '핫샷',
#  '소녀시대',
#  '아스트로',
#  None,
#  None,
#  '방탄소년단']

# %%
df0['삭제여부'] = res
df0
# Out:
#          그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수   삭제여부
# 이름
# 지민    방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260  방탄소년단
# 지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947   None
# 강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745    NaN
# 뷔     방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501  방탄소년단
# 화사      마마무      RBW  여자  1995-07-23  162.1   A   7650928    마마무
# 정국    방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335  방탄소년단
# 민현     뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792   None
# 소연      아이들       큐브  여자  1998-08-26    NaN   B   4668615    아이들
# 진     방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308  방탄소년단
# 하성운      핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489     핫샷
# 태연     소녀시대       SM  여자  1989-03-09    NaN   A   3918661   소녀시대
# 차은우    아스트로     판타지오  남자  1997-03-30  183.0   B   3506027   아스트로
# 백호     뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654   None
# ...

# %%
res=[]
s=['빅뱅','뉴이스트']
for i in df['그룹']:
    try:
        if i in s:
            res.append(None)
        else:
            res.append(i)
    except:
        res.append(None)
res
# Out:
# ['방탄소년단',
#  None,
#  nan,
#  '방탄소년단',
#  '마마무',
#  '방탄소년단',
#  None,
#  '아이들',
#  '방탄소년단',
#  '핫샷',
#  '소녀시대',
#  '아스트로',
#  None,
#  None,
#  '방탄소년단']

# %%
df0.dropna()
# Out:
#         그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수   삭제여부
# 이름
# 지민   방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260  방탄소년단
# 뷔    방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501  방탄소년단
# 화사     마마무      RBW  여자  1995-07-23  162.1   A   7650928    마마무
# 정국   방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335  방탄소년단
# 진    방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308  방탄소년단
# 하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489     핫샷
# 차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027   아스트로
# 슈가   방탄소년단      빅히트  남자  1993-03-09  174.0   O   2925442  방탄소년단

# %%
df1
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df0 = df1.set_index('이름')
df0
# Out:
#          그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 이름
# 지민    방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 뷔     방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 화사      마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 정국    방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 민현     뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 소연      아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 진     방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 하성운      핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 태연     소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 차은우    아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 백호     뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# JR     뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# 슈가    방탄소년단      빅히트  남자  1993-03-09  174.0   O   2925442

# %%
df0['그룹'] == '방탄소년단'
# Out:
# 이름
# 지민       True
# 지드래곤    False
# 강다니엘    False
# 뷔        True
# 화사      False
# 정국       True
# 민현      False
# 소연      False
# 진        True
# 하성운     False
# 태연      False
# 차은우     False
# 백호      False
# JR      False
# 슈가       True
# Name: 그룹, dtype: bool

# %%
df0['그룹'].isin(['방탄소년단', '뉴이스트', '마마무'])
# Out:
# 이름
# 지민       True
# 지드래곤    False
# 강다니엘    False
# 뷔        True
# 화사       True
# 정국       True
# 민현       True
# 소연      False
# 진        True
# 하성운     False
# 태연      False
# 차은우     False
# 백호       True
# JR       True
# 슈가       True
# Name: 그룹, dtype: bool

# %%
df0[df0['그룹'].isin(['방탄소년단', '뉴이스트', '마마무'])]
# Out:
#        그룹   소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 이름
# 지민  방탄소년단   빅히트  남자  1995-10-13  173.6   A  10523260
# 뷔   방탄소년단   빅히트  남자  1995-12-30  178.0  AB   8073501
# 화사    마마무   RBW  여자  1995-07-23  162.1   A   7650928
# 정국  방탄소년단   빅히트  남자  1997-09-01  178.0   A   5208335
# 민현   뉴이스트  플레디스  남자  1995-08-09  182.3   O   4989792
# 진   방탄소년단   빅히트  남자  1992-12-04  179.2   O   4570308
# 백호   뉴이스트  플레디스  남자  1995-07-21  175.0  AB   3301654
# JR   뉴이스트  플레디스  남자  1995-06-08  176.0   O   3274137
# 슈가  방탄소년단   빅히트  남자  1993-03-09  174.0   O   2925442

# %%
cond1 = df0['그룹']=='방탄소년단'
cond2 = df0['그룹']=='뉴이스트'
cond3 = df0['그룹']=='마마무'
df0[cond1 | cond2 | cond3]
# Out:
#        그룹   소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 이름
# 지민  방탄소년단   빅히트  남자  1995-10-13  173.6   A  10523260
# 뷔   방탄소년단   빅히트  남자  1995-12-30  178.0  AB   8073501
# 화사    마마무   RBW  여자  1995-07-23  162.1   A   7650928
# 정국  방탄소년단   빅히트  남자  1997-09-01  178.0   A   5208335
# 민현   뉴이스트  플레디스  남자  1995-08-09  182.3   O   4989792
# 진   방탄소년단   빅히트  남자  1992-12-04  179.2   O   4570308
# 백호   뉴이스트  플레디스  남자  1995-07-21  175.0  AB   3301654
# JR   뉴이스트  플레디스  남자  1995-06-08  176.0   O   3274137
# 슈가  방탄소년단   빅히트  남자  1993-03-09  174.0   O   2925442

# %%
(df0['키'] >= 180) | (df0['키'] <= 170)
# Out:
# 이름
# 지민      False
# 지드래곤    False
# 강다니엘     True
# 뷔       False
# 화사       True
# 정국      False
# 민현       True
# 소연      False
# 진       False
# 하성운      True
# 태연      False
# 차은우      True
# 백호      False
# JR      False
# 슈가      False
# Name: 키, dtype: bool

# %%
df0[(df0['키'] >= 180) | (df0['키'] <= 170)]
# Out:
#         그룹      소속사  성별        생년월일      키 혈액형  브랜드평판지수
# 이름
# 강다니엘   NaN      커넥트  남자  1996-12-10  180.0   A  8273745
# 화사     마마무      RBW  여자  1995-07-23  162.1   A  7650928
# 민현    뉴이스트     플레디스  남자  1995-08-09  182.3   O  4989792
# 하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A  4036489
# 차은우   아스트로     판타지오  남자  1997-03-30  183.0   B  3506027

# %%
df0 = df.copy()
df0
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df0.fillna(0)
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘      0      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    0.0   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    0.0   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df0.fillna(df0.mean())
# Out:
# C:\Users\hjk70\AppData\Local\Temp\ipykernel_12916\1302409635.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df0.fillna(df0.mean())
#       이름     그룹      소속사  성별        생년월일           키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.600000   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.000000   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.000000   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.000000  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.100000   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.000000   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.300000   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26  175.792308   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.200000   O   4570308
# ...

# %%
# 위의 문자로 채운다
df0.fillna(method='ffill')
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘     빅뱅      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26  182.3   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09  167.1   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df1 = df0.fillna(df0.mean())
df1
# Out:
# C:\Users\hjk70\AppData\Local\Temp\ipykernel_12916\1659642435.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1 = df0.fillna(df0.mean())
#       이름     그룹      소속사  성별        생년월일           키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.600000   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.000000   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.000000   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.000000  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.100000   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.000000   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.300000   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26  175.792308   B   4668615
# ...

# %%
df0.describe()
# Out:
#                 키       브랜드평판지수
# count   13.000000  1.500000e+01
# mean   175.792308  5.655856e+06
# std      5.820576  2.539068e+06
# min    162.100000  2.925442e+06
# 25%    174.000000  3.712344e+06
# 50%    177.000000  4.668615e+06
# 75%    179.200000  7.862214e+06
# max    183.000000  1.052326e+07

# %%
df1['그룹'].fillna(method='ffill')
# Out:
# 0     방탄소년단
# 1        빅뱅
# 2        빅뱅
# 3     방탄소년단
# 4       마마무
# 5     방탄소년단
# 6      뉴이스트
# 7       아이들
# 8     방탄소년단
# 9        핫샷
# 10     소녀시대
# 11     아스트로
# 12     뉴이스트
# 13     뉴이스트
# 14    방탄소년단
# Name: 그룹, dtype: object

# %%
df1['그룹'] = df1['그룹'].fillna(method='ffill')
df1
# Out:
#       이름     그룹      소속사  성별        생년월일           키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.600000   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.000000   A   9916947
# 2   강다니엘     빅뱅      커넥트  남자  1996-12-10  180.000000   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.000000  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.100000   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.000000   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.300000   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26  175.792308   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.200000   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.100000   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09  175.792308   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.000000   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.000000  AB   3301654
# ...

# %%
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df1 = df

# %%
df1
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df1['그룹'].value_counts()
# Out:
# 방탄소년단    5
# 뉴이스트     3
# 빅뱅       1
# 마마무      1
# 아이들      1
# 핫샷       1
# 소녀시대     1
# 아스트로     1
# Name: 그룹, dtype: int64

# %%
df1['그룹'].value_counts().sort_values(ascending=False)
# Out:
# 방탄소년단    5
# 뉴이스트     3
# 빅뱅       1
# 마마무      1
# 아이들      1
# 핫샷       1
# 소녀시대     1
# 아스트로     1
# Name: 그룹, dtype: int64

# %%
df1['그룹'].isnull() =
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# Name: 그룹, dtype: bool

# %%
tmp = df1['그룹'].value_counts().sort_values(ascending=False)
tmp
# Out:
# 방탄소년단    5
# 뉴이스트     3
# 빅뱅       1
# 마마무      1
# 아이들      1
# 핫샷       1
# 소녀시대     1
# 아스트로     1
# Name: 그룹, dtype: int64

# %%
tmp.index[0]
# Out:
# '방탄소년단'

# %%
df1['그룹'].fillna('방탄소년단')
df1['그룹'] = df1['그룹'].fillna(tmp.index[0])
df1
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘  방탄소년단      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df = pd.read_csv('./data/korean-idol.csv')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df = pd.read_csv('./data/korean-idol.csv')
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df1 = df.copy()

# %%
df1
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
tmp = df1[0:1]
tmp
# Out:
#    이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0  지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260

# %%
tmp.loc[0,['그룹', '소속사', '성별']]
# Out:
# 그룹     방탄소년단
# 소속사      빅히트
# 성별        남자
# Name: 0, dtype: object

# %%
tmp.loc[0,['그룹', '소속사', '성별']] = None
tmp
# Out:
#    이름    그룹   소속사    성별        생년월일      키 혈액형   브랜드평판지수
# 0  지민  None  None  None  1995-10-13  173.6   A  10523260

# %%
pd.concat([df1, tmp])
# Out:
#       이름     그룹      소속사    성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민   None     None  None  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG    남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트    남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트    남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW    여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트    남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스    남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브    여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트    남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티    남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM    여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오    남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스    남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스    남자  1995-06-08  176.0   O   3274137
# ...

# %%
df=pd.read_csv('./data/korean-idol.csv')

temp=df[0:1]

temp.loc[0,['그룹','소속사','성별']]=None

temp

df1=pd.concat([df,temp])
df1
# Out:
#       이름     그룹      소속사    성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민   None     None  None  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG    남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트    남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트    남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW    여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트    남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스    남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브    여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트    남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티    남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM    여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오    남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스    남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스    남자  1995-06-08  176.0   O   3274137
# ...

# %%
tmp = df1['그룹'].value_counts().index[0]
tmp
# Out:
# '방탄소년단'

# %%
df1['그룹'].fillna('방탄소년단')
# Out:
# 0     방탄소년단
# 1        빅뱅
# 2     방탄소년단
# 3     방탄소년단
# 4       마마무
# 5     방탄소년단
# 6      뉴이스트
# 7       아이들
# 8     방탄소년단
# 9        핫샷
# 10     소녀시대
# 11     아스트로
# 12     뉴이스트
# 13     뉴이스트
# 14    방탄소년단
# 0     방탄소년단
# Name: 그룹, dtype: object

# %%
df1['그룹'] = df1['그룹'].fillna('방탄소년단')
df1
# Out:
#       이름     그룹      소속사    성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단     None  None  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG    남자  1988-08-18  177.0   A   9916947
# 2   강다니엘  방탄소년단      커넥트    남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트    남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW    여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트    남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스    남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브    여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트    남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티    남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM    여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오    남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스    남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스    남자  1995-06-08  176.0   O   3274137
# ...

# %%
cols = ['그룹', '소속사', '성별']
for col in cols:
    tmp = df1[col].value_counts().index[0]
    df1[col] = df1[col].fillna(tmp)
df1
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘  방탄소년단      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df1 = df.copy()
df1
# Out:
#       이름     그룹      소속사    성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민   None     None  None  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG    남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트    남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트    남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW    여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트    남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스    남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브    여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트    남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티    남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM    여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오    남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스    남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스    남자  1995-06-08  176.0   O   3274137
# ...

# %%
df1.dtypes
# Out:
# 이름          object
# 그룹          object
# 소속사         object
# 성별          object
# 생년월일        object
# 키          float64
# 혈액형         object
# 브랜드평판지수      int64
# dtype: object

# %%
df1
# Out:
#       이름     그룹      소속사    성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민   None     None  None  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG    남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트    남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트    남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW    여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트    남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스    남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브    여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트    남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티    남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM    여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오    남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스    남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스    남자  1995-06-08  176.0   O   3274137
# ...

# %%
res = []
name = df1.columns
name_null = name[df1.isnull().any()]

for i in name_null:
    if df1[i].dtypes=='object':
        res.append(i)

for i in res:
    freq = df1[i].value_counts().index[0]
    df1[i] = df1[i].fillna(freq)
    
df1
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘  방탄소년단      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
# 이미 fillna()가 있어서 이것만 해도 됨
res = []
for i in name_null:
    if df1[i].dtypes=='object':
        res.append(i)

for i in res:
    freq = df1[i].value_counts().index[0]
    df1[i] = df1[i].fillna(freq)
    
df1
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘  방탄소년단      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df1 = df.copy()
df1
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
(df1.dtypes == 'float64') | (df1.dtypes == 'int64')
# Out:
# 이름         False
# 그룹         False
# 소속사        False
# 성별         False
# 생년월일       False
# 키           True
# 혈액형        False
# 브랜드평판지수     True
# dtype: bool

# %%
tmp = df1.dtypes.isin(['float64','int64'])
tmp
# Out:
# 이름         False
# 그룹         False
# 소속사        False
# 성별         False
# 생년월일       False
# 키           True
# 혈액형        False
# 브랜드평판지수    False
# dtype: bool

# %%
tmp = df1.dtypes.isin(['int64'])
tmp
# Out:
# 이름         False
# 그룹         False
# 소속사        False
# 성별         False
# 생년월일       False
# 키          False
# 혈액형        False
# 브랜드평판지수    False
# dtype: bool

# %%
df1.loc[:,tmp]
# Out:
#         키
# 0   173.6
# 1   177.0
# 2   180.0
# 3   178.0
# 4   162.1
# 5   178.0
# 6   182.3
# 7     NaN
# 8   179.2
# 9   167.1
# 10    NaN
# 11  183.0
# 12  175.0
# 13  176.0
# 14  174.0

# %%
df1.dtypes
# Out:
# 이름          object
# 그룹          object
# 소속사         object
# 성별          object
# 생년월일        object
# 키          float64
# 혈액형         object
# 브랜드평판지수      int64
# dtype: object

# %%
print(df1.dtypes)
# Out:
# 이름          object
# 그룹          object
# 소속사         object
# 성별          object
# 생년월일        object
# 키          float64
# 혈액형         object
# 브랜드평판지수      int64
# dtype: object

# %%
df1.dtypes == 'int64'
# Out:
# 이름         False
# 그룹         False
# 소속사        False
# 성별         False
# 생년월일       False
# 키          False
# 혈액형        False
# 브랜드평판지수     True
# dtype: bool

# %%
df1.dtypes.isin(['int64'])
# Out:
# 이름         False
# 그룹         False
# 소속사        False
# 성별         False
# 생년월일       False
# 키          False
# 혈액형        False
# 브랜드평판지수    False
# dtype: bool

# %%
df1.dtypes == 'float64'
# Out:
# 이름         False
# 그룹         False
# 소속사        False
# 성별         False
# 생년월일       False
# 키           True
# 혈액형        False
# 브랜드평판지수    False
# dtype: bool

# %%
df1.dtypes.isin(['float64'])
# Out:
# 이름         False
# 그룹         False
# 소속사        False
# 성별         False
# 생년월일       False
# 키           True
# 혈액형        False
# 브랜드평판지수    False
# dtype: bool

# %%
df1.head()
# Out:
#      이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0    지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 1  지드래곤     빅뱅   YG  남자  1988-08-18  177.0   A   9916947
# 2  강다니엘    NaN  커넥트  남자  1996-12-10  180.0   A   8273745
# 3     뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 4    화사    마마무  RBW  여자  1995-07-23  162.1   A   7650928

# %%
df1.dtypes.isin(['float64', 'int64'])
# Out:
# 이름         False
# 그룹         False
# 소속사        False
# 성별         False
# 생년월일       False
# 키           True
# 혈액형        False
# 브랜드평판지수    False
# dtype: bool
