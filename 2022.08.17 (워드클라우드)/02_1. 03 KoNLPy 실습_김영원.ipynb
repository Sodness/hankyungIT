# %%
from konlpy.tag import Okt,Kkma,Hannanum
import re
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# 유니코드에서  음수 부호설정
plt.rc('axes', unicode_minus=False)

# %%
txt = '''
대한민국(大韓民國, 영어: Republic of Korea, ROK), 약칭 남한(南韓, 영어: South Korea), 한국(韓國)은 동아시아의 한반도 남부에 자리한 민주공화국이다. 대한민국의 국기는 대한민국 국기법에 따라 태극기[3], 국가는 관습상 애국가[4], 국화는 관습상 무궁화이다. 공용어는 한국어와 한국 수어이다. 수도는 서울이다. 인구는 약 5,160만명으로, 전체 인구 중 절반 정도(약 2611만명)가 수도권에 살고 있다.[5]

대한민국은 1948년 5월 10일 총선거를 통해 제헌국회를 구성하였고, 1948년 8월 15일 대한민국 정부를 수립하였다. 1948년 제헌 국회에서 대한민국의 국호를 계승하여 헌법에 명시하였고, 다시 1950년 1월 16일 국무원 고시 제7호 ‘국호 및 일부 지방명과 지도색 사용에 관한 건’에 의해 확정하였다.

대한민국은 20세기 후반 이후 급격한 경제 성장을 이루었다. 그 과정에서 1990년대 말 외환 위기 등의 부침이 있기도 했다. 대한민국의 2022년 1인당 국민 총소득 (GNI)은 명목 3만 4,994달러이다.[6] 2020년 유엔개발계획 (UNDP)이 매년 발표하는 인간개발지수 (HDI) 조사에서 세계 22위를 기록하였다.[2] 2021년 7월 2일 스위스 제네바 본부에서 열린 ‘제68차 무역개발이사회’ 마지막 회의에서 한국의 지위를 선진국 그룹으로 ‘의견 일치’로 변경하고 선진국으로 인정했다.[7] 다만 높은 자살률, 장시간 근로 문화와 높은 산업 재해 사망률, 저출산 등의 사회 문제가 이 같은 성과와 병존하고 있다. 대한민국의 행정 구역

대한민국은 이코노미스트에서 발표하는 민주주의 지수 조사에서 2019년 기준 23위의 8.0점을 기록한 바와 같이 아시아에서 민주주의 수준이 가장 높은 국가 가운데 하나이다. 또한 대한민국은 주요 20개국 (G20), 경제 협력 개발 기구 (OECD), 개발 원조 위원회 (DAC), 파리 클럽 등의 회원국이다.[8]

1948년 이후로 오늘날까지 한반도에는 대한민국과 조선민주주의인민공화국이라는 두 개의 분단국가가 각각 남북에 위치하고 있다. 한반도와 부속도서의 면적은 약 22만 km2이며, 인구는 대한민국과 조선민주주의인민공화국을 합쳐 2019년을 기준으로 약 7,700만 명에 달한다[9].
'''

# %%
print(txt)
# Out:
# 대한민국(大韓民國, 영어: Republic of Korea, ROK), 약칭 남한(南韓, 영어: South Korea), 한국(韓國)은 동아시아의 한반도 남부에 자리한 민주공화국이다. 대한민국의 국기는 대한민국 국기법에 따라 태극기[3], 국가는 관습상 애국가[4], 국화는 관습상 무궁화이다. 공용어는 한국어와 한국 수어이다. 수도는 서울이다. 인구는 약 5,160만명으로, 전체 인구 중 절반 정도(약 2611만명)가 수도권에 살고 있다.[5]
#
# 대한민국은 1948년 5월 10일 총선거를 통해 제헌국회를 구성하였고, 1948년 8월 15일 대한민국 정부를 수립하였다. 1948년 제헌 국회에서 대한민국의 국호를 계승하여 헌법에 명시하였고, 다시 1950년 1월 16일 국무원 고시 제7호 ‘국호 및 일부 지방명과 지도색 사용에 관한 건’에 의해 확정하였다.
#
# 대한민국은 20세기 후반 이후 급격한 경제 성장을 이루었다. 그 과정에서 1990년대 말 외환 위기 등의 부침이 있기도 했다. 대한민국의 2022년 1인당 국민 총소득 (GNI)은 명목 3만 4,994달러이다.[6] 2020년 유엔개발계획 (UNDP)이 매년 발표하는 인간개발지수 (HDI) 조사에서 세계 22위를 기록하였다.[2] 2021년 7월 2일 스위스 제네바 본부에서 열린 ‘제68차 무역개발이사회’ 마지막 회의에서 한국의 지위를 선진국 그룹으로 ‘의견 일치’로 변경하고 선진국으로 인정했다.[7] 다만 높은 자살률, 장시간 근로 문화와 높은 산업 재해 사망률, 저출산 등의 사회 문제가 이 같은 성과와 병존하고 있다. 대한민국의 행정 구역
#
# 대한민국은 이코노미스트에서 발표하는 민주주의 지수 조사에서 2019년 기준 23위의 8.0점을 기록한 바와 같이 아시아에서 민주주의 수준이 가장 높은 국가 가운데 하나이다. 또한 대한민국은 주요 20개국 (G20), 경제 협력 개발 기구 (OECD), 개발 원조 위원회 (DAC), 파리 클럽 등의 회원국이다.[8]
#
# 1948년 이후로 오늘날까지 한반도에는 대한민국과 조선민주주의인민공화국이라는 두 개의 분단국가가 각각 남북에 위치하고 있다. 한반도와 부속도서의 면적은 약 22만 km2이며, 인구는 대한민국과 조선민주주의인민공화국을 합쳐 2019년을 기준으로 약 7,700만 명에 달한다[9].

# %%
mask = re.compile('\(.+?\)|\[.+?\]')
# mask.findall(txt)
txt1 = mask.sub('', txt)

# %%
txt1
# Out:
# '\n대한민국, 약칭 남한, 한국은 동아시아의 한반도 남부에 자리한 민주공화국이다. 대한민국의 국기는 대한민국 국기법에 따라 태극기, 국가는 관습상 애국가, 국화는 관습상 무궁화이다. 공용어는 한국어와 한국 수어이다. 수도는 서울이다. 인구는 약 5,160만명으로, 전체 인구 중 절반 정도가 수도권에 살고 있다.\n\n대한민국은 1948년 5월 10일 총선거를 통해 제헌국회를 구성하였고, 1948년 8월 15일 대한민국 정부를 수립하였다. 1948년 제헌 국회에서 대한민국의 국호를 계승하여 헌법에 명시하였고, 다시 1950년 1월 16일 국무원 고시 제7호 ‘국호 및 일부 지방명과 지도색 사용에 관한 건’에 의해 확정하였다.\n\n대한민국은 20세기 후반 이후 급격한 경제 성장을 이루었다. 그 과정에서 1990년대 말 외환 위기 등의 부침이 있기도 했다. 대한민국의 2022년 1인당 국민 총소득 은 명목 3만 4,994달러이다. 2020년 유엔개발계획 이 매년 발표하는 인간개발지수  조사에서 세계 22위를 기록하였다. 2021년 7월 2일 스위스 제네바 본부에서 열린 ‘제68차 무역개발이사회’ 마지막 회의에서 한국의 지위를 선진국 그룹으로 ‘의견 일치’로 변경하고 선진국으로 인정했다. 다만 높은 자살률, 장시간 근로 문화와 높은 산업 재해 사망률, 저출산 등의 사회 문제가 이 같은 성과와 병존하고 있다. 대한민국의 행정 구역\n\n대한민국은 이코노미스트에서 발표하는 민주주의 지수 조사에서 2019년 기준 23위의 8.0점을 기록한 바와 같이 아시아에서 민주주의 수준이 가장 높은 국가 가운데 하나이다. 또한 대한민국은 주요 20개국 , 경제 협력 개발 기구 , 개발 원조 위원회 , 파리 클럽 등의 회원국이다.\n\n1948년 이후로 오늘날까지 한반도에는 대한민국과 조선민주주의인민공화국이라는 두 개의 분단국가가 각각 남북에 위치하고 있다. 한반도와 부속도서의 면적은 약 22만 km2이며, 인구는 대한민국과 조선민주주의인민공화국을 합쳐 2019년을 기준으로 약 7,700만 명에 달한다.\n'

# %%
kkma_v
# Out:
# [('따르다', 'VV'),
#  ('가다', 'VV'),
#  ('살다', 'VV'),
#  ('통하다', 'VV'),
#  ('관하다', 'VV'),
#  ('의하다', 'VV'),
#  ('이루다', 'VV'),
#  ('있다', 'VV'),
#  ('하다', 'VV'),
#  ('열리다', 'VV'),
#  ('하다', 'VV'),
#  ('하다', 'VV'),
#  ('합치다', 'VV'),
#  ('달하다', 'VV')]

# %%
# %time
okt = Okt()
o_nouns = okt.nouns(txt)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
o_nouns
# Out:
# ['대한민국',
#  '영어',
#  '약칭',
#  '남한',
#  '영어',
#  '한국',
#  '은',
#  '동아시아',
#  '한반도',
#  '남부',
#  '자리',
#  '민주공화국',
#  '대한민국',
#  '국기',
#  '대한민국',
#  '국기법',
#  '태극기',
#  '국가',
#  '관습',
#  '애국가',
#  '국화',
#  '관습',
#  '무궁화',
#  '용어',
#  '한국어',
#  '한국',
#  '수어',
#  '수도',
#  '서울',
#  '인구',
#  '약',
#  '전체',
#  '인구',
#  '중',
#  '절반',
#  '정도',
#  '약',
#  '수도권',
#  '살',
#  '대한민국',
#  '총선거',
#  '통해',
#  '제헌국회',
#  '구성',
#  '대한민국',
#  '정부',
#  '수립',
#  '제헌',
#  '국회',
#  '대한민국',
#  '국호',
#  '계승',
#  '헌법',
#  '명시',
#  '다시',
#  '국무원',
#  '고시',
#  '제',
#  '호',
#  '국호',
#  '및',
#  '일부',
#  '지방',
#  '명과',
#  '도색',
#  '사용',
#  '관',
#  '건',
#  '확정',
#  '대한민국',
#  '세기',
#  '후반',
#  '이후',
#  '경제',
#  '성장',
#  '그',
#  '과정',
#  '말',
#  '외환',
#  '위기',
#  '등',
#  '대한민국',
#  '국민',
#  '소득',
#  '은',
#  '명목',
#  '유엔',
#  '개발',
#  '계획',
#  '이',
#  '매년',
#  '발표',
#  '인간',
#  '개발',
#  '지수',
#  '조사',
#  '세계',
#  '위',
#  '기록',
#  '스위스',
#  '제네바',
#  '본부',
#  '제',
#  '차',
#  '무역',
#  '개발',
#  '이사회',
#  '마지막',
#  '회의',
#  '한국',
#  '지위',
#  '선진국',
#  '그룹',
#  '의견',
#  '일치',
#  '로',
#  '변경',
#  '선진국',
#  '인정',
#  '다만',
#  '자살률',
#  '장시간',
#  '근로',
#  '문화',
#  '산업',
#  '재해',
#  '사망률',
#  '저출산',
#  '등',
#  '사회',
#  '문제',
#  '이',
#  '성과',
#  '병존',
#  '대한민국',
#  '행정',
#  '구역',
#  '대한민국',
#  '이코노미스트',
#  '발표',
#  '민주주의',
#  '지수',
#  '조사',
#  '기준',
#  '위',
#  '점',
#  '기록',
#  '바',
#  '아시아',
#  '민주주의',
#  '수준',
#  '가장',
#  '국가',
#  '가운데',
#  '하나',
#  '또한',
#  '대한민국',
#  '주요',
#  '개국',
#  '경제',
#  '협력',
#  '개발',
#  '기구',
#  '개발',
#  '원조',
#  '위원회',
#  '파리',
#  '클럽',
#  '등',
#  '회원',
#  '국',
#  '이후',
#  '오늘날',
#  '한반도',
#  '대한민국',
#  '조선',
#  '민주주의',
#  '인민공화국',
#  '두',
#  '개',
#  '분단국가',
#  '각각',
#  '남북',
#  '위치',
#  '한반도',
#  '부속',
#  '도서',
#  '면적',
#  '약',
#  '인구',
#  '대한민국',
#  '조선',
#  '민주주의',
#  '인민공화국',
#  '기준',
#  '약',
#  '명',
#  '달']

# %%
len(nouns)
# Out:
# 198

# %%
# %time
han = Hannanum()
h_nouns = han.nouns(txt)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
h_nouns
# Out:
# ['대한민국(大韓民國,',
#  '영어',
#  '약칭',
#  '남한(南韓,',
#  '영어',
#  '한국(韓國)',
#  '동아시아',
#  '한반',
#  '남부',
#  '자리한',
#  '민주공화국',
#  '대한민국',
#  '국기',
#  '대한민국',
#  '국기법',
#  '태극기[3],',
#  '국가',
#  '관습상',
#  '애국가[4],',
#  '국화',
#  '관습상',
#  '무궁화',
#  '공용어',
#  '한국어',
#  '한국',
#  '수어',
#  '수',
#  '서울',
#  '인구',
#  '약',
#  '5,160만명',
#  '전체',
#  '인구',
#  '중',
#  '절반',
#  '정도(약',
#  '2611만명',
#  '수도권',
#  '5',
#  '대한민국',
#  '1948년',
#  '5월',
#  '10',
#  '총선거',
#  '제헌국회',
#  '구성',
#  '1948년',
#  '8월',
#  '15일',
#  '대한민국',
#  '정부',
#  '수립',
#  '1948년',
#  '제헌',
#  '국회',
#  '대한민국',
#  '국호',
#  '계승',
#  '헌법',
#  '명시',
#  '1950년',
#  '1월',
#  '16일',
#  '국무원',
#  '고시',
#  '제7호',
#  '‘국호',
#  '일부',
#  '지방명',
#  '지도색',
#  '사용',
#  '건’',
#  '확정',
#  '대한민국',
#  '20세',
#  '후반',
#  '이후',
#  '급격',
#  '경제',
#  '성장',
#  '과정',
#  '1990년대',
#  '외환',
#  '위',
#  '등',
#  '대한민국',
#  '2022년',
#  '1인당',
#  '국민',
#  '총소득',
#  '명목',
#  '3',
#  '4,994달러',
#  '6',
#  '2020년',
#  '유엔개발계획',
#  '발표',
#  '인간개발지수',
#  '조사',
#  '세계',
#  '22위',
#  '기록',
#  '2',
#  '2021년',
#  '7월',
#  '2일',
#  '스위스',
#  '제네바',
#  '본부',
#  '‘제68차',
#  '무역개발이사회’',
#  '마지막',
#  '회의',
#  '한국의',
#  '지위',
#  '선진국',
#  '그룹',
#  '‘의견',
#  '일치’',
#  '변경',
#  '선진국',
#  '인정',
#  '7',
#  '자살률',
#  '장시간',
#  '근',
#  '문화',
#  '산업',
#  '사망률',
#  '저출산',
#  '등',
#  '사회',
#  '문제',
#  '성과',
#  '병존',
#  '대한민국',
#  '행정',
#  '구역',
#  '대한민국',
#  '이코노미스트',
#  '발표',
#  '민주주의',
#  '지수',
#  '조사',
#  '2019년',
#  '기준',
#  '23위',
#  '8.0점',
#  '기록',
#  '바',
#  '아시아',
#  '민주주의',
#  '수준',
#  '국',
#  '가운데',
#  '하나',
#  '대한민국',
#  '주요',
#  '20개국',
#  '(G20),',
#  '경제',
#  '협력',
#  '개발',
#  '기구',
#  '개발',
#  '원조',
#  '위원회',
#  '파리',
#  '클럽',
#  '등',
#  '회원국',
#  '8',
#  '1948년',
#  '이후',
#  '오늘날',
#  '한반도',
#  '대한민국',
#  '조선민주주의인민공화국',
#  '두',
#  '개',
#  '분단국가',
#  '남북',
#  '위치',
#  '한반도',
#  '부속도서',
#  '면적',
#  '약',
#  '22',
#  'km2이며,',
#  '인구',
#  '대한민국',
#  '조선민주주의인민공화국',
#  '2019년',
#  '기준',
#  '약',
#  '7,700',
#  '명',
#  '달한다[9]']

# %%
# %time
kkma = Kkma()
k_nouns = kkma.nouns(txt)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
k_nouns
# Out:
# ['대한',
#  '대한민국',
#  '민국',
#  '영어',
#  '약칭',
#  '남한',
#  '한국',
#  '은',
#  '동아시아',
#  '한반도',
#  '남부',
#  '자리',
#  '민주',
#  '민주공화국',
#  '공화국',
#  '국기',
#  '국',
#  '국기법',
#  '기법',
#  '태극기',
#  '3',
#  '국가',
#  '관습',
#  '애',
#  '애국가',
#  '4',
#  '국화',
#  '관습상',
#  '상',
#  '무궁화',
#  '공용어',
#  '한국어',
#  '수어',
#  '수도',
#  '서울',
#  '인구',
#  '5,160',
#  '5,160만명',
#  '만',
#  '명',
#  '전체',
#  '중',
#  '절반',
#  '정도',
#  '약',
#  '2611',
#  '2611만명',
#  '수도권',
#  '5',
#  '1948',
#  '1948년',
#  '년',
#  '5월',
#  '월',
#  '10',
#  '10일',
#  '일',
#  '총선거',
#  '제헌',
#  '제헌국회',
#  '국회',
#  '구성',
#  '8',
#  '8월',
#  '15',
#  '15일',
#  '정부',
#  '수립',
#  '국호',
#  '계승',
#  '헌법',
#  '명시',
#  '1950',
#  '1950년',
#  '1',
#  '1월',
#  '16',
#  '16일',
#  '국무원',
#  '고시',
#  '제',
#  '제7호',
#  '7',
#  '호',
#  '호',
#  '일부',
#  '지방',
#  '지방명과',
#  '명과',
#  '지도',
#  '지도색',
#  '색',
#  '사용',
#  '건',
#  '확정',
#  '20',
#  '20세기',
#  '세기',
#  '후반',
#  '이후',
#  '급격',
#  '경제',
#  '성장',
#  '과정',
#  '1990',
#  '1990년대',
#  '년대',
#  '말',
#  '외환',
#  '위기',
#  '등',
#  '부침',
#  '2022',
#  '2022년',
#  '1인',
#  '인',
#  '국민',
#  '총소득',
#  '명목',
#  '3만',
#  '4,994',
#  '4,994달러',
#  '달러',
#  '6',
#  '2020',
#  '2020년',
#  '유엔',
#  '유엔개발계획',
#  '개발',
#  '계획',
#  '이',
#  '발표',
#  '인간',
#  '인간개발지수',
#  '지수',
#  '조사',
#  '세계',
#  '22',
#  '22위',
#  '위',
#  '기록',
#  '2',
#  '2021',
#  '2021년',
#  '7월',
#  '2일',
#  '스위스',
#  '제네바',
#  '본부',
#  '저',
#  '68',
#  '68차',
#  '차',
#  '무역',
#  '무역개발이사회',
#  '이사회',
#  '마지막',
#  '회의',
#  '지위',
#  '선진국',
#  '그룹',
#  '의견',
#  '일치',
#  '로',
#  '변경',
#  '인정',
#  '자살률',
#  '장시간',
#  '근로',
#  '문화',
#  '산업',
#  '재해',
#  '사망률',
#  '저출산',
#  '사회',
#  '문제',
#  '이',
#  '성과',
#  '병존',
#  '행정',
#  '구역',
#  '이코노',
#  '이코노미스트',
#  '미스트',
#  '민주주의',
#  '주의',
#  '2019',
#  '2019년',
#  '기준',
#  '23',
#  '23위의',
#  '위의',
#  '8.0',
#  '8.0점',
#  '점',
#  '바',
#  '아시아',
#  '수준',
#  '가운데',
#  '주요',
#  '20개국',
#  '개국',
#  '협력',
#  '기구',
#  '원조',
#  '위원회',
#  '파리',
#  '클럽',
#  '회원국',
#  '오늘날',
#  '조선',
#  '인민',
#  '조선민주주의',
#  '개',
#  '분단',
#  '분단국가',
#  '남북',
#  '위치',
#  '부',
#  '부속도서의',
#  '속도',
#  '서의',
#  '면적',
#  '22만',
#  '조선민주주의인민공화국',
#  '7,700',
#  '7,700만',
#  '9']

# %%
okt.nouns(txt)    # 명사
okt.pos(txt)      # 형태소 분석
okt.tagset        # 형태소 분류 설명
okt.morphs(txt)   # 종류 구분 없이 다 뽑는거

# %%
okt.pos(txt)
# Out:
# [('\n', 'Foreign'),
#  ('대한민국', 'Noun'),
#  ('(', 'Punctuation'),
#  ('大韓民國', 'Foreign'),
#  (',', 'Punctuation'),
#  ('영어', 'Noun'),
#  (':', 'Punctuation'),
#  ('Republic', 'Alpha'),
#  ('of', 'Alpha'),
#  ('Korea', 'Alpha'),
#  (',', 'Punctuation'),
#  ('ROK', 'Alpha'),
#  ('),', 'Punctuation'),
#  ('약칭', 'Noun'),
#  ('남한', 'Noun'),
#  ('(', 'Punctuation'),
#  ('南韓', 'Foreign'),
#  (',', 'Punctuation'),
#  ('영어', 'Noun'),
#  (':', 'Punctuation'),
#  ('South', 'Alpha'),
#  ('Korea', 'Alpha'),
#  ('),', 'Punctuation'),
#  ('한국', 'Noun'),
#  ('(', 'Punctuation'),
#  ('韓國', 'Foreign'),
#  (')', 'Punctuation'),
#  ('은', 'Noun'),
#  ('동아시아', 'Noun'),
#  ('의', 'Josa'),
#  ('한반도', 'Noun'),
#  ('남부', 'Noun'),
#  ('에', 'Josa'),
#  ('자리', 'Noun'),
#  ('한', 'Josa'),
#  ('민주공화국', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('대한민국', 'Noun'),
#  ('의', 'Josa'),
#  ('국기', 'Noun'),
#  ('는', 'Josa'),
#  ('대한민국', 'Noun'),
#  ('국기법', 'Noun'),
#  ('에', 'Josa'),
#  ('따라', 'Verb'),
#  ('태극기', 'Noun'),
#  ('[', 'Punctuation'),
#  ('3', 'Number'),
#  ('],', 'Punctuation'),
#  ('국가', 'Noun'),
#  ('는', 'Josa'),
#  ('관습', 'Noun'),
#  ('상', 'Suffix'),
#  ('애국가', 'Noun'),
#  ('[', 'Punctuation'),
#  ('4', 'Number'),
#  ('],', 'Punctuation'),
#  ('국화', 'Noun'),
#  ('는', 'Josa'),
#  ('관습', 'Noun'),
#  ('상', 'Suffix'),
#  ('무궁화', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('공', 'Modifier'),
#  ('용어', 'Noun'),
#  ('는', 'Josa'),
#  ('한국어', 'Noun'),
#  ('와', 'Josa'),
#  ('한국', 'Noun'),
#  ('수어', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('수도', 'Noun'),
#  ('는', 'Josa'),
#  ('서울', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('인구', 'Noun'),
#  ('는', 'Josa'),
#  ('약', 'Noun'),
#  ('5,160만', 'Number'),
#  ('명으로', 'Foreign'),
#  (',', 'Punctuation'),
#  ('전체', 'Noun'),
#  ('인구', 'Noun'),
#  ('중', 'Noun'),
#  ('절반', 'Noun'),
#  ('정도', 'Noun'),
#  ('(', 'Punctuation'),
#  ('약', 'Noun'),
#  ('2611만', 'Number'),
#  ('명', 'Foreign'),
#  (')', 'Punctuation'),
#  ('가', 'Verb'),
#  ('수도권', 'Noun'),
#  ('에', 'Josa'),
#  ('살', 'Noun'),
#  ('고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('.[', 'Punctuation'),
#  ('5', 'Number'),
#  (']', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('대한민국', 'Noun'),
#  ('은', 'Josa'),
#  ('1948년', 'Number'),
#  ('5월', 'Number'),
#  ('10일', 'Number'),
#  ('총선거', 'Noun'),
#  ('를', 'Josa'),
#  ('통해', 'Noun'),
#  ('제헌국회', 'Noun'),
#  ('를', 'Josa'),
#  ('구성', 'Noun'),
#  ('하였고', 'Verb'),
#  (',', 'Punctuation'),
#  ('1948년', 'Number'),
#  ('8월', 'Number'),
#  ('15일', 'Number'),
#  ('대한민국', 'Noun'),
#  ('정부', 'Noun'),
#  ('를', 'Josa'),
#  ('수립', 'Noun'),
#  ('하였다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('1948년', 'Number'),
#  ('제헌', 'Noun'),
#  ('국회', 'Noun'),
#  ('에서', 'Josa'),
#  ('대한민국', 'Noun'),
#  ('의', 'Josa'),
#  ('국호', 'Noun'),
#  ('를', 'Josa'),
#  ('계승', 'Noun'),
#  ('하여', 'Verb'),
#  ('헌법', 'Noun'),
#  ('에', 'Josa'),
#  ('명시', 'Noun'),
#  ('하였고', 'Verb'),
#  (',', 'Punctuation'),
#  ('다시', 'Noun'),
#  ('1950년', 'Number'),
#  ('1월', 'Number'),
#  ('16일', 'Number'),
#  ('국무원', 'Noun'),
#  ('고시', 'Noun'),
#  ('제', 'Noun'),
#  ('7', 'Number'),
#  ('호', 'Noun'),
#  ('‘', 'Foreign'),
#  ('국호', 'Noun'),
#  ('및', 'Noun'),
#  ('일부', 'Noun'),
#  ('지방', 'Noun'),
#  ('명과', 'Noun'),
#  ('지', 'Modifier'),
#  ('도색', 'Noun'),
#  ('사용', 'Noun'),
#  ('에', 'Josa'),
#  ('관', 'Noun'),
#  ('한', 'Josa'),
#  ('건', 'Noun'),
#  ('’', 'Punctuation'),
#  ('에', 'Josa'),
#  ('의해', 'Adjective'),
#  ('확정', 'Noun'),
#  ('하였다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('대한민국', 'Noun'),
#  ('은', 'Josa'),
#  ('20', 'Number'),
#  ('세기', 'Noun'),
#  ('후반', 'Noun'),
#  ('이후', 'Noun'),
#  ('급격한', 'Adjective'),
#  ('경제', 'Noun'),
#  ('성장', 'Noun'),
#  ('을', 'Josa'),
#  ('이루었다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('그', 'Noun'),
#  ('과정', 'Noun'),
#  ('에서', 'Josa'),
#  ('1990년', 'Number'),
#  ('대', 'Foreign'),
#  ('말', 'Noun'),
#  ('외환', 'Noun'),
#  ('위기', 'Noun'),
#  ('등', 'Noun'),
#  ('의', 'Josa'),
#  ('부침이', 'Verb'),
#  ('있기도', 'Adjective'),
#  ('했다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('대한민국', 'Noun'),
#  ('의', 'Josa'),
#  ('2022년', 'Number'),
#  ('1', 'Number'),
#  ('인당', 'Verb'),
#  ('국민', 'Noun'),
#  ('총', 'Modifier'),
#  ('소득', 'Noun'),
#  ('(', 'Punctuation'),
#  ('GNI', 'Alpha'),
#  (')', 'Punctuation'),
#  ('은', 'Noun'),
#  ('명목', 'Noun'),
#  ('3만', 'Number'),
#  ('4,994달러', 'Number'),
#  ('이다', 'Foreign'),
#  ('.[', 'Punctuation'),
#  ('6', 'Number'),
#  (']', 'Punctuation'),
#  ('2020년', 'Number'),
#  ('유엔', 'Noun'),
#  ('개발', 'Noun'),
#  ('계획', 'Noun'),
#  ('(', 'Punctuation'),
#  ('UNDP', 'Alpha'),
#  (')', 'Punctuation'),
#  ('이', 'Noun'),
#  ('매년', 'Noun'),
#  ('발표', 'Noun'),
#  ('하는', 'Verb'),
#  ('인간', 'Noun'),
#  ('개발', 'Noun'),
#  ('지수', 'Noun'),
#  ('(', 'Punctuation'),
#  ('HDI', 'Alpha'),
#  (')', 'Punctuation'),
#  ('조사', 'Noun'),
#  ('에서', 'Josa'),
#  ('세계', 'Noun'),
#  ('22', 'Number'),
#  ('위', 'Noun'),
#  ('를', 'Josa'),
#  ('기록', 'Noun'),
#  ('하였다', 'Verb'),
#  ('.[', 'Punctuation'),
#  ('2', 'Number'),
#  (']', 'Punctuation'),
#  ('2021년', 'Number'),
#  ('7월', 'Number'),
#  ('2일', 'Number'),
#  ('스위스', 'Noun'),
#  ('제네바', 'Noun'),
#  ('본부', 'Noun'),
#  ('에서', 'Josa'),
#  ('열린', 'Verb'),
#  ('‘', 'Foreign'),
#  ('제', 'Noun'),
#  ('68', 'Number'),
#  ('차', 'Noun'),
#  ('무역', 'Noun'),
#  ('개발', 'Noun'),
#  ('이사회', 'Noun'),
#  ('’', 'Punctuation'),
#  ('마지막', 'Noun'),
#  ('회의', 'Noun'),
#  ('에서', 'Josa'),
#  ('한국', 'Noun'),
#  ('의', 'Josa'),
#  ('지위', 'Noun'),
#  ('를', 'Josa'),
#  ('선진국', 'Noun'),
#  ('그룹', 'Noun'),
#  ('으로', 'Josa'),
#  ('‘', 'Foreign'),
#  ('의견', 'Noun'),
#  ('일치', 'Noun'),
#  ('’', 'Punctuation'),
#  ('로', 'Noun'),
#  ('변경', 'Noun'),
#  ('하고', 'Josa'),
#  ('선진국', 'Noun'),
#  ('으로', 'Josa'),
#  ('인정', 'Noun'),
#  ('했다', 'Verb'),
#  ('.[', 'Punctuation'),
#  ('7', 'Number'),
#  (']', 'Punctuation'),
#  ('다만', 'Noun'),
#  ('높은', 'Adjective'),
#  ('자살률', 'Noun'),
#  (',', 'Punctuation'),
#  ('장시간', 'Noun'),
#  ('근로', 'Noun'),
#  ('문화', 'Noun'),
#  ('와', 'Josa'),
#  ('높은', 'Adjective'),
#  ('산업', 'Noun'),
#  ('재해', 'Noun'),
#  ('사망률', 'Noun'),
#  (',', 'Punctuation'),
#  ('저출산', 'Noun'),
#  ('등', 'Noun'),
#  ('의', 'Josa'),
#  ('사회', 'Noun'),
#  ('문제', 'Noun'),
#  ('가', 'Josa'),
#  ('이', 'Noun'),
#  ('같은', 'Adjective'),
#  ('성과', 'Noun'),
#  ('와', 'Josa'),
#  ('병존', 'Noun'),
#  ('하고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('대한민국', 'Noun'),
#  ('의', 'Josa'),
#  ('행정', 'Noun'),
#  ('구역', 'Noun'),
#  ('\n\n', 'Foreign'),
#  ('대한민국', 'Noun'),
#  ('은', 'Josa'),
#  ('이코노미스트', 'Noun'),
#  ('에서', 'Josa'),
#  ('발표', 'Noun'),
#  ('하는', 'Verb'),
#  ('민주주의', 'Noun'),
#  ('지수', 'Noun'),
#  ('조사', 'Noun'),
#  ('에서', 'Josa'),
#  ('2019년', 'Number'),
#  ('기준', 'Noun'),
#  ('23', 'Number'),
#  ('위', 'Noun'),
#  ('의', 'Josa'),
#  ('8.0', 'Number'),
#  ('점', 'Noun'),
#  ('을', 'Josa'),
#  ('기록', 'Noun'),
#  ('한', 'Josa'),
#  ('바', 'Noun'),
#  ('와', 'Josa'),
#  ('같이', 'Adverb'),
#  ('아시아', 'Noun'),
#  ('에서', 'Josa'),
#  ('민주주의', 'Noun'),
#  ('수준', 'Noun'),
#  ('이', 'Josa'),
#  ('가장', 'Noun'),
#  ('높은', 'Adjective'),
#  ('국가', 'Noun'),
#  ('가운데', 'Noun'),
#  ('하나', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('또한', 'Noun'),
#  ('대한민국', 'Noun'),
#  ('은', 'Josa'),
#  ('주요', 'Noun'),
#  ('20', 'Number'),
#  ('개국', 'Noun'),
#  ('(', 'Punctuation'),
#  ('G', 'Alpha'),
#  ('20', 'Number'),
#  ('),', 'Punctuation'),
#  ('경제', 'Noun'),
#  ('협력', 'Noun'),
#  ('개발', 'Noun'),
#  ('기구', 'Noun'),
#  ('(', 'Punctuation'),
#  ('OECD', 'Alpha'),
#  ('),', 'Punctuation'),
#  ('개발', 'Noun'),
#  ('원조', 'Noun'),
#  ('위원회', 'Noun'),
#  ('(', 'Punctuation'),
#  ('DAC', 'Alpha'),
#  ('),', 'Punctuation'),
#  ('파리', 'Noun'),
#  ('클럽', 'Noun'),
#  ('등', 'Noun'),
#  ('의', 'Josa'),
#  ('회원', 'Noun'),
#  ('국', 'Noun'),
#  ('이다', 'Josa'),
#  ('.[', 'Punctuation'),
#  ('8', 'Number'),
#  (']', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('1948년', 'Number'),
#  ('이후', 'Noun'),
#  ('로', 'Josa'),
#  ('오늘날', 'Noun'),
#  ('까지', 'Josa'),
#  ('한반도', 'Noun'),
#  ('에는', 'Josa'),
#  ('대한민국', 'Noun'),
#  ('과', 'Josa'),
#  ('조선', 'Noun'),
#  ('민주주의', 'Noun'),
#  ('인민공화국', 'Noun'),
#  ('이라는', 'Josa'),
#  ('두', 'Noun'),
#  ('개', 'Noun'),
#  ('의', 'Josa'),
#  ('분단국가', 'Noun'),
#  ('가', 'Josa'),
#  ('각각', 'Noun'),
#  ('남북', 'Noun'),
#  ('에', 'Josa'),
#  ('위치', 'Noun'),
#  ('하고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('한반도', 'Noun'),
#  ('와', 'Josa'),
#  ('부속', 'Noun'),
#  ('도서', 'Noun'),
#  ('의', 'Josa'),
#  ('면적', 'Noun'),
#  ('은', 'Josa'),
#  ('약', 'Noun'),
#  ('22만', 'Number'),
#  ('km', 'Alpha'),
#  ('2', 'Number'),
#  ('이며', 'Josa'),
#  (',', 'Punctuation'),
#  ('인구', 'Noun'),
#  ('는', 'Josa'),
#  ('대한민국', 'Noun'),
#  ('과', 'Josa'),
#  ('조선', 'Noun'),
#  ('민주주의', 'Noun'),
#  ('인민공화국', 'Noun'),
#  ('을', 'Josa'),
#  ('합쳐', 'Verb'),
#  ('2019년', 'Number'),
#  ('을', 'Foreign'),
#  ('기준', 'Noun'),
#  ('으로', 'Josa'),
#  ('약', 'Noun'),
#  ('7,700만', 'Number'),
#  ('명', 'Noun'),
#  ('에', 'Josa'),
#  ('달', 'Noun'),
#  ('한', 'Josa'),
#  ('다', 'Adverb'),
#  ('[', 'Punctuation'),
#  ('9', 'Number'),
#  ('].', 'Punctuation'),
#  ('\n', 'Foreign')]

# %%
kkma.pos(txt)
# Out:
# [('대한민국', 'NNG'),
#  ('(', 'SS'),
#  ('大韓民國', 'OH'),
#  (',', 'SP'),
#  ('영어', 'NNG'),
#  (':', 'SP'),
#  ('Republic', 'OL'),
#  ('of', 'OL'),
#  ('Korea', 'OL'),
#  (',', 'SP'),
#  ('ROK', 'OL'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('약칭', 'NNG'),
#  ('남한', 'NNG'),
#  ('(', 'SS'),
#  ('南韓', 'OH'),
#  (',', 'SP'),
#  ('영어', 'NNG'),
#  (':', 'SP'),
#  ('South', 'OL'),
#  ('Korea', 'OL'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('한국', 'NNG'),
#  ('(', 'SS'),
#  ('韓國', 'OH'),
#  (')', 'SS'),
#  ('은', 'NNG'),
#  ('동아시아', 'NNP'),
#  ('의', 'JKG'),
#  ('한반도', 'NNG'),
#  ('남부', 'NNG'),
#  ('에', 'JKM'),
#  ('자리', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('민주', 'NNG'),
#  ('공화국', 'NNG'),
#  ('이', 'VCP'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('대한민국', 'NNG'),
#  ('의', 'JKG'),
#  ('국기', 'NNG'),
#  ('는', 'JX'),
#  ('대한민국', 'NNG'),
#  ('국', 'NNG'),
#  ('기법', 'NNG'),
#  ('에', 'JKM'),
#  ('따르', 'VV'),
#  ('아', 'ECS'),
#  ('태극기', 'NNG'),
#  ('[', 'SS'),
#  ('3', 'NR'),
#  (']', 'SS'),
#  (',', 'SP'),
#  ('국가', 'NNG'),
#  ('는', 'JX'),
#  ('관습', 'NNG'),
#  ('상', 'XSN'),
#  ('애', 'NNG'),
#  ('국가', 'NNG'),
#  ('[', 'SS'),
#  ('4', 'NR'),
#  (']', 'SS'),
#  (',', 'SP'),
#  ('국화', 'NNG'),
#  ('는', 'JX'),
#  ('관습', 'NNG'),
#  ('상', 'NNG'),
#  ('무궁화', 'NNG'),
#  ('이', 'VCP'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('공용어', 'NNG'),
#  ('는', 'JX'),
#  ('한국어', 'NNG'),
#  ('와', 'JKM'),
#  ('한국', 'NNG'),
#  ('수어', 'NNG'),
#  ('이', 'VCP'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('수도', 'NNG'),
#  ('는', 'JX'),
#  ('서울', 'NNG'),
#  ('이', 'VCP'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('인구', 'NNG'),
#  ('는', 'JX'),
#  ('약', 'MDN'),
#  ('5,160', 'NR'),
#  ('만', 'NR'),
#  ('명', 'NNM'),
#  ('으로', 'JKM'),
#  (',', 'SP'),
#  ('전체', 'NNG'),
#  ('인구', 'NNG'),
#  ('중', 'NNB'),
#  ('절반', 'NNG'),
#  ('정도', 'NNG'),
#  ('(', 'SS'),
#  ('약', 'NNG'),
#  ('2611', 'NR'),
#  ('만', 'NR'),
#  ('명', 'NNM'),
#  (')', 'SS'),
#  ('가', 'VV'),
#  ('아', 'ECS'),
#  ('수도권', 'NNG'),
#  ('에', 'JKM'),
#  ('살', 'VV'),
#  ('고', 'ECE'),
#  ('있', 'VXV'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('[', 'SS'),
#  ('5', 'NR'),
#  (']', 'SS'),
#  ('대한민국', 'NNG'),
#  ('은', 'JX'),
#  ('1948', 'NR'),
#  ('년', 'NNM'),
#  ('5', 'NR'),
#  ('월', 'NNM'),
#  ('10', 'NR'),
#  ('일', 'NNM'),
#  ('총선거', 'NNG'),
#  ('를', 'JKO'),
#  ('통하', 'VV'),
#  ('어', 'ECS'),
#  ('제헌', 'NNG'),
#  ('국회', 'NNG'),
#  ('를', 'JKO'),
#  ('구성', 'NNG'),
#  ('하', 'XSV'),
#  ('였', 'EPT'),
#  ('고', 'ECE'),
#  (',', 'SP'),
#  ('1948', 'NR'),
#  ('년', 'NNM'),
#  ('8', 'NR'),
#  ('월', 'NNM'),
#  ('15', 'NR'),
#  ('일', 'NNM'),
#  ('대한민국', 'NNG'),
#  ('정부', 'NNG'),
#  ('를', 'JKO'),
#  ('수립', 'NNG'),
#  ('하', 'XSV'),
#  ('였', 'EPT'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('1948', 'NR'),
#  ('년', 'NNM'),
#  ('제헌', 'NNG'),
#  ('국회', 'NNG'),
#  ('에서', 'JKM'),
#  ('대한민국', 'NNG'),
#  ('의', 'JKG'),
#  ('국호', 'NNG'),
#  ('를', 'JKO'),
#  ('계승', 'NNG'),
#  ('하', 'XSV'),
#  ('여', 'ECS'),
#  ('헌법', 'NNG'),
#  ('에', 'JKM'),
#  ('명시', 'NNG'),
#  ('하', 'XSV'),
#  ('였', 'EPT'),
#  ('고', 'ECE'),
#  (',', 'SP'),
#  ('다시', 'MAG'),
#  ('1950', 'NR'),
#  ('년', 'NNM'),
#  ('1', 'NR'),
#  ('월', 'NNM'),
#  ('16', 'NR'),
#  ('일', 'NNM'),
#  ('국무원', 'NNG'),
#  ('고시', 'NNG'),
#  ('제', 'NNG'),
#  ('7', 'NR'),
#  ('호', 'NNM'),
#  ('‘', 'SS'),
#  ('국', 'NNG'),
#  ('호', 'NNG'),
#  ('및', 'MAG'),
#  ('일부', 'NNG'),
#  ('지방', 'NNG'),
#  ('명과', 'NNG'),
#  ('지도', 'NNG'),
#  ('색', 'NNG'),
#  ('사용', 'NNG'),
#  ('에', 'JKM'),
#  ('관하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('건', 'NNG'),
#  ('’', 'SS'),
#  ('에', 'JKM'),
#  ('의하', 'VV'),
#  ('어', 'ECS'),
#  ('확정', 'NNG'),
#  ('하', 'XSV'),
#  ('였', 'EPT'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('대한민국', 'NNG'),
#  ('은', 'JX'),
#  ('20', 'NR'),
#  ('세기', 'NNG'),
#  ('후반', 'NNG'),
#  ('이후', 'NNG'),
#  ('급격', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('경제', 'NNG'),
#  ('성장', 'NNG'),
#  ('을', 'JKO'),
#  ('이루', 'VV'),
#  ('었', 'EPT'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('그', 'MDT'),
#  ('과정', 'NNG'),
#  ('에서', 'JKM'),
#  ('1990', 'NR'),
#  ('년대', 'NNM'),
#  ('말', 'NNG'),
#  ('외환', 'NNG'),
#  ('위기', 'NNG'),
#  ('등', 'NNB'),
#  ('의', 'JKG'),
#  ('부침', 'NNG'),
#  ('이', 'JKS'),
#  ('있', 'VV'),
#  ('기', 'ETN'),
#  ('도', 'JX'),
#  ('하', 'VV'),
#  ('었', 'EPT'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('대한민국', 'NNG'),
#  ('의', 'JKG'),
#  ('2022', 'NR'),
#  ('년', 'NNM'),
#  ('1', 'NR'),
#  ('인', 'NNG'),
#  ('당', 'XSN'),
#  ('국민', 'NNG'),
#  ('총소득', 'NNG'),
#  ('(', 'SS'),
#  ('GNI', 'OL'),
#  (')', 'SS'),
#  ('은', 'NNG'),
#  ('명목', 'NNG'),
#  ('3', 'NR'),
#  ('만', 'NR'),
#  ('4,994', 'NR'),
#  ('달러', 'NNM'),
#  ('이', 'VCP'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('[', 'SS'),
#  ('6', 'NR'),
#  (']', 'SS'),
#  ('2020', 'NR'),
#  ('년', 'NNM'),
#  ('유엔', 'NNG'),
#  ('개발', 'NNG'),
#  ('계획', 'NNG'),
#  ('(', 'SS'),
#  ('UNDP', 'OL'),
#  (')', 'SS'),
#  ('이', 'NNG'),
#  ('매년', 'MAG'),
#  ('발표', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETD'),
#  ('인간', 'NNG'),
#  ('개발', 'NNG'),
#  ('지수', 'NNG'),
#  ('(', 'SS'),
#  ('HDI', 'OL'),
#  (')', 'SS'),
#  ('조사', 'NNG'),
#  ('에서', 'JKM'),
#  ('세계', 'NNG'),
#  ('22', 'NR'),
#  ('위', 'NNM'),
#  ('를', 'JKO'),
#  ('기록', 'NNG'),
#  ('하', 'XSV'),
#  ('였', 'EPT'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('[', 'SS'),
#  ('2', 'NR'),
#  (']', 'SS'),
#  ('2021', 'NR'),
#  ('년', 'NNM'),
#  ('7', 'NR'),
#  ('월', 'NNM'),
#  ('2', 'NR'),
#  ('일', 'NNM'),
#  ('스위스', 'NNG'),
#  ('제네바', 'NNG'),
#  ('본부', 'NNG'),
#  ('에서', 'JKM'),
#  ('열리', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('‘', 'SS'),
#  ('저', 'NP'),
#  ('의', 'JKG'),
#  ('68', 'NR'),
#  ('차', 'NNM'),
#  ('무역', 'NNG'),
#  ('개발', 'NNG'),
#  ('이사회', 'NNG'),
#  ('’', 'SS'),
#  ('마지막', 'NNG'),
#  ('회의', 'NNG'),
#  ('에서', 'JKM'),
#  ('한국', 'NNG'),
#  ('의', 'JKG'),
#  ('지위', 'NNG'),
#  ('를', 'JKO'),
#  ('선진국', 'NNG'),
#  ('그룹', 'NNG'),
#  ('으로', 'JKM'),
#  ('‘', 'SS'),
#  ('의견', 'NNG'),
#  ('일치', 'NNG'),
#  ('’', 'SS'),
#  ('로', 'NNG'),
#  ('변경', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'ECE'),
#  ('선진국', 'NNG'),
#  ('으로', 'JKM'),
#  ('인정', 'NNG'),
#  ('하', 'XSV'),
#  ('었', 'EPT'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('[', 'SS'),
#  ('7', 'NR'),
#  (']', 'SS'),
#  ('다만', 'MAG'),
#  ('높', 'VA'),
#  ('은', 'ETD'),
#  ('자살률', 'NNG'),
#  (',', 'SP'),
#  ('장시간', 'NNG'),
#  ('근로', 'NNG'),
#  ('문화', 'NNG'),
#  ('와', 'JKM'),
#  ('높', 'VA'),
#  ('은', 'ETD'),
#  ('산업', 'NNG'),
#  ('재해', 'NNG'),
#  ('사망률', 'NNG'),
#  (',', 'SP'),
#  ('저출산', 'NNG'),
#  ('등', 'NNB'),
#  ('의', 'JKG'),
#  ('사회', 'NNG'),
#  ('문제', 'NNG'),
#  ('가', 'JKS'),
#  ('이', 'NP'),
#  ('같', 'VA'),
#  ('은', 'ETD'),
#  ('성과', 'NNG'),
#  ('와', 'JKM'),
#  ('병존', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'ECE'),
#  ('있', 'VXV'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('대한민국', 'NNG'),
#  ('의', 'JKG'),
#  ('행정', 'NNG'),
#  ('구역', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('은', 'JX'),
#  ('이코노', 'NNG'),
#  ('미스트', 'NNG'),
#  ('에서', 'JKM'),
#  ('발표', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETD'),
#  ('민주주의', 'NNG'),
#  ('지수', 'NNG'),
#  ('조사', 'NNG'),
#  ('에서', 'JKM'),
#  ('2019', 'NR'),
#  ('년', 'NNM'),
#  ('기준', 'NNG'),
#  ('23', 'NR'),
#  ('위의', 'NNG'),
#  ('8.0', 'NR'),
#  ('점', 'NNM'),
#  ('을', 'JKO'),
#  ('기록', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('바', 'NNB'),
#  ('와', 'JKM'),
#  ('같이', 'MAG'),
#  ('아시아', 'NNG'),
#  ('에서', 'JKM'),
#  ('민주주의', 'NNG'),
#  ('수준', 'NNG'),
#  ('이', 'JKS'),
#  ('가장', 'MAG'),
#  ('높', 'VA'),
#  ('은', 'ETD'),
#  ('국가', 'NNG'),
#  ('가운데', 'NNG'),
#  ('하', 'VV'),
#  ('나이다', 'EFN'),
#  ('.', 'SF'),
#  ('또', 'MAG'),
#  ('하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('대한민국', 'NNG'),
#  ('은', 'JX'),
#  ('주요', 'NNG'),
#  ('20', 'NR'),
#  ('개국', 'NNM'),
#  ('(', 'SS'),
#  ('G', 'OL'),
#  ('20', 'NR'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('경제', 'NNG'),
#  ('협력', 'NNG'),
#  ('개발', 'NNG'),
#  ('기구', 'NNG'),
#  ('(', 'SS'),
#  ('OECD', 'OL'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('개발', 'NNG'),
#  ('원조', 'NNG'),
#  ('위원회', 'NNG'),
#  ('(', 'SS'),
#  ('DAC', 'OL'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('파리', 'NNG'),
#  ('클럽', 'NNG'),
#  ('등', 'NNB'),
#  ('의', 'JKG'),
#  ('회원국', 'NNG'),
#  ('이', 'VCP'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('[', 'SS'),
#  ('8', 'NR'),
#  (']', 'SS'),
#  ('1948', 'NR'),
#  ('년', 'NNM'),
#  ('이후', 'NNG'),
#  ('로', 'JKM'),
#  ('오늘날', 'NNG'),
#  ('까지', 'JX'),
#  ('한반도', 'NNG'),
#  ('에', 'JKM'),
#  ('는', 'JX'),
#  ('대한민국', 'NNG'),
#  ('과', 'JKM'),
#  ('조선', 'NNG'),
#  ('민주주의', 'NNG'),
#  ('인민', 'NNG'),
#  ('공화국', 'NNG'),
#  ('이', 'VCP'),
#  ('라는', 'ETD'),
#  ('두', 'MDN'),
#  ('개', 'NNM'),
#  ('의', 'JKG'),
#  ('분단', 'NNG'),
#  ('국가', 'NNG'),
#  ('가', 'JKS'),
#  ('각각', 'MAG'),
#  ('남북', 'NNG'),
#  ('에', 'JKM'),
#  ('위치', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'ECE'),
#  ('있', 'VXV'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('한반도', 'NNG'),
#  ('와', 'JC'),
#  ('부', 'NNG'),
#  ('속도', 'NNG'),
#  ('서의', 'NNG'),
#  ('면적', 'NNG'),
#  ('은', 'JX'),
#  ('약', 'MDN'),
#  ('22', 'NR'),
#  ('만', 'NR'),
#  ('km', 'OL'),
#  ('2', 'NR'),
#  ('이', 'VCP'),
#  ('며', 'ECE'),
#  (',', 'SP'),
#  ('인구', 'NNG'),
#  ('는', 'JX'),
#  ('대한민국', 'NNG'),
#  ('과', 'JKM'),
#  ('조선', 'NNG'),
#  ('민주주의', 'NNG'),
#  ('인민', 'NNG'),
#  ('공화국', 'NNG'),
#  ('을', 'JKO'),
#  ('합치', 'VV'),
#  ('어', 'ECS'),
#  ('2019', 'NR'),
#  ('년', 'NNM'),
#  ('을', 'JKO'),
#  ('기준', 'NNG'),
#  ('으로', 'JKM'),
#  ('약', 'NNG'),
#  ('7,700', 'NR'),
#  ('만', 'NR'),
#  ('명', 'NNM'),
#  ('에', 'JKM'),
#  ('달하', 'VV'),
#  ('ㄴ다', 'ECS'),
#  ('[', 'SS'),
#  ('9', 'NR'),
#  (']', 'SS'),
#  ('.', 'SF')]

# %%
han.pos(txt)
# Out:
# [('대한민국(大韓民國,', 'N'),
#  ('영어', 'N'),
#  (':', 'S'),
#  ('Republic', 'F'),
#  ('of', 'F'),
#  ('Korea', 'F'),
#  (',', 'S'),
#  ('ROK', 'F'),
#  ('),', 'S'),
#  ('약칭', 'N'),
#  ('남한(南韓,', 'N'),
#  ('영어', 'N'),
#  (':', 'S'),
#  ('South', 'F'),
#  ('Korea', 'F'),
#  ('),', 'S'),
#  ('한국(韓國)', 'N'),
#  ('은', 'J'),
#  ('동아시아', 'N'),
#  ('의', 'J'),
#  ('한반', 'N'),
#  ('도', 'J'),
#  ('남부', 'N'),
#  ('에', 'J'),
#  ('자리한', 'N'),
#  ('민주공화국', 'N'),
#  ('이', 'J'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('대한민국', 'N'),
#  ('의', 'J'),
#  ('국기', 'N'),
#  ('는', 'J'),
#  ('대한민국', 'N'),
#  ('국기법', 'N'),
#  ('에', 'J'),
#  ('따르', 'P'),
#  ('아', 'E'),
#  ('태극기[3],', 'N'),
#  ('국가', 'N'),
#  ('는', 'J'),
#  ('관습상', 'N'),
#  ('애국가[4],', 'N'),
#  ('국화', 'N'),
#  ('는', 'J'),
#  ('관습상', 'N'),
#  ('무궁화', 'N'),
#  ('이', 'J'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('공용어', 'N'),
#  ('는', 'J'),
#  ('한국어', 'N'),
#  ('와', 'J'),
#  ('한국', 'N'),
#  ('수어', 'N'),
#  ('이', 'J'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('수', 'N'),
#  ('도는', 'J'),
#  ('서울', 'N'),
#  ('이', 'J'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('인구', 'N'),
#  ('는', 'J'),
#  ('약', 'N'),
#  ('5,160만명', 'N'),
#  ('으로', 'J'),
#  (',', 'S'),
#  ('전체', 'N'),
#  ('인구', 'N'),
#  ('중', 'N'),
#  ('절반', 'N'),
#  ('정도(약', 'N'),
#  ('2611만명', 'N'),
#  (')', 'S'),
#  ('가', 'J'),
#  ('수도권', 'N'),
#  ('에', 'J'),
#  ('살', 'P'),
#  ('고', 'E'),
#  ('있', 'P'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('5', 'N'),
#  (']', 'S'),
#  ('대한민국', 'N'),
#  ('은', 'J'),
#  ('1948년', 'N'),
#  ('5월', 'N'),
#  ('10', 'N'),
#  ('이', 'J'),
#  ('ㄹ', 'E'),
#  ('총선거', 'N'),
#  ('를', 'J'),
#  ('통하', 'P'),
#  ('어', 'E'),
#  ('제헌국회', 'N'),
#  ('를', 'J'),
#  ('구성', 'N'),
#  ('하', 'X'),
#  ('었고', 'E'),
#  (',', 'S'),
#  ('1948년', 'N'),
#  ('8월', 'N'),
#  ('15일', 'N'),
#  ('대한민국', 'N'),
#  ('정부', 'N'),
#  ('를', 'J'),
#  ('수립', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('1948년', 'N'),
#  ('제헌', 'N'),
#  ('국회', 'N'),
#  ('에서', 'J'),
#  ('대한민국', 'N'),
#  ('의', 'J'),
#  ('국호', 'N'),
#  ('를', 'J'),
#  ('계승', 'N'),
#  ('하', 'X'),
#  ('어', 'E'),
#  ('헌법', 'N'),
#  ('에', 'J'),
#  ('명시', 'N'),
#  ('하', 'X'),
#  ('었고', 'E'),
#  (',', 'S'),
#  ('다시', 'M'),
#  ('1950년', 'N'),
#  ('1월', 'N'),
#  ('16일', 'N'),
#  ('국무원', 'N'),
#  ('고시', 'N'),
#  ('제7호', 'N'),
#  ('‘국호', 'N'),
#  ('및', 'M'),
#  ('일부', 'N'),
#  ('지방명', 'N'),
#  ('과', 'J'),
#  ('지도색', 'N'),
#  ('사용', 'N'),
#  ('에', 'J'),
#  ('관하', 'P'),
#  ('ㄴ', 'E'),
#  ('건’', 'N'),
#  ('에', 'J'),
#  ('의하', 'P'),
#  ('어', 'E'),
#  ('확정', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('대한민국', 'N'),
#  ('은', 'J'),
#  ('20세', 'N'),
#  ('이', 'J'),
#  ('기', 'E'),
#  ('후반', 'N'),
#  ('이후', 'N'),
#  ('급격', 'N'),
#  ('하', 'X'),
#  ('ㄴ', 'E'),
#  ('경제', 'N'),
#  ('성장', 'N'),
#  ('을', 'J'),
#  ('이루', 'P'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('그', 'M'),
#  ('과정', 'N'),
#  ('에서', 'J'),
#  ('1990년대', 'N'),
#  ('말', 'P'),
#  ('ㄹ', 'E'),
#  ('외환', 'N'),
#  ('위', 'N'),
#  ('이', 'J'),
#  ('기', 'E'),
#  ('등', 'N'),
#  ('의', 'J'),
#  ('부치', 'P'),
#  ('ㅁ', 'E'),
#  ('이', 'J'),
#  ('있', 'P'),
#  ('기', 'E'),
#  ('도', 'J'),
#  ('하', 'P'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('대한민국', 'N'),
#  ('의', 'J'),
#  ('2022년', 'N'),
#  ('1인당', 'N'),
#  ('국민', 'N'),
#  ('총소득', 'N'),
#  ('(', 'S'),
#  ('GNI', 'F'),
#  (')', 'S'),
#  ('은', 'J'),
#  ('명목', 'N'),
#  ('3', 'N'),
#  ('만', 'J'),
#  ('4,994달러', 'N'),
#  ('이', 'J'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('6', 'N'),
#  (']', 'S'),
#  ('2020년', 'N'),
#  ('유엔개발계획', 'N'),
#  ('(', 'S'),
#  ('UNDP', 'F'),
#  (')', 'S'),
#  ('이', 'J'),
#  ('매년', 'M'),
#  ('발표', 'N'),
#  ('하', 'X'),
#  ('는', 'E'),
#  ('인간개발지수', 'N'),
#  ('(', 'S'),
#  ('HDI', 'F'),
#  (')', 'S'),
#  ('조사', 'N'),
#  ('에서', 'J'),
#  ('세계', 'N'),
#  ('22위', 'N'),
#  ('를', 'J'),
#  ('기록', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('2', 'N'),
#  (']', 'S'),
#  ('2021년', 'N'),
#  ('7월', 'N'),
#  ('2일', 'N'),
#  ('스위스', 'N'),
#  ('제네바', 'N'),
#  ('본부', 'N'),
#  ('에서', 'J'),
#  ('열리', 'P'),
#  ('ㄴ', 'E'),
#  ('‘제68차', 'N'),
#  ('무역개발이사회’', 'N'),
#  ('마지막', 'N'),
#  ('회의', 'N'),
#  ('에서', 'J'),
#  ('한국의', 'N'),
#  ('지위', 'N'),
#  ('를', 'J'),
#  ('선진국', 'N'),
#  ('그룹', 'N'),
#  ('으로', 'J'),
#  ('‘의견', 'N'),
#  ('일치’', 'N'),
#  ('로', 'J'),
#  ('변경', 'N'),
#  ('하고', 'J'),
#  ('선진국', 'N'),
#  ('으로', 'J'),
#  ('인정', 'N'),
#  ('하', 'X'),
#  ('었다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('7', 'N'),
#  (']', 'S'),
#  ('다만', 'M'),
#  ('높', 'P'),
#  ('은', 'E'),
#  ('자살률', 'N'),
#  (',', 'S'),
#  ('장시간', 'N'),
#  ('근', 'N'),
#  ('로', 'J'),
#  ('문화', 'N'),
#  ('와', 'J'),
#  ('높', 'P'),
#  ('은', 'E'),
#  ('산업', 'N'),
#  ('재', 'P'),
#  ('어', 'E'),
#  ('하', 'P'),
#  ('어', 'E'),
#  ('사망률', 'N'),
#  (',', 'S'),
#  ('저출산', 'N'),
#  ('등', 'N'),
#  ('의', 'J'),
#  ('사회', 'N'),
#  ('문제', 'N'),
#  ('가', 'J'),
#  ('이', 'M'),
#  ('같', 'P'),
#  ('은', 'E'),
#  ('성과', 'N'),
#  ('와', 'J'),
#  ('병존', 'N'),
#  ('하고', 'J'),
#  ('있', 'P'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('대한민국', 'N'),
#  ('의', 'J'),
#  ('행정', 'N'),
#  ('구역', 'N'),
#  ('대한민국', 'N'),
#  ('은', 'J'),
#  ('이코노미스트', 'N'),
#  ('에서', 'J'),
#  ('발표', 'N'),
#  ('하', 'X'),
#  ('는', 'E'),
#  ('민주주의', 'N'),
#  ('지수', 'N'),
#  ('조사', 'N'),
#  ('에서', 'J'),
#  ('2019년', 'N'),
#  ('기준', 'N'),
#  ('23위', 'N'),
#  ('의', 'J'),
#  ('8.0점', 'N'),
#  ('을', 'J'),
#  ('기록', 'N'),
#  ('하', 'X'),
#  ('ㄴ', 'E'),
#  ('바', 'N'),
#  ('와', 'J'),
#  ('같', 'P'),
#  ('이', 'X'),
#  ('아시아', 'N'),
#  ('에서', 'J'),
#  ('민주주의', 'N'),
#  ('수준', 'N'),
#  ('이', 'J'),
#  ('가장', 'M'),
#  ('높', 'P'),
#  ('은', 'E'),
#  ('국', 'N'),
#  ('가', 'J'),
#  ('가운데', 'N'),
#  ('하나', 'N'),
#  ('이', 'J'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('또한', 'M'),
#  ('대한민국', 'N'),
#  ('은', 'J'),
#  ('주요', 'N'),
#  ('20개국', 'N'),
#  ('(G20),', 'N'),
#  ('경제', 'N'),
#  ('협력', 'N'),
#  ('개발', 'N'),
#  ('기구', 'N'),
#  ('(', 'S'),
#  ('OECD', 'F'),
#  ('),', 'S'),
#  ('개발', 'N'),
#  ('원조', 'N'),
#  ('위원회', 'N'),
#  ('(', 'S'),
#  ('DAC', 'F'),
#  ('),', 'S'),
#  ('파리', 'N'),
#  ('클럽', 'N'),
#  ('등', 'N'),
#  ('의', 'J'),
#  ('회원국', 'N'),
#  ('이', 'J'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('[', 'S'),
#  ('8', 'N'),
#  (']', 'S'),
#  ('1948년', 'N'),
#  ('이후', 'N'),
#  ('로', 'J'),
#  ('오늘날', 'N'),
#  ('까지', 'J'),
#  ('한반도', 'N'),
#  ('에는', 'J'),
#  ('대한민국', 'N'),
#  ('과', 'J'),
#  ('조선민주주의인민공화국', 'N'),
#  ('이', 'J'),
#  ('라는', 'E'),
#  ('두', 'N'),
#  ('개', 'N'),
#  ('의', 'J'),
#  ('분단국가', 'N'),
#  ('가', 'J'),
#  ('각각', 'M'),
#  ('남북', 'N'),
#  ('에', 'J'),
#  ('위치', 'N'),
#  ('하고', 'J'),
#  ('있', 'P'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('한반도', 'N'),
#  ('와', 'J'),
#  ('부속도서', 'N'),
#  ('의', 'J'),
#  ('면적', 'N'),
#  ('은', 'J'),
#  ('약', 'N'),
#  ('22', 'N'),
#  ('만', 'J'),
#  ('km2이며,', 'N'),
#  ('인구', 'N'),
#  ('는', 'J'),
#  ('대한민국', 'N'),
#  ('과', 'J'),
#  ('조선민주주의인민공화국', 'N'),
#  ('을', 'J'),
#  ('합치', 'P'),
#  ('어', 'E'),
#  ('2019년', 'N'),
#  ('을', 'J'),
#  ('기준', 'N'),
#  ('으로', 'J'),
#  ('약', 'N'),
#  ('7,700', 'N'),
#  ('만', 'J'),
#  ('명', 'N'),
#  ('에', 'J'),
#  ('달한다[9]', 'N'),
#  ('.', 'S')]

# %%
okt.tagset
# Out:
# {'Adjective': '형용사',
#  'Adverb': '부사',
#  'Alpha': '알파벳',
#  'Conjunction': '접속사',
#  'Determiner': '관형사',
#  'Eomi': '어미',
#  'Exclamation': '감탄사',
#  'Foreign': '외국어, 한자 및 기타기호',
#  'Hashtag': '트위터 해쉬태그',
#  'Josa': '조사',
#  'KoreanParticle': '(ex: ㅋㅋ)',
#  'Noun': '명사',
#  'Number': '숫자',
#  'PreEomi': '선어말어미',
#  'Punctuation': '구두점',
#  'ScreenName': '트위터 아이디',
#  'Suffix': '접미사',
#  'Unknown': '미등록어',
#  'Verb': '동사'}

# %%
okt.pos(txt)
# Out:
# [('\n', 'Foreign'),
#  ('대한민국', 'Noun'),
#  ('(', 'Punctuation'),
#  ('大韓民國', 'Foreign'),
#  (',', 'Punctuation'),
#  ('영어', 'Noun'),
#  (':', 'Punctuation'),
#  ('Republic', 'Alpha'),
#  ('of', 'Alpha'),
#  ('Korea', 'Alpha'),
#  (',', 'Punctuation'),
#  ('ROK', 'Alpha'),
#  ('),', 'Punctuation'),
#  ('약칭', 'Noun'),
#  ('남한', 'Noun'),
#  ('(', 'Punctuation'),
#  ('南韓', 'Foreign'),
#  (',', 'Punctuation'),
#  ('영어', 'Noun'),
#  (':', 'Punctuation'),
#  ('South', 'Alpha'),
#  ('Korea', 'Alpha'),
#  ('),', 'Punctuation'),
#  ('한국', 'Noun'),
#  ('(', 'Punctuation'),
#  ('韓國', 'Foreign'),
#  (')', 'Punctuation'),
#  ('은', 'Noun'),
#  ('동아시아', 'Noun'),
#  ('의', 'Josa'),
#  ('한반도', 'Noun'),
#  ('남부', 'Noun'),
#  ('에', 'Josa'),
#  ('자리', 'Noun'),
#  ('한', 'Josa'),
#  ('민주공화국', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('대한민국', 'Noun'),
#  ('의', 'Josa'),
#  ('국기', 'Noun'),
#  ('는', 'Josa'),
#  ('대한민국', 'Noun'),
#  ('국기법', 'Noun'),
#  ('에', 'Josa'),
#  ('따라', 'Verb'),
#  ('태극기', 'Noun'),
#  ('[', 'Punctuation'),
#  ('3', 'Number'),
#  ('],', 'Punctuation'),
#  ('국가', 'Noun'),
#  ('는', 'Josa'),
#  ('관습', 'Noun'),
#  ('상', 'Suffix'),
#  ('애국가', 'Noun'),
#  ('[', 'Punctuation'),
#  ('4', 'Number'),
#  ('],', 'Punctuation'),
#  ('국화', 'Noun'),
#  ('는', 'Josa'),
#  ('관습', 'Noun'),
#  ('상', 'Suffix'),
#  ('무궁화', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('공', 'Modifier'),
#  ('용어', 'Noun'),
#  ('는', 'Josa'),
#  ('한국어', 'Noun'),
#  ('와', 'Josa'),
#  ('한국', 'Noun'),
#  ('수어', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('수도', 'Noun'),
#  ('는', 'Josa'),
#  ('서울', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('인구', 'Noun'),
#  ('는', 'Josa'),
#  ('약', 'Noun'),
#  ('5,160만', 'Number'),
#  ('명으로', 'Foreign'),
#  (',', 'Punctuation'),
#  ('전체', 'Noun'),
#  ('인구', 'Noun'),
#  ('중', 'Noun'),
#  ('절반', 'Noun'),
#  ('정도', 'Noun'),
#  ('(', 'Punctuation'),
#  ('약', 'Noun'),
#  ('2611만', 'Number'),
#  ('명', 'Foreign'),
#  (')', 'Punctuation'),
#  ('가', 'Verb'),
#  ('수도권', 'Noun'),
#  ('에', 'Josa'),
#  ('살', 'Noun'),
#  ('고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('.[', 'Punctuation'),
#  ('5', 'Number'),
#  (']', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('대한민국', 'Noun'),
#  ('은', 'Josa'),
#  ('1948년', 'Number'),
#  ('5월', 'Number'),
#  ('10일', 'Number'),
#  ('총선거', 'Noun'),
#  ('를', 'Josa'),
#  ('통해', 'Noun'),
#  ('제헌국회', 'Noun'),
#  ('를', 'Josa'),
#  ('구성', 'Noun'),
#  ('하였고', 'Verb'),
#  (',', 'Punctuation'),
#  ('1948년', 'Number'),
#  ('8월', 'Number'),
#  ('15일', 'Number'),
#  ('대한민국', 'Noun'),
#  ('정부', 'Noun'),
#  ('를', 'Josa'),
#  ('수립', 'Noun'),
#  ('하였다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('1948년', 'Number'),
#  ('제헌', 'Noun'),
#  ('국회', 'Noun'),
#  ('에서', 'Josa'),
#  ('대한민국', 'Noun'),
#  ('의', 'Josa'),
#  ('국호', 'Noun'),
#  ('를', 'Josa'),
#  ('계승', 'Noun'),
#  ('하여', 'Verb'),
#  ('헌법', 'Noun'),
#  ('에', 'Josa'),
#  ('명시', 'Noun'),
#  ('하였고', 'Verb'),
#  (',', 'Punctuation'),
#  ('다시', 'Noun'),
#  ('1950년', 'Number'),
#  ('1월', 'Number'),
#  ('16일', 'Number'),
#  ('국무원', 'Noun'),
#  ('고시', 'Noun'),
#  ('제', 'Noun'),
#  ('7', 'Number'),
#  ('호', 'Noun'),
#  ('‘', 'Foreign'),
#  ('국호', 'Noun'),
#  ('및', 'Noun'),
#  ('일부', 'Noun'),
#  ('지방', 'Noun'),
#  ('명과', 'Noun'),
#  ('지', 'Modifier'),
#  ('도색', 'Noun'),
#  ('사용', 'Noun'),
#  ('에', 'Josa'),
#  ('관', 'Noun'),
#  ('한', 'Josa'),
#  ('건', 'Noun'),
#  ('’', 'Punctuation'),
#  ('에', 'Josa'),
#  ('의해', 'Adjective'),
#  ('확정', 'Noun'),
#  ('하였다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('대한민국', 'Noun'),
#  ('은', 'Josa'),
#  ('20', 'Number'),
#  ('세기', 'Noun'),
#  ('후반', 'Noun'),
#  ('이후', 'Noun'),
#  ('급격한', 'Adjective'),
#  ('경제', 'Noun'),
#  ('성장', 'Noun'),
#  ('을', 'Josa'),
#  ('이루었다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('그', 'Noun'),
#  ('과정', 'Noun'),
#  ('에서', 'Josa'),
#  ('1990년', 'Number'),
#  ('대', 'Foreign'),
#  ('말', 'Noun'),
#  ('외환', 'Noun'),
#  ('위기', 'Noun'),
#  ('등', 'Noun'),
#  ('의', 'Josa'),
#  ('부침이', 'Verb'),
#  ('있기도', 'Adjective'),
#  ('했다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('대한민국', 'Noun'),
#  ('의', 'Josa'),
#  ('2022년', 'Number'),
#  ('1', 'Number'),
#  ('인당', 'Verb'),
#  ('국민', 'Noun'),
#  ('총', 'Modifier'),
#  ('소득', 'Noun'),
#  ('(', 'Punctuation'),
#  ('GNI', 'Alpha'),
#  (')', 'Punctuation'),
#  ('은', 'Noun'),
#  ('명목', 'Noun'),
#  ('3만', 'Number'),
#  ('4,994달러', 'Number'),
#  ('이다', 'Foreign'),
#  ('.[', 'Punctuation'),
#  ('6', 'Number'),
#  (']', 'Punctuation'),
#  ('2020년', 'Number'),
#  ('유엔', 'Noun'),
#  ('개발', 'Noun'),
#  ('계획', 'Noun'),
#  ('(', 'Punctuation'),
#  ('UNDP', 'Alpha'),
#  (')', 'Punctuation'),
#  ('이', 'Noun'),
#  ('매년', 'Noun'),
#  ('발표', 'Noun'),
#  ('하는', 'Verb'),
#  ('인간', 'Noun'),
#  ('개발', 'Noun'),
#  ('지수', 'Noun'),
#  ('(', 'Punctuation'),
#  ('HDI', 'Alpha'),
#  (')', 'Punctuation'),
#  ('조사', 'Noun'),
#  ('에서', 'Josa'),
#  ('세계', 'Noun'),
#  ('22', 'Number'),
#  ('위', 'Noun'),
#  ('를', 'Josa'),
#  ('기록', 'Noun'),
#  ('하였다', 'Verb'),
#  ('.[', 'Punctuation'),
#  ('2', 'Number'),
#  (']', 'Punctuation'),
#  ('2021년', 'Number'),
#  ('7월', 'Number'),
#  ('2일', 'Number'),
#  ('스위스', 'Noun'),
#  ('제네바', 'Noun'),
#  ('본부', 'Noun'),
#  ('에서', 'Josa'),
#  ('열린', 'Verb'),
#  ('‘', 'Foreign'),
#  ('제', 'Noun'),
#  ('68', 'Number'),
#  ('차', 'Noun'),
#  ('무역', 'Noun'),
#  ('개발', 'Noun'),
#  ('이사회', 'Noun'),
#  ('’', 'Punctuation'),
#  ('마지막', 'Noun'),
#  ('회의', 'Noun'),
#  ('에서', 'Josa'),
#  ('한국', 'Noun'),
#  ('의', 'Josa'),
#  ('지위', 'Noun'),
#  ('를', 'Josa'),
#  ('선진국', 'Noun'),
#  ('그룹', 'Noun'),
#  ('으로', 'Josa'),
#  ('‘', 'Foreign'),
#  ('의견', 'Noun'),
#  ('일치', 'Noun'),
#  ('’', 'Punctuation'),
#  ('로', 'Noun'),
#  ('변경', 'Noun'),
#  ('하고', 'Josa'),
#  ('선진국', 'Noun'),
#  ('으로', 'Josa'),
#  ('인정', 'Noun'),
#  ('했다', 'Verb'),
#  ('.[', 'Punctuation'),
#  ('7', 'Number'),
#  (']', 'Punctuation'),
#  ('다만', 'Noun'),
#  ('높은', 'Adjective'),
#  ('자살률', 'Noun'),
#  (',', 'Punctuation'),
#  ('장시간', 'Noun'),
#  ('근로', 'Noun'),
#  ('문화', 'Noun'),
#  ('와', 'Josa'),
#  ('높은', 'Adjective'),
#  ('산업', 'Noun'),
#  ('재해', 'Noun'),
#  ('사망률', 'Noun'),
#  (',', 'Punctuation'),
#  ('저출산', 'Noun'),
#  ('등', 'Noun'),
#  ('의', 'Josa'),
#  ('사회', 'Noun'),
#  ('문제', 'Noun'),
#  ('가', 'Josa'),
#  ('이', 'Noun'),
#  ('같은', 'Adjective'),
#  ('성과', 'Noun'),
#  ('와', 'Josa'),
#  ('병존', 'Noun'),
#  ('하고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('대한민국', 'Noun'),
#  ('의', 'Josa'),
#  ('행정', 'Noun'),
#  ('구역', 'Noun'),
#  ('\n\n', 'Foreign'),
#  ('대한민국', 'Noun'),
#  ('은', 'Josa'),
#  ('이코노미스트', 'Noun'),
#  ('에서', 'Josa'),
#  ('발표', 'Noun'),
#  ('하는', 'Verb'),
#  ('민주주의', 'Noun'),
#  ('지수', 'Noun'),
#  ('조사', 'Noun'),
#  ('에서', 'Josa'),
#  ('2019년', 'Number'),
#  ('기준', 'Noun'),
#  ('23', 'Number'),
#  ('위', 'Noun'),
#  ('의', 'Josa'),
#  ('8.0', 'Number'),
#  ('점', 'Noun'),
#  ('을', 'Josa'),
#  ('기록', 'Noun'),
#  ('한', 'Josa'),
#  ('바', 'Noun'),
#  ('와', 'Josa'),
#  ('같이', 'Adverb'),
#  ('아시아', 'Noun'),
#  ('에서', 'Josa'),
#  ('민주주의', 'Noun'),
#  ('수준', 'Noun'),
#  ('이', 'Josa'),
#  ('가장', 'Noun'),
#  ('높은', 'Adjective'),
#  ('국가', 'Noun'),
#  ('가운데', 'Noun'),
#  ('하나', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('또한', 'Noun'),
#  ('대한민국', 'Noun'),
#  ('은', 'Josa'),
#  ('주요', 'Noun'),
#  ('20', 'Number'),
#  ('개국', 'Noun'),
#  ('(', 'Punctuation'),
#  ('G', 'Alpha'),
#  ('20', 'Number'),
#  ('),', 'Punctuation'),
#  ('경제', 'Noun'),
#  ('협력', 'Noun'),
#  ('개발', 'Noun'),
#  ('기구', 'Noun'),
#  ('(', 'Punctuation'),
#  ('OECD', 'Alpha'),
#  ('),', 'Punctuation'),
#  ('개발', 'Noun'),
#  ('원조', 'Noun'),
#  ('위원회', 'Noun'),
#  ('(', 'Punctuation'),
#  ('DAC', 'Alpha'),
#  ('),', 'Punctuation'),
#  ('파리', 'Noun'),
#  ('클럽', 'Noun'),
#  ('등', 'Noun'),
#  ('의', 'Josa'),
#  ('회원', 'Noun'),
#  ('국', 'Noun'),
#  ('이다', 'Josa'),
#  ('.[', 'Punctuation'),
#  ('8', 'Number'),
#  (']', 'Punctuation'),
#  ('\n\n', 'Foreign'),
#  ('1948년', 'Number'),
#  ('이후', 'Noun'),
#  ('로', 'Josa'),
#  ('오늘날', 'Noun'),
#  ('까지', 'Josa'),
#  ('한반도', 'Noun'),
#  ('에는', 'Josa'),
#  ('대한민국', 'Noun'),
#  ('과', 'Josa'),
#  ('조선', 'Noun'),
#  ('민주주의', 'Noun'),
#  ('인민공화국', 'Noun'),
#  ('이라는', 'Josa'),
#  ('두', 'Noun'),
#  ('개', 'Noun'),
#  ('의', 'Josa'),
#  ('분단국가', 'Noun'),
#  ('가', 'Josa'),
#  ('각각', 'Noun'),
#  ('남북', 'Noun'),
#  ('에', 'Josa'),
#  ('위치', 'Noun'),
#  ('하고', 'Josa'),
#  ('있다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('한반도', 'Noun'),
#  ('와', 'Josa'),
#  ('부속', 'Noun'),
#  ('도서', 'Noun'),
#  ('의', 'Josa'),
#  ('면적', 'Noun'),
#  ('은', 'Josa'),
#  ('약', 'Noun'),
#  ('22만', 'Number'),
#  ('km', 'Alpha'),
#  ('2', 'Number'),
#  ('이며', 'Josa'),
#  (',', 'Punctuation'),
#  ('인구', 'Noun'),
#  ('는', 'Josa'),
#  ('대한민국', 'Noun'),
#  ('과', 'Josa'),
#  ('조선', 'Noun'),
#  ('민주주의', 'Noun'),
#  ('인민공화국', 'Noun'),
#  ('을', 'Josa'),
#  ('합쳐', 'Verb'),
#  ('2019년', 'Number'),
#  ('을', 'Foreign'),
#  ('기준', 'Noun'),
#  ('으로', 'Josa'),
#  ('약', 'Noun'),
#  ('7,700만', 'Number'),
#  ('명', 'Noun'),
#  ('에', 'Josa'),
#  ('달', 'Noun'),
#  ('한', 'Josa'),
#  ('다', 'Adverb'),
#  ('[', 'Punctuation'),
#  ('9', 'Number'),
#  ('].', 'Punctuation'),
#  ('\n', 'Foreign')]

# %%
okt.pos(txt)[0]
# Out:
# ('\n', 'Foreign')

# %%
okt.pos(txt)[0][1]
# Out:
# 'Foreign'

# %%
res = []
for i in okt.pos(txt):
    if i[1] == 'Adjective':
        res.append(i)

# %%
res
# Out:
# [('있다', 'Adjective'),
#  ('의해', 'Adjective'),
#  ('급격한', 'Adjective'),
#  ('있기도', 'Adjective'),
#  ('높은', 'Adjective'),
#  ('높은', 'Adjective'),
#  ('같은', 'Adjective'),
#  ('있다', 'Adjective'),
#  ('높은', 'Adjective'),
#  ('있다', 'Adjective')]

# %%
kkma.tagset
# Out:
# {'EC': '연결 어미',
#  'ECD': '의존적 연결 어미',
#  'ECE': '대등 연결 어미',
#  'ECS': '보조적 연결 어미',
#  'EF': '종결 어미',
#  'EFA': '청유형 종결 어미',
#  'EFI': '감탄형 종결 어미',
#  'EFN': '평서형 종결 어미',
#  'EFO': '명령형 종결 어미',
#  'EFQ': '의문형 종결 어미',
#  'EFR': '존칭형 종결 어미',
#  'EP': '선어말 어미',
#  'EPH': '존칭 선어말 어미',
#  'EPP': '공손 선어말 어미',
#  'EPT': '시제 선어말 어미',
#  'ET': '전성 어미',
#  'ETD': '관형형 전성 어미',
#  'ETN': '명사형 전성 어미',
#  'IC': '감탄사',
#  'JC': '접속 조사',
#  'JK': '조사',
#  'JKC': '보격 조사',
#  'JKG': '관형격 조사',
#  'JKI': '호격 조사',
#  'JKM': '부사격 조사',
#  'JKO': '목적격 조사',
#  'JKQ': '인용격 조사',
#  'JKS': '주격 조사',
#  'JX': '보조사',
#  'MA': '부사',
#  'MAC': '접속 부사',
#  'MAG': '일반 부사',
#  'MD': '관형사',
#  'MDN': '수 관형사',
#  'MDT': '일반 관형사',
#  'NN': '명사',
#  'NNB': '일반 의존 명사',
#  'NNG': '보통명사',
#  'NNM': '단위 의존 명사',
#  'NNP': '고유명사',
#  'NP': '대명사',
#  'NR': '수사',
#  'OH': '한자',
#  'OL': '외국어',
#  'ON': '숫자',
#  'SE': '줄임표',
#  'SF': '마침표, 물음표, 느낌표',
#  'SO': '붙임표(물결,숨김,빠짐)',
#  'SP': '쉼표,가운뎃점,콜론,빗금',
#  'SS': '따옴표,괄호표,줄표',
#  'SW': '기타기호 (논리수학기호,화폐기호)',
#  'UN': '명사추정범주',
#  'VA': '형용사',
#  'VC': '지정사',
#  'VCN': "부정 지정사, 형용사 '아니다'",
#  'VCP': "긍정 지정사, 서술격 조사 '이다'",
#  'VV': '동사',
#  'VX': '보조 용언',
#  'VXA': '보조 형용사',
#  'VXV': '보조 동사',
#  'XP': '접두사',
#  'XPN': '체언 접두사',
#  'XPV': '용언 접두사',
#  'XR': '어근',
#  'XSA': '형용사 파생 접미사',
#  'XSN': '명사파생 접미사',
#  'XSV': '동사 파생 접미사'}

# %%
res = []
for i in kkma.pos(txt):
    if i[1] == 'VA':
        res.append(i)

# %%
res
# Out:
# [('높', 'VA'), ('높', 'VA'), ('같', 'VA'), ('높', 'VA')]

# %%
ls = ['Noun', 'Adjective', 'Adverb']
res = []
res_noun = []
res_adjective = []
res_adverb = []
for i in okt.pos(txt):
    if i[1] in ls:
        res.append(i)

# %%
res
# Out:
# [('대한민국', 'Noun'),
#  ('영어', 'Noun'),
#  ('약칭', 'Noun'),
#  ('남한', 'Noun'),
#  ('영어', 'Noun'),
#  ('한국', 'Noun'),
#  ('은', 'Noun'),
#  ('동아시아', 'Noun'),
#  ('한반도', 'Noun'),
#  ('남부', 'Noun'),
#  ('자리', 'Noun'),
#  ('민주공화국', 'Noun'),
#  ('대한민국', 'Noun'),
#  ('국기', 'Noun'),
#  ('대한민국', 'Noun'),
#  ('국기법', 'Noun'),
#  ('태극기', 'Noun'),
#  ('국가', 'Noun'),
#  ('관습', 'Noun'),
#  ('애국가', 'Noun'),
#  ('국화', 'Noun'),
#  ('관습', 'Noun'),
#  ('무궁화', 'Noun'),
#  ('용어', 'Noun'),
#  ('한국어', 'Noun'),
#  ('한국', 'Noun'),
#  ('수어', 'Noun'),
#  ('수도', 'Noun'),
#  ('서울', 'Noun'),
#  ('인구', 'Noun'),
#  ('약', 'Noun'),
#  ('전체', 'Noun'),
#  ('인구', 'Noun'),
#  ('중', 'Noun'),
#  ('절반', 'Noun'),
#  ('정도', 'Noun'),
#  ('약', 'Noun'),
#  ('수도권', 'Noun'),
#  ('살', 'Noun'),
#  ('있다', 'Adjective'),
#  ('대한민국', 'Noun'),
#  ('총선거', 'Noun'),
#  ('통해', 'Noun'),
#  ('제헌국회', 'Noun'),
#  ('구성', 'Noun'),
#  ('대한민국', 'Noun'),
#  ('정부', 'Noun'),
#  ('수립', 'Noun'),
#  ('제헌', 'Noun'),
#  ('국회', 'Noun'),
#  ('대한민국', 'Noun'),
#  ('국호', 'Noun'),
#  ('계승', 'Noun'),
#  ('헌법', 'Noun'),
#  ('명시', 'Noun'),
#  ('다시', 'Noun'),
#  ('국무원', 'Noun'),
#  ('고시', 'Noun'),
#  ('제', 'Noun'),
#  ('호', 'Noun'),
#  ('국호', 'Noun'),
#  ('및', 'Noun'),
#  ('일부', 'Noun'),
#  ('지방', 'Noun'),
#  ('명과', 'Noun'),
#  ('도색', 'Noun'),
#  ('사용', 'Noun'),
#  ('관', 'Noun'),
#  ('건', 'Noun'),
#  ('의해', 'Adjective'),
#  ('확정', 'Noun'),
#  ('대한민국', 'Noun'),
#  ('세기', 'Noun'),
#  ('후반', 'Noun'),
#  ('이후', 'Noun'),
#  ('급격한', 'Adjective'),
#  ('경제', 'Noun'),
#  ('성장', 'Noun'),
#  ('그', 'Noun'),
#  ('과정', 'Noun'),
#  ('말', 'Noun'),
#  ('외환', 'Noun'),
#  ('위기', 'Noun'),
#  ('등', 'Noun'),
#  ('있기도', 'Adjective'),
#  ('대한민국', 'Noun'),
#  ('국민', 'Noun'),
#  ('소득', 'Noun'),
#  ('은', 'Noun'),
#  ('명목', 'Noun'),
#  ('유엔', 'Noun'),
#  ('개발', 'Noun'),
#  ('계획', 'Noun'),
#  ('이', 'Noun'),
#  ('매년', 'Noun'),
#  ('발표', 'Noun'),
#  ('인간', 'Noun'),
#  ('개발', 'Noun'),
#  ('지수', 'Noun'),
#  ('조사', 'Noun'),
#  ('세계', 'Noun'),
#  ('위', 'Noun'),
#  ('기록', 'Noun'),
#  ('스위스', 'Noun'),
#  ('제네바', 'Noun'),
#  ('본부', 'Noun'),
#  ('제', 'Noun'),
#  ('차', 'Noun'),
#  ('무역', 'Noun'),
#  ('개발', 'Noun'),
#  ('이사회', 'Noun'),
#  ('마지막', 'Noun'),
#  ('회의', 'Noun'),
#  ('한국', 'Noun'),
#  ('지위', 'Noun'),
#  ('선진국', 'Noun'),
#  ('그룹', 'Noun'),
#  ('의견', 'Noun'),
#  ('일치', 'Noun'),
#  ('로', 'Noun'),
#  ('변경', 'Noun'),
#  ('선진국', 'Noun'),
#  ('인정', 'Noun'),
#  ('다만', 'Noun'),
#  ('높은', 'Adjective'),
#  ('자살률', 'Noun'),
#  ('장시간', 'Noun'),
#  ('근로', 'Noun'),
#  ('문화', 'Noun'),
#  ('높은', 'Adjective'),
#  ('산업', 'Noun'),
#  ('재해', 'Noun'),
#  ('사망률', 'Noun'),
#  ('저출산', 'Noun'),
#  ('등', 'Noun'),
#  ('사회', 'Noun'),
#  ('문제', 'Noun'),
#  ('이', 'Noun'),
#  ('같은', 'Adjective'),
#  ('성과', 'Noun'),
#  ('병존', 'Noun'),
#  ('있다', 'Adjective'),
#  ('대한민국', 'Noun'),
#  ('행정', 'Noun'),
#  ('구역', 'Noun'),
#  ('대한민국', 'Noun'),
#  ('이코노미스트', 'Noun'),
#  ('발표', 'Noun'),
#  ('민주주의', 'Noun'),
#  ('지수', 'Noun'),
#  ('조사', 'Noun'),
#  ('기준', 'Noun'),
#  ('위', 'Noun'),
#  ('점', 'Noun'),
#  ('기록', 'Noun'),
#  ('바', 'Noun'),
#  ('같이', 'Adverb'),
#  ('아시아', 'Noun'),
#  ('민주주의', 'Noun'),
#  ('수준', 'Noun'),
#  ('가장', 'Noun'),
#  ('높은', 'Adjective'),
#  ('국가', 'Noun'),
#  ('가운데', 'Noun'),
#  ('하나', 'Noun'),
#  ('또한', 'Noun'),
#  ('대한민국', 'Noun'),
#  ('주요', 'Noun'),
#  ('개국', 'Noun'),
#  ('경제', 'Noun'),
#  ('협력', 'Noun'),
#  ('개발', 'Noun'),
#  ('기구', 'Noun'),
#  ('개발', 'Noun'),
#  ('원조', 'Noun'),
#  ('위원회', 'Noun'),
#  ('파리', 'Noun'),
#  ('클럽', 'Noun'),
#  ('등', 'Noun'),
#  ('회원', 'Noun'),
#  ('국', 'Noun'),
#  ('이후', 'Noun'),
#  ('오늘날', 'Noun'),
#  ('한반도', 'Noun'),
#  ('대한민국', 'Noun'),
#  ('조선', 'Noun'),
#  ('민주주의', 'Noun'),
#  ('인민공화국', 'Noun'),
#  ('두', 'Noun'),
#  ('개', 'Noun'),
#  ('분단국가', 'Noun'),
#  ('각각', 'Noun'),
#  ('남북', 'Noun'),
#  ('위치', 'Noun'),
#  ('있다', 'Adjective'),
#  ('한반도', 'Noun'),
#  ('부속', 'Noun'),
#  ('도서', 'Noun'),
#  ('면적', 'Noun'),
#  ('약', 'Noun'),
#  ('인구', 'Noun'),
#  ('대한민국', 'Noun'),
#  ('조선', 'Noun'),
#  ('민주주의', 'Noun'),
#  ('인민공화국', 'Noun'),
#  ('기준', 'Noun'),
#  ('약', 'Noun'),
#  ('명', 'Noun'),
#  ('달', 'Noun'),
#  ('다', 'Adverb')]

# %%
for i in res:
    if i[1] == 'Noun':
        res_none.append(i)
    elif i[1] == 'Adjective':
        res_adjective.append(i)
    elif i[1] == 'Adverb':
        res_adverb.append(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [73], in <cell line: 1>()
#       1 for i in res:
#       2     if i[1] == 'Noun':
# ----> 3         res_none.append(i)
#       4     elif i[1] == 'Adjective':
#       5         res_adjective.append(i)
#
# NameError: name 'res_none' is not defined

# %%
han.tagset
# Out:
# {'E': '어미',
#  'EC': '연결 어미',
#  'EF': '종결 어미',
#  'EP': '선어말어미',
#  'ET': '전성 어미',
#  'F': '외국어',
#  'I': '독립언',
#  'II': '감탄사',
#  'J': '관계언',
#  'JC': '격조사',
#  'JP': '서술격 조사',
#  'JX': '보조사',
#  'M': '수식언',
#  'MA': '부사',
#  'MM': '관형사',
#  'N': '체언',
#  'NB': '의존명사',
#  'NC': '보통명사',
#  'NN': '수사',
#  'NP': '대명사',
#  'NQ': '고유명사',
#  'P': '용언',
#  'PA': '형용사',
#  'PV': '동사',
#  'PX': '보조 용언',
#  'S': '기호',
#  'X': '접사',
#  'XP': '접두사',
#  'XS': '접미사'}

# %%
ls = ['PA', 'PV']
res = []
for i in han.pos(txt):
    if i[1] in ls:
        res.append(i)

# %%
res
# Out:
# []

# %%
kkma.tagset
# Out:
# {'EC': '연결 어미',
#  'ECD': '의존적 연결 어미',
#  'ECE': '대등 연결 어미',
#  'ECS': '보조적 연결 어미',
#  'EF': '종결 어미',
#  'EFA': '청유형 종결 어미',
#  'EFI': '감탄형 종결 어미',
#  'EFN': '평서형 종결 어미',
#  'EFO': '명령형 종결 어미',
#  'EFQ': '의문형 종결 어미',
#  'EFR': '존칭형 종결 어미',
#  'EP': '선어말 어미',
#  'EPH': '존칭 선어말 어미',
#  'EPP': '공손 선어말 어미',
#  'EPT': '시제 선어말 어미',
#  'ET': '전성 어미',
#  'ETD': '관형형 전성 어미',
#  'ETN': '명사형 전성 어미',
#  'IC': '감탄사',
#  'JC': '접속 조사',
#  'JK': '조사',
#  'JKC': '보격 조사',
#  'JKG': '관형격 조사',
#  'JKI': '호격 조사',
#  'JKM': '부사격 조사',
#  'JKO': '목적격 조사',
#  'JKQ': '인용격 조사',
#  'JKS': '주격 조사',
#  'JX': '보조사',
#  'MA': '부사',
#  'MAC': '접속 부사',
#  'MAG': '일반 부사',
#  'MD': '관형사',
#  'MDN': '수 관형사',
#  'MDT': '일반 관형사',
#  'NN': '명사',
#  'NNB': '일반 의존 명사',
#  'NNG': '보통명사',
#  'NNM': '단위 의존 명사',
#  'NNP': '고유명사',
#  'NP': '대명사',
#  'NR': '수사',
#  'OH': '한자',
#  'OL': '외국어',
#  'ON': '숫자',
#  'SE': '줄임표',
#  'SF': '마침표, 물음표, 느낌표',
#  'SO': '붙임표(물결,숨김,빠짐)',
#  'SP': '쉼표,가운뎃점,콜론,빗금',
#  'SS': '따옴표,괄호표,줄표',
#  'SW': '기타기호 (논리수학기호,화폐기호)',
#  'UN': '명사추정범주',
#  'VA': '형용사',
#  'VC': '지정사',
#  'VCN': "부정 지정사, 형용사 '아니다'",
#  'VCP': "긍정 지정사, 서술격 조사 '이다'",
#  'VV': '동사',
#  'VX': '보조 용언',
#  'VXA': '보조 형용사',
#  'VXV': '보조 동사',
#  'XP': '접두사',
#  'XPN': '체언 접두사',
#  'XPV': '용언 접두사',
#  'XR': '어근',
#  'XSA': '형용사 파생 접미사',
#  'XSN': '명사파생 접미사',
#  'XSV': '동사 파생 접미사'}

# %%
# NN VA VV (명사 형용사 동사)
ls = ['NN', 'VA', 'VV']
res = []
for i in kkma.pos(txt1):
    for j in ls:
        if j in i[1]:
            res.append(i)

# %%
res
# Out:
# [('대한민국', 'NNG'),
#  ('약칭', 'NNG'),
#  ('남한', 'NNG'),
#  ('한국', 'NNG'),
#  ('동아시아', 'NNP'),
#  ('한반도', 'NNG'),
#  ('남부', 'NNG'),
#  ('자리', 'NNG'),
#  ('민주', 'NNG'),
#  ('공화국', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('국기', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('국', 'NNG'),
#  ('기법', 'NNG'),
#  ('따르', 'VV'),
#  ('태극기', 'NNG'),
#  ('국가', 'NNG'),
#  ('관습', 'NNG'),
#  ('애', 'NNG'),
#  ('국가', 'NNG'),
#  ('국화', 'NNG'),
#  ('관습', 'NNG'),
#  ('상', 'NNG'),
#  ('무궁화', 'NNG'),
#  ('공용어', 'NNG'),
#  ('한국어', 'NNG'),
#  ('한국', 'NNG'),
#  ('수어', 'NNG'),
#  ('수도', 'NNG'),
#  ('서울', 'NNG'),
#  ('인구', 'NNG'),
#  ('명', 'NNM'),
#  ('전체', 'NNG'),
#  ('인구', 'NNG'),
#  ('중', 'NNB'),
#  ('절반', 'NNG'),
#  ('정도', 'NNG'),
#  ('수도권', 'NNG'),
#  ('살', 'VV'),
#  ('대한민국', 'NNG'),
#  ('년', 'NNM'),
#  ('월', 'NNM'),
#  ('일', 'NNM'),
#  ('총선거', 'NNG'),
#  ('통하', 'VV'),
#  ('제헌', 'NNG'),
#  ('국회', 'NNG'),
#  ('구성', 'NNG'),
#  ('년', 'NNM'),
#  ('월', 'NNM'),
#  ('일', 'NNM'),
#  ('대한민국', 'NNG'),
#  ('정부', 'NNG'),
#  ('수립', 'NNG'),
#  ('년', 'NNM'),
#  ('제헌', 'NNG'),
#  ('국회', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('국호', 'NNG'),
#  ('계승', 'NNG'),
#  ('헌법', 'NNG'),
#  ('명시', 'NNG'),
#  ('년', 'NNM'),
#  ('월', 'NNM'),
#  ('일', 'NNM'),
#  ('국무원', 'NNG'),
#  ('고시', 'NNG'),
#  ('제', 'NNG'),
#  ('호', 'NNM'),
#  ('국', 'NNG'),
#  ('호', 'NNG'),
#  ('일부', 'NNG'),
#  ('지방', 'NNG'),
#  ('명과', 'NNG'),
#  ('지도', 'NNG'),
#  ('색', 'NNG'),
#  ('사용', 'NNG'),
#  ('관하', 'VV'),
#  ('건', 'NNG'),
#  ('의하', 'VV'),
#  ('확정', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('세기', 'NNG'),
#  ('후반', 'NNG'),
#  ('이후', 'NNG'),
#  ('급격', 'NNG'),
#  ('경제', 'NNG'),
#  ('성장', 'NNG'),
#  ('이루', 'VV'),
#  ('과정', 'NNG'),
#  ('년대', 'NNM'),
#  ('말', 'NNG'),
#  ('외환', 'NNG'),
#  ('위기', 'NNG'),
#  ('등', 'NNB'),
#  ('부침', 'NNG'),
#  ('있', 'VV'),
#  ('하', 'VV'),
#  ('대한민국', 'NNG'),
#  ('년', 'NNM'),
#  ('인', 'NNG'),
#  ('국민', 'NNG'),
#  ('총소득', 'NNG'),
#  ('은', 'NNG'),
#  ('명목', 'NNG'),
#  ('달러', 'NNM'),
#  ('년', 'NNM'),
#  ('유엔', 'NNG'),
#  ('개발', 'NNG'),
#  ('계획', 'NNG'),
#  ('이', 'NNG'),
#  ('발표', 'NNG'),
#  ('인간', 'NNG'),
#  ('개발', 'NNG'),
#  ('지수', 'NNG'),
#  ('조사', 'NNG'),
#  ('세계', 'NNG'),
#  ('위', 'NNM'),
#  ('기록', 'NNG'),
#  ('년', 'NNM'),
#  ('월', 'NNM'),
#  ('일', 'NNM'),
#  ('스위스', 'NNG'),
#  ('제네바', 'NNG'),
#  ('본부', 'NNG'),
#  ('열리', 'VV'),
#  ('차', 'NNM'),
#  ('무역', 'NNG'),
#  ('개발', 'NNG'),
#  ('이사회', 'NNG'),
#  ('마지막', 'NNG'),
#  ('회의', 'NNG'),
#  ('한국', 'NNG'),
#  ('지위', 'NNG'),
#  ('선진국', 'NNG'),
#  ('그룹', 'NNG'),
#  ('의견', 'NNG'),
#  ('일치', 'NNG'),
#  ('로', 'NNG'),
#  ('변경', 'NNG'),
#  ('선진국', 'NNG'),
#  ('인정', 'NNG'),
#  ('높', 'VA'),
#  ('자살률', 'NNG'),
#  ('장시간', 'NNG'),
#  ('근로', 'NNG'),
#  ('문화', 'NNG'),
#  ('높', 'VA'),
#  ('산업', 'NNG'),
#  ('재해', 'NNG'),
#  ('사망률', 'NNG'),
#  ('저출산', 'NNG'),
#  ('등', 'NNB'),
#  ('사회', 'NNG'),
#  ('문제', 'NNG'),
#  ('같', 'VA'),
#  ('성과', 'NNG'),
#  ('병존', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('행정', 'NNG'),
#  ('구역', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('이코노', 'NNG'),
#  ('미스트', 'NNG'),
#  ('발표', 'NNG'),
#  ('민주주의', 'NNG'),
#  ('지수', 'NNG'),
#  ('조사', 'NNG'),
#  ('년', 'NNM'),
#  ('기준', 'NNG'),
#  ('위의', 'NNG'),
#  ('점', 'NNM'),
#  ('기록', 'NNG'),
#  ('바', 'NNB'),
#  ('아시아', 'NNG'),
#  ('민주주의', 'NNG'),
#  ('수준', 'NNG'),
#  ('높', 'VA'),
#  ('국가', 'NNG'),
#  ('가운데', 'NNG'),
#  ('하', 'VV'),
#  ('하', 'VV'),
#  ('대한민국', 'NNG'),
#  ('주요', 'NNG'),
#  ('개국', 'NNM'),
#  ('경제', 'NNG'),
#  ('협력', 'NNG'),
#  ('개발', 'NNG'),
#  ('기구', 'NNG'),
#  ('개발', 'NNG'),
#  ('원조', 'NNG'),
#  ('위원회', 'NNG'),
#  ('파리', 'NNG'),
#  ('클럽', 'NNG'),
#  ('등', 'NNB'),
#  ('회원국', 'NNG'),
#  ('년', 'NNM'),
#  ('이후', 'NNG'),
#  ('오늘날', 'NNG'),
#  ('한반도', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('조선', 'NNG'),
#  ('민주주의', 'NNG'),
#  ('인민', 'NNG'),
#  ('공화국', 'NNG'),
#  ('개', 'NNM'),
#  ('분단', 'NNG'),
#  ('국가', 'NNG'),
#  ('남북', 'NNG'),
#  ('위치', 'NNG'),
#  ('한반도', 'NNG'),
#  ('부', 'NNG'),
#  ('속도', 'NNG'),
#  ('서의', 'NNG'),
#  ('면적', 'NNG'),
#  ('인구', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('조선', 'NNG'),
#  ('민주주의', 'NNG'),
#  ('인민', 'NNG'),
#  ('공화국', 'NNG'),
#  ('합치', 'VV'),
#  ('년', 'NNM'),
#  ('기준', 'NNG'),
#  ('약', 'NNG'),
#  ('명', 'NNM'),
#  ('달하', 'VV')]

# %%
kkma.pos(txt)
# Out:
# [('대한민국', 'NNG'),
#  ('(', 'SS'),
#  ('大韓民國', 'OH'),
#  (',', 'SP'),
#  ('영어', 'NNG'),
#  (':', 'SP'),
#  ('Republic', 'OL'),
#  ('of', 'OL'),
#  ('Korea', 'OL'),
#  (',', 'SP'),
#  ('ROK', 'OL'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('약칭', 'NNG'),
#  ('남한', 'NNG'),
#  ('(', 'SS'),
#  ('南韓', 'OH'),
#  (',', 'SP'),
#  ('영어', 'NNG'),
#  (':', 'SP'),
#  ('South', 'OL'),
#  ('Korea', 'OL'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('한국', 'NNG'),
#  ('(', 'SS'),
#  ('韓國', 'OH'),
#  (')', 'SS'),
#  ('은', 'NNG'),
#  ('동아시아', 'NNP'),
#  ('의', 'JKG'),
#  ('한반도', 'NNG'),
#  ('남부', 'NNG'),
#  ('에', 'JKM'),
#  ('자리', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('민주', 'NNG'),
#  ('공화국', 'NNG'),
#  ('이', 'VCP'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('대한민국', 'NNG'),
#  ('의', 'JKG'),
#  ('국기', 'NNG'),
#  ('는', 'JX'),
#  ('대한민국', 'NNG'),
#  ('국', 'NNG'),
#  ('기법', 'NNG'),
#  ('에', 'JKM'),
#  ('따르', 'VV'),
#  ('아', 'ECS'),
#  ('태극기', 'NNG'),
#  ('[', 'SS'),
#  ('3', 'NR'),
#  (']', 'SS'),
#  (',', 'SP'),
#  ('국가', 'NNG'),
#  ('는', 'JX'),
#  ('관습', 'NNG'),
#  ('상', 'XSN'),
#  ('애', 'NNG'),
#  ('국가', 'NNG'),
#  ('[', 'SS'),
#  ('4', 'NR'),
#  (']', 'SS'),
#  (',', 'SP'),
#  ('국화', 'NNG'),
#  ('는', 'JX'),
#  ('관습', 'NNG'),
#  ('상', 'NNG'),
#  ('무궁화', 'NNG'),
#  ('이', 'VCP'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('공용어', 'NNG'),
#  ('는', 'JX'),
#  ('한국어', 'NNG'),
#  ('와', 'JKM'),
#  ('한국', 'NNG'),
#  ('수어', 'NNG'),
#  ('이', 'VCP'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('수도', 'NNG'),
#  ('는', 'JX'),
#  ('서울', 'NNG'),
#  ('이', 'VCP'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('인구', 'NNG'),
#  ('는', 'JX'),
#  ('약', 'MDN'),
#  ('5,160', 'NR'),
#  ('만', 'NR'),
#  ('명', 'NNM'),
#  ('으로', 'JKM'),
#  (',', 'SP'),
#  ('전체', 'NNG'),
#  ('인구', 'NNG'),
#  ('중', 'NNB'),
#  ('절반', 'NNG'),
#  ('정도', 'NNG'),
#  ('(', 'SS'),
#  ('약', 'NNG'),
#  ('2611', 'NR'),
#  ('만', 'NR'),
#  ('명', 'NNM'),
#  (')', 'SS'),
#  ('가', 'VV'),
#  ('아', 'ECS'),
#  ('수도권', 'NNG'),
#  ('에', 'JKM'),
#  ('살', 'VV'),
#  ('고', 'ECE'),
#  ('있', 'VXV'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('[', 'SS'),
#  ('5', 'NR'),
#  (']', 'SS'),
#  ('대한민국', 'NNG'),
#  ('은', 'JX'),
#  ('1948', 'NR'),
#  ('년', 'NNM'),
#  ('5', 'NR'),
#  ('월', 'NNM'),
#  ('10', 'NR'),
#  ('일', 'NNM'),
#  ('총선거', 'NNG'),
#  ('를', 'JKO'),
#  ('통하', 'VV'),
#  ('어', 'ECS'),
#  ('제헌', 'NNG'),
#  ('국회', 'NNG'),
#  ('를', 'JKO'),
#  ('구성', 'NNG'),
#  ('하', 'XSV'),
#  ('였', 'EPT'),
#  ('고', 'ECE'),
#  (',', 'SP'),
#  ('1948', 'NR'),
#  ('년', 'NNM'),
#  ('8', 'NR'),
#  ('월', 'NNM'),
#  ('15', 'NR'),
#  ('일', 'NNM'),
#  ('대한민국', 'NNG'),
#  ('정부', 'NNG'),
#  ('를', 'JKO'),
#  ('수립', 'NNG'),
#  ('하', 'XSV'),
#  ('였', 'EPT'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('1948', 'NR'),
#  ('년', 'NNM'),
#  ('제헌', 'NNG'),
#  ('국회', 'NNG'),
#  ('에서', 'JKM'),
#  ('대한민국', 'NNG'),
#  ('의', 'JKG'),
#  ('국호', 'NNG'),
#  ('를', 'JKO'),
#  ('계승', 'NNG'),
#  ('하', 'XSV'),
#  ('여', 'ECS'),
#  ('헌법', 'NNG'),
#  ('에', 'JKM'),
#  ('명시', 'NNG'),
#  ('하', 'XSV'),
#  ('였', 'EPT'),
#  ('고', 'ECE'),
#  (',', 'SP'),
#  ('다시', 'MAG'),
#  ('1950', 'NR'),
#  ('년', 'NNM'),
#  ('1', 'NR'),
#  ('월', 'NNM'),
#  ('16', 'NR'),
#  ('일', 'NNM'),
#  ('국무원', 'NNG'),
#  ('고시', 'NNG'),
#  ('제', 'NNG'),
#  ('7', 'NR'),
#  ('호', 'NNM'),
#  ('‘', 'SS'),
#  ('국', 'NNG'),
#  ('호', 'NNG'),
#  ('및', 'MAG'),
#  ('일부', 'NNG'),
#  ('지방', 'NNG'),
#  ('명과', 'NNG'),
#  ('지도', 'NNG'),
#  ('색', 'NNG'),
#  ('사용', 'NNG'),
#  ('에', 'JKM'),
#  ('관하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('건', 'NNG'),
#  ('’', 'SS'),
#  ('에', 'JKM'),
#  ('의하', 'VV'),
#  ('어', 'ECS'),
#  ('확정', 'NNG'),
#  ('하', 'XSV'),
#  ('였', 'EPT'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('대한민국', 'NNG'),
#  ('은', 'JX'),
#  ('20', 'NR'),
#  ('세기', 'NNG'),
#  ('후반', 'NNG'),
#  ('이후', 'NNG'),
#  ('급격', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('경제', 'NNG'),
#  ('성장', 'NNG'),
#  ('을', 'JKO'),
#  ('이루', 'VV'),
#  ('었', 'EPT'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('그', 'MDT'),
#  ('과정', 'NNG'),
#  ('에서', 'JKM'),
#  ('1990', 'NR'),
#  ('년대', 'NNM'),
#  ('말', 'NNG'),
#  ('외환', 'NNG'),
#  ('위기', 'NNG'),
#  ('등', 'NNB'),
#  ('의', 'JKG'),
#  ('부침', 'NNG'),
#  ('이', 'JKS'),
#  ('있', 'VV'),
#  ('기', 'ETN'),
#  ('도', 'JX'),
#  ('하', 'VV'),
#  ('었', 'EPT'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('대한민국', 'NNG'),
#  ('의', 'JKG'),
#  ('2022', 'NR'),
#  ('년', 'NNM'),
#  ('1', 'NR'),
#  ('인', 'NNG'),
#  ('당', 'XSN'),
#  ('국민', 'NNG'),
#  ('총소득', 'NNG'),
#  ('(', 'SS'),
#  ('GNI', 'OL'),
#  (')', 'SS'),
#  ('은', 'NNG'),
#  ('명목', 'NNG'),
#  ('3', 'NR'),
#  ('만', 'NR'),
#  ('4,994', 'NR'),
#  ('달러', 'NNM'),
#  ('이', 'VCP'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('[', 'SS'),
#  ('6', 'NR'),
#  (']', 'SS'),
#  ('2020', 'NR'),
#  ('년', 'NNM'),
#  ('유엔', 'NNG'),
#  ('개발', 'NNG'),
#  ('계획', 'NNG'),
#  ('(', 'SS'),
#  ('UNDP', 'OL'),
#  (')', 'SS'),
#  ('이', 'NNG'),
#  ('매년', 'MAG'),
#  ('발표', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETD'),
#  ('인간', 'NNG'),
#  ('개발', 'NNG'),
#  ('지수', 'NNG'),
#  ('(', 'SS'),
#  ('HDI', 'OL'),
#  (')', 'SS'),
#  ('조사', 'NNG'),
#  ('에서', 'JKM'),
#  ('세계', 'NNG'),
#  ('22', 'NR'),
#  ('위', 'NNM'),
#  ('를', 'JKO'),
#  ('기록', 'NNG'),
#  ('하', 'XSV'),
#  ('였', 'EPT'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('[', 'SS'),
#  ('2', 'NR'),
#  (']', 'SS'),
#  ('2021', 'NR'),
#  ('년', 'NNM'),
#  ('7', 'NR'),
#  ('월', 'NNM'),
#  ('2', 'NR'),
#  ('일', 'NNM'),
#  ('스위스', 'NNG'),
#  ('제네바', 'NNG'),
#  ('본부', 'NNG'),
#  ('에서', 'JKM'),
#  ('열리', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('‘', 'SS'),
#  ('저', 'NP'),
#  ('의', 'JKG'),
#  ('68', 'NR'),
#  ('차', 'NNM'),
#  ('무역', 'NNG'),
#  ('개발', 'NNG'),
#  ('이사회', 'NNG'),
#  ('’', 'SS'),
#  ('마지막', 'NNG'),
#  ('회의', 'NNG'),
#  ('에서', 'JKM'),
#  ('한국', 'NNG'),
#  ('의', 'JKG'),
#  ('지위', 'NNG'),
#  ('를', 'JKO'),
#  ('선진국', 'NNG'),
#  ('그룹', 'NNG'),
#  ('으로', 'JKM'),
#  ('‘', 'SS'),
#  ('의견', 'NNG'),
#  ('일치', 'NNG'),
#  ('’', 'SS'),
#  ('로', 'NNG'),
#  ('변경', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'ECE'),
#  ('선진국', 'NNG'),
#  ('으로', 'JKM'),
#  ('인정', 'NNG'),
#  ('하', 'XSV'),
#  ('었', 'EPT'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('[', 'SS'),
#  ('7', 'NR'),
#  (']', 'SS'),
#  ('다만', 'MAG'),
#  ('높', 'VA'),
#  ('은', 'ETD'),
#  ('자살률', 'NNG'),
#  (',', 'SP'),
#  ('장시간', 'NNG'),
#  ('근로', 'NNG'),
#  ('문화', 'NNG'),
#  ('와', 'JKM'),
#  ('높', 'VA'),
#  ('은', 'ETD'),
#  ('산업', 'NNG'),
#  ('재해', 'NNG'),
#  ('사망률', 'NNG'),
#  (',', 'SP'),
#  ('저출산', 'NNG'),
#  ('등', 'NNB'),
#  ('의', 'JKG'),
#  ('사회', 'NNG'),
#  ('문제', 'NNG'),
#  ('가', 'JKS'),
#  ('이', 'NP'),
#  ('같', 'VA'),
#  ('은', 'ETD'),
#  ('성과', 'NNG'),
#  ('와', 'JKM'),
#  ('병존', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'ECE'),
#  ('있', 'VXV'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('대한민국', 'NNG'),
#  ('의', 'JKG'),
#  ('행정', 'NNG'),
#  ('구역', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('은', 'JX'),
#  ('이코노', 'NNG'),
#  ('미스트', 'NNG'),
#  ('에서', 'JKM'),
#  ('발표', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETD'),
#  ('민주주의', 'NNG'),
#  ('지수', 'NNG'),
#  ('조사', 'NNG'),
#  ('에서', 'JKM'),
#  ('2019', 'NR'),
#  ('년', 'NNM'),
#  ('기준', 'NNG'),
#  ('23', 'NR'),
#  ('위의', 'NNG'),
#  ('8.0', 'NR'),
#  ('점', 'NNM'),
#  ('을', 'JKO'),
#  ('기록', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('바', 'NNB'),
#  ('와', 'JKM'),
#  ('같이', 'MAG'),
#  ('아시아', 'NNG'),
#  ('에서', 'JKM'),
#  ('민주주의', 'NNG'),
#  ('수준', 'NNG'),
#  ('이', 'JKS'),
#  ('가장', 'MAG'),
#  ('높', 'VA'),
#  ('은', 'ETD'),
#  ('국가', 'NNG'),
#  ('가운데', 'NNG'),
#  ('하', 'VV'),
#  ('나이다', 'EFN'),
#  ('.', 'SF'),
#  ('또', 'MAG'),
#  ('하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('대한민국', 'NNG'),
#  ('은', 'JX'),
#  ('주요', 'NNG'),
#  ('20', 'NR'),
#  ('개국', 'NNM'),
#  ('(', 'SS'),
#  ('G', 'OL'),
#  ('20', 'NR'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('경제', 'NNG'),
#  ('협력', 'NNG'),
#  ('개발', 'NNG'),
#  ('기구', 'NNG'),
#  ('(', 'SS'),
#  ('OECD', 'OL'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('개발', 'NNG'),
#  ('원조', 'NNG'),
#  ('위원회', 'NNG'),
#  ('(', 'SS'),
#  ('DAC', 'OL'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('파리', 'NNG'),
#  ('클럽', 'NNG'),
#  ('등', 'NNB'),
#  ('의', 'JKG'),
#  ('회원국', 'NNG'),
#  ('이', 'VCP'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('[', 'SS'),
#  ('8', 'NR'),
#  (']', 'SS'),
#  ('1948', 'NR'),
#  ('년', 'NNM'),
#  ('이후', 'NNG'),
#  ('로', 'JKM'),
#  ('오늘날', 'NNG'),
#  ('까지', 'JX'),
#  ('한반도', 'NNG'),
#  ('에', 'JKM'),
#  ('는', 'JX'),
#  ('대한민국', 'NNG'),
#  ('과', 'JKM'),
#  ('조선', 'NNG'),
#  ('민주주의', 'NNG'),
#  ('인민', 'NNG'),
#  ('공화국', 'NNG'),
#  ('이', 'VCP'),
#  ('라는', 'ETD'),
#  ('두', 'MDN'),
#  ('개', 'NNM'),
#  ('의', 'JKG'),
#  ('분단', 'NNG'),
#  ('국가', 'NNG'),
#  ('가', 'JKS'),
#  ('각각', 'MAG'),
#  ('남북', 'NNG'),
#  ('에', 'JKM'),
#  ('위치', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'ECE'),
#  ('있', 'VXV'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('한반도', 'NNG'),
#  ('와', 'JC'),
#  ('부', 'NNG'),
#  ('속도', 'NNG'),
#  ('서의', 'NNG'),
#  ('면적', 'NNG'),
#  ('은', 'JX'),
#  ('약', 'MDN'),
#  ('22', 'NR'),
#  ('만', 'NR'),
#  ('km', 'OL'),
#  ('2', 'NR'),
#  ('이', 'VCP'),
#  ('며', 'ECE'),
#  (',', 'SP'),
#  ('인구', 'NNG'),
#  ('는', 'JX'),
#  ('대한민국', 'NNG'),
#  ('과', 'JKM'),
#  ('조선', 'NNG'),
#  ('민주주의', 'NNG'),
#  ('인민', 'NNG'),
#  ('공화국', 'NNG'),
#  ('을', 'JKO'),
#  ('합치', 'VV'),
#  ('어', 'ECS'),
#  ('2019', 'NR'),
#  ('년', 'NNM'),
#  ('을', 'JKO'),
#  ('기준', 'NNG'),
#  ('으로', 'JKM'),
#  ('약', 'NNG'),
#  ('7,700', 'NR'),
#  ('만', 'NR'),
#  ('명', 'NNM'),
#  ('에', 'JKM'),
#  ('달하', 'VV'),
#  ('ㄴ다', 'ECS'),
#  ('[', 'SS'),
#  ('9', 'NR'),
#  (']', 'SS'),
#  ('.', 'SF')]

# %%
kkma_nouns = []
kkma_h = []
kkma_v = []

for i in res:
    if 'NN' in i[1]:
        kkma_nouns.append(i)
    elif 'VA' in i[1]:
        kkma_h.append(i)
    elif 'VV' in i[1]:
        kkma_v.append((i[0]+'다', i[1]))

# %%
kkma_nouns
# Out:
# [('대한민국', 'NNG'),
#  ('약칭', 'NNG'),
#  ('남한', 'NNG'),
#  ('한국', 'NNG'),
#  ('동아시아', 'NNP'),
#  ('한반도', 'NNG'),
#  ('남부', 'NNG'),
#  ('자리', 'NNG'),
#  ('민주', 'NNG'),
#  ('공화국', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('국기', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('국', 'NNG'),
#  ('기법', 'NNG'),
#  ('태극기', 'NNG'),
#  ('국가', 'NNG'),
#  ('관습', 'NNG'),
#  ('애', 'NNG'),
#  ('국가', 'NNG'),
#  ('국화', 'NNG'),
#  ('관습', 'NNG'),
#  ('상', 'NNG'),
#  ('무궁화', 'NNG'),
#  ('공용어', 'NNG'),
#  ('한국어', 'NNG'),
#  ('한국', 'NNG'),
#  ('수어', 'NNG'),
#  ('수도', 'NNG'),
#  ('서울', 'NNG'),
#  ('인구', 'NNG'),
#  ('명', 'NNM'),
#  ('전체', 'NNG'),
#  ('인구', 'NNG'),
#  ('중', 'NNB'),
#  ('절반', 'NNG'),
#  ('정도', 'NNG'),
#  ('수도권', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('년', 'NNM'),
#  ('월', 'NNM'),
#  ('일', 'NNM'),
#  ('총선거', 'NNG'),
#  ('제헌', 'NNG'),
#  ('국회', 'NNG'),
#  ('구성', 'NNG'),
#  ('년', 'NNM'),
#  ('월', 'NNM'),
#  ('일', 'NNM'),
#  ('대한민국', 'NNG'),
#  ('정부', 'NNG'),
#  ('수립', 'NNG'),
#  ('년', 'NNM'),
#  ('제헌', 'NNG'),
#  ('국회', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('국호', 'NNG'),
#  ('계승', 'NNG'),
#  ('헌법', 'NNG'),
#  ('명시', 'NNG'),
#  ('년', 'NNM'),
#  ('월', 'NNM'),
#  ('일', 'NNM'),
#  ('국무원', 'NNG'),
#  ('고시', 'NNG'),
#  ('제', 'NNG'),
#  ('호', 'NNM'),
#  ('국', 'NNG'),
#  ('호', 'NNG'),
#  ('일부', 'NNG'),
#  ('지방', 'NNG'),
#  ('명과', 'NNG'),
#  ('지도', 'NNG'),
#  ('색', 'NNG'),
#  ('사용', 'NNG'),
#  ('건', 'NNG'),
#  ('확정', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('세기', 'NNG'),
#  ('후반', 'NNG'),
#  ('이후', 'NNG'),
#  ('급격', 'NNG'),
#  ('경제', 'NNG'),
#  ('성장', 'NNG'),
#  ('과정', 'NNG'),
#  ('년대', 'NNM'),
#  ('말', 'NNG'),
#  ('외환', 'NNG'),
#  ('위기', 'NNG'),
#  ('등', 'NNB'),
#  ('부침', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('년', 'NNM'),
#  ('인', 'NNG'),
#  ('국민', 'NNG'),
#  ('총소득', 'NNG'),
#  ('은', 'NNG'),
#  ('명목', 'NNG'),
#  ('달러', 'NNM'),
#  ('년', 'NNM'),
#  ('유엔', 'NNG'),
#  ('개발', 'NNG'),
#  ('계획', 'NNG'),
#  ('이', 'NNG'),
#  ('발표', 'NNG'),
#  ('인간', 'NNG'),
#  ('개발', 'NNG'),
#  ('지수', 'NNG'),
#  ('조사', 'NNG'),
#  ('세계', 'NNG'),
#  ('위', 'NNM'),
#  ('기록', 'NNG'),
#  ('년', 'NNM'),
#  ('월', 'NNM'),
#  ('일', 'NNM'),
#  ('스위스', 'NNG'),
#  ('제네바', 'NNG'),
#  ('본부', 'NNG'),
#  ('차', 'NNM'),
#  ('무역', 'NNG'),
#  ('개발', 'NNG'),
#  ('이사회', 'NNG'),
#  ('마지막', 'NNG'),
#  ('회의', 'NNG'),
#  ('한국', 'NNG'),
#  ('지위', 'NNG'),
#  ('선진국', 'NNG'),
#  ('그룹', 'NNG'),
#  ('의견', 'NNG'),
#  ('일치', 'NNG'),
#  ('로', 'NNG'),
#  ('변경', 'NNG'),
#  ('선진국', 'NNG'),
#  ('인정', 'NNG'),
#  ('자살률', 'NNG'),
#  ('장시간', 'NNG'),
#  ('근로', 'NNG'),
#  ('문화', 'NNG'),
#  ('산업', 'NNG'),
#  ('재해', 'NNG'),
#  ('사망률', 'NNG'),
#  ('저출산', 'NNG'),
#  ('등', 'NNB'),
#  ('사회', 'NNG'),
#  ('문제', 'NNG'),
#  ('성과', 'NNG'),
#  ('병존', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('행정', 'NNG'),
#  ('구역', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('이코노', 'NNG'),
#  ('미스트', 'NNG'),
#  ('발표', 'NNG'),
#  ('민주주의', 'NNG'),
#  ('지수', 'NNG'),
#  ('조사', 'NNG'),
#  ('년', 'NNM'),
#  ('기준', 'NNG'),
#  ('위의', 'NNG'),
#  ('점', 'NNM'),
#  ('기록', 'NNG'),
#  ('바', 'NNB'),
#  ('아시아', 'NNG'),
#  ('민주주의', 'NNG'),
#  ('수준', 'NNG'),
#  ('국가', 'NNG'),
#  ('가운데', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('주요', 'NNG'),
#  ('개국', 'NNM'),
#  ('경제', 'NNG'),
#  ('협력', 'NNG'),
#  ('개발', 'NNG'),
#  ('기구', 'NNG'),
#  ('개발', 'NNG'),
#  ('원조', 'NNG'),
#  ('위원회', 'NNG'),
#  ('파리', 'NNG'),
#  ('클럽', 'NNG'),
#  ('등', 'NNB'),
#  ('회원국', 'NNG'),
#  ('년', 'NNM'),
#  ('이후', 'NNG'),
#  ('오늘날', 'NNG'),
#  ('한반도', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('조선', 'NNG'),
#  ('민주주의', 'NNG'),
#  ('인민', 'NNG'),
#  ('공화국', 'NNG'),
#  ('개', 'NNM'),
#  ('분단', 'NNG'),
#  ('국가', 'NNG'),
#  ('남북', 'NNG'),
#  ('위치', 'NNG'),
#  ('한반도', 'NNG'),
#  ('부', 'NNG'),
#  ('속도', 'NNG'),
#  ('서의', 'NNG'),
#  ('면적', 'NNG'),
#  ('인구', 'NNG'),
#  ('대한민국', 'NNG'),
#  ('조선', 'NNG'),
#  ('민주주의', 'NNG'),
#  ('인민', 'NNG'),
#  ('공화국', 'NNG'),
#  ('년', 'NNM'),
#  ('기준', 'NNG'),
#  ('약', 'NNG'),
#  ('명', 'NNM')]

# %%
kkma_h
# Out:
# [('높', 'VA'), ('높', 'VA'), ('같', 'VA'), ('높', 'VA')]

# %%
kkma_v
# Out:
# [('따르다', 'VV'),
#  ('살다', 'VV'),
#  ('통하다', 'VV'),
#  ('관하다', 'VV'),
#  ('의하다', 'VV'),
#  ('이루다', 'VV'),
#  ('있다', 'VV'),
#  ('하다', 'VV'),
#  ('열리다', 'VV'),
#  ('하다', 'VV'),
#  ('하다', 'VV'),
#  ('합치다', 'VV'),
#  ('달하다', 'VV')]

# %%
txt1
# Out:
# '\n대한민국, 약칭 남한, 한국은 동아시아의 한반도 남부에 자리한 민주공화국이다. 대한민국의 국기는 대한민국 국기법에 따라 태극기, 국가는 관습상 애국가, 국화는 관습상 무궁화이다. 공용어는 한국어와 한국 수어이다. 수도는 서울이다. 인구는 약 5,160만명으로, 전체 인구 중 절반 정도가 수도권에 살고 있다.\n\n대한민국은 1948년 5월 10일 총선거를 통해 제헌국회를 구성하였고, 1948년 8월 15일 대한민국 정부를 수립하였다. 1948년 제헌 국회에서 대한민국의 국호를 계승하여 헌법에 명시하였고, 다시 1950년 1월 16일 국무원 고시 제7호 ‘국호 및 일부 지방명과 지도색 사용에 관한 건’에 의해 확정하였다.\n\n대한민국은 20세기 후반 이후 급격한 경제 성장을 이루었다. 그 과정에서 1990년대 말 외환 위기 등의 부침이 있기도 했다. 대한민국의 2022년 1인당 국민 총소득 은 명목 3만 4,994달러이다. 2020년 유엔개발계획 이 매년 발표하는 인간개발지수  조사에서 세계 22위를 기록하였다. 2021년 7월 2일 스위스 제네바 본부에서 열린 ‘제68차 무역개발이사회’ 마지막 회의에서 한국의 지위를 선진국 그룹으로 ‘의견 일치’로 변경하고 선진국으로 인정했다. 다만 높은 자살률, 장시간 근로 문화와 높은 산업 재해 사망률, 저출산 등의 사회 문제가 이 같은 성과와 병존하고 있다. 대한민국의 행정 구역\n\n대한민국은 이코노미스트에서 발표하는 민주주의 지수 조사에서 2019년 기준 23위의 8.0점을 기록한 바와 같이 아시아에서 민주주의 수준이 가장 높은 국가 가운데 하나이다. 또한 대한민국은 주요 20개국 , 경제 협력 개발 기구 , 개발 원조 위원회 , 파리 클럽 등의 회원국이다.\n\n1948년 이후로 오늘날까지 한반도에는 대한민국과 조선민주주의인민공화국이라는 두 개의 분단국가가 각각 남북에 위치하고 있다. 한반도와 부속도서의 면적은 약 22만 km2이며, 인구는 대한민국과 조선민주주의인민공화국을 합쳐 2019년을 기준으로 약 7,700만 명에 달한다.\n'

# %%
re.findall('\(', txt)
# Out:
# ['(', '(', '(', '(', '(', '(', '(', '(', '(', '(']

# %% [markdown]
# # 반복 연습

# %%
okt.tagset
# Out:
# {'Adjective': '형용사',
#  'Adverb': '부사',
#  'Alpha': '알파벳',
#  'Conjunction': '접속사',
#  'Determiner': '관형사',
#  'Eomi': '어미',
#  'Exclamation': '감탄사',
#  'Foreign': '외국어, 한자 및 기타기호',
#  'Hashtag': '트위터 해쉬태그',
#  'Josa': '조사',
#  'KoreanParticle': '(ex: ㅋㅋ)',
#  'Noun': '명사',
#  'Number': '숫자',
#  'PreEomi': '선어말어미',
#  'Punctuation': '구두점',
#  'ScreenName': '트위터 아이디',
#  'Suffix': '접미사',
#  'Unknown': '미등록어',
#  'Verb': '동사'}

# %%
ls = ['Adjective', 'Verb']
res_a = []
res_v = []
for i,j in okt.pos(txt1):
    # print(i)
    # print(j)
    if j == 'Adjective':
        res_a.append(i)
    elif j == 'Verb':
        res_v.append(i)

# %%
res_a
# Out:
# ['있다', '의해', '급격한', '있기도', '높은', '높은', '같은', '있다', '높은', '있다']

# %%
kkma.tagset
# Out:
# {'EC': '연결 어미',
#  'ECD': '의존적 연결 어미',
#  'ECE': '대등 연결 어미',
#  'ECS': '보조적 연결 어미',
#  'EF': '종결 어미',
#  'EFA': '청유형 종결 어미',
#  'EFI': '감탄형 종결 어미',
#  'EFN': '평서형 종결 어미',
#  'EFO': '명령형 종결 어미',
#  'EFQ': '의문형 종결 어미',
#  'EFR': '존칭형 종결 어미',
#  'EP': '선어말 어미',
#  'EPH': '존칭 선어말 어미',
#  'EPP': '공손 선어말 어미',
#  'EPT': '시제 선어말 어미',
#  'ET': '전성 어미',
#  'ETD': '관형형 전성 어미',
#  'ETN': '명사형 전성 어미',
#  'IC': '감탄사',
#  'JC': '접속 조사',
#  'JK': '조사',
#  'JKC': '보격 조사',
#  'JKG': '관형격 조사',
#  'JKI': '호격 조사',
#  'JKM': '부사격 조사',
#  'JKO': '목적격 조사',
#  'JKQ': '인용격 조사',
#  'JKS': '주격 조사',
#  'JX': '보조사',
#  'MA': '부사',
#  'MAC': '접속 부사',
#  'MAG': '일반 부사',
#  'MD': '관형사',
#  'MDN': '수 관형사',
#  'MDT': '일반 관형사',
#  'NN': '명사',
#  'NNB': '일반 의존 명사',
#  'NNG': '보통명사',
#  'NNM': '단위 의존 명사',
#  'NNP': '고유명사',
#  'NP': '대명사',
#  'NR': '수사',
#  'OH': '한자',
#  'OL': '외국어',
#  'ON': '숫자',
#  'SE': '줄임표',
#  'SF': '마침표, 물음표, 느낌표',
#  'SO': '붙임표(물결,숨김,빠짐)',
#  'SP': '쉼표,가운뎃점,콜론,빗금',
#  'SS': '따옴표,괄호표,줄표',
#  'SW': '기타기호 (논리수학기호,화폐기호)',
#  'UN': '명사추정범주',
#  'VA': '형용사',
#  'VC': '지정사',
#  'VCN': "부정 지정사, 형용사 '아니다'",
#  'VCP': "긍정 지정사, 서술격 조사 '이다'",
#  'VV': '동사',
#  'VX': '보조 용언',
#  'VXA': '보조 형용사',
#  'VXV': '보조 동사',
#  'XP': '접두사',
#  'XPN': '체언 접두사',
#  'XPV': '용언 접두사',
#  'XR': '어근',
#  'XSA': '형용사 파생 접미사',
#  'XSN': '명사파생 접미사',
#  'XSV': '동사 파생 접미사'}

# %%
ls = ['VA', 'VV', 'XR']
res_a = []
res_v = []
res_r = []
for i,j in kkma.pos(txt1):
    # print(i)
    # print(j)
    if j == 'VA':
        res_a.append(i)
    elif j == 'VV':
        res_v.append(i+'다')
    elif j == 'XR':
        res_r.append(i)

# %%
res_v
# Out:
# ['따르다',
#  '살다',
#  '통하다',
#  '관하다',
#  '의하다',
#  '이루다',
#  '있다',
#  '하다',
#  '열리다',
#  '하다',
#  '하다',
#  '합치다',
#  '달하다']

# %%
res_a
# Out:
# ['높', '높', '같', '높']

# %%
k_nouns
# Out:
# ['대한',
#  '대한민국',
#  '민국',
#  '영어',
#  '약칭',
#  '남한',
#  '한국',
#  '은',
#  '동아시아',
#  '한반도',
#  '남부',
#  '자리',
#  '민주',
#  '민주공화국',
#  '공화국',
#  '국기',
#  '국',
#  '국기법',
#  '기법',
#  '태극기',
#  '3',
#  '국가',
#  '관습',
#  '애',
#  '애국가',
#  '4',
#  '국화',
#  '관습상',
#  '상',
#  '무궁화',
#  '공용어',
#  '한국어',
#  '수어',
#  '수도',
#  '서울',
#  '인구',
#  '5,160',
#  '5,160만명',
#  '만',
#  '명',
#  '전체',
#  '중',
#  '절반',
#  '정도',
#  '약',
#  '2611',
#  '2611만명',
#  '수도권',
#  '5',
#  '1948',
#  '1948년',
#  '년',
#  '5월',
#  '월',
#  '10',
#  '10일',
#  '일',
#  '총선거',
#  '제헌',
#  '제헌국회',
#  '국회',
#  '구성',
#  '8',
#  '8월',
#  '15',
#  '15일',
#  '정부',
#  '수립',
#  '국호',
#  '계승',
#  '헌법',
#  '명시',
#  '1950',
#  '1950년',
#  '1',
#  '1월',
#  '16',
#  '16일',
#  '국무원',
#  '고시',
#  '제',
#  '제7호',
#  '7',
#  '호',
#  '호',
#  '일부',
#  '지방',
#  '지방명과',
#  '명과',
#  '지도',
#  '지도색',
#  '색',
#  '사용',
#  '건',
#  '확정',
#  '20',
#  '20세기',
#  '세기',
#  '후반',
#  '이후',
#  '급격',
#  '경제',
#  '성장',
#  '과정',
#  '1990',
#  '1990년대',
#  '년대',
#  '말',
#  '외환',
#  '위기',
#  '등',
#  '부침',
#  '2022',
#  '2022년',
#  '1인',
#  '인',
#  '국민',
#  '총소득',
#  '명목',
#  '3만',
#  '4,994',
#  '4,994달러',
#  '달러',
#  '6',
#  '2020',
#  '2020년',
#  '유엔',
#  '유엔개발계획',
#  '개발',
#  '계획',
#  '이',
#  '발표',
#  '인간',
#  '인간개발지수',
#  '지수',
#  '조사',
#  '세계',
#  '22',
#  '22위',
#  '위',
#  '기록',
#  '2',
#  '2021',
#  '2021년',
#  '7월',
#  '2일',
#  '스위스',
#  '제네바',
#  '본부',
#  '저',
#  '68',
#  '68차',
#  '차',
#  '무역',
#  '무역개발이사회',
#  '이사회',
#  '마지막',
#  '회의',
#  '지위',
#  '선진국',
#  '그룹',
#  '의견',
#  '일치',
#  '로',
#  '변경',
#  '인정',
#  '자살률',
#  '장시간',
#  '근로',
#  '문화',
#  '산업',
#  '재해',
#  '사망률',
#  '저출산',
#  '사회',
#  '문제',
#  '이',
#  '성과',
#  '병존',
#  '행정',
#  '구역',
#  '이코노',
#  '이코노미스트',
#  '미스트',
#  '민주주의',
#  '주의',
#  '2019',
#  '2019년',
#  '기준',
#  '23',
#  '23위의',
#  '위의',
#  '8.0',
#  '8.0점',
#  '점',
#  '바',
#  '아시아',
#  '수준',
#  '가운데',
#  '주요',
#  '20개국',
#  '개국',
#  '협력',
#  '기구',
#  '원조',
#  '위원회',
#  '파리',
#  '클럽',
#  '회원국',
#  '오늘날',
#  '조선',
#  '인민',
#  '조선민주주의',
#  '개',
#  '분단',
#  '분단국가',
#  '남북',
#  '위치',
#  '부',
#  '부속도서의',
#  '속도',
#  '서의',
#  '면적',
#  '22만',
#  '조선민주주의인민공화국',
#  '7,700',
#  '7,700만',
#  '9']

# %%
re = k_nouns + res_a + res_v

# %%
len(re)
# Out:
# 245

# %%
re1 = ' '.join(re)

# %%
re1
# Out:
# '대한 대한민국 민국 영어 약칭 남한 한국 은 동아시아 한반도 남부 자리 민주 민주공화국 공화국 국기 국 국기법 기법 태극기 3 국가 관습 애 애국가 4 국화 관습상 상 무궁화 공용어 한국어 수어 수도 서울 인구 5,160 5,160만명 만 명 전체 중 절반 정도 약 2611 2611만명 수도권 5 1948 1948년 년 5월 월 10 10일 일 총선거 제헌 제헌국회 국회 구성 8 8월 15 15일 정부 수립 국호 계승 헌법 명시 1950 1950년 1 1월 16 16일 국무원 고시 제 제7호 7 호 호 일부 지방 지방명과 명과 지도 지도색 색 사용 건 확정 20 20세기 세기 후반 이후 급격 경제 성장 과정 1990 1990년대 년대 말 외환 위기 등 부침 2022 2022년 1인 인 국민 총소득 명목 3만 4,994 4,994달러 달러 6 2020 2020년 유엔 유엔개발계획 개발 계획 이 발표 인간 인간개발지수 지수 조사 세계 22 22위 위 기록 2 2021 2021년 7월 2일 스위스 제네바 본부 저 68 68차 차 무역 무역개발이사회 이사회 마지막 회의 지위 선진국 그룹 의견 일치 로 변경 인정 자살률 장시간 근로 문화 산업 재해 사망률 저출산 사회 문제 이 성과 병존 행정 구역 이코노 이코노미스트 미스트 민주주의 주의 2019 2019년 기준 23 23위의 위의 8.0 8.0점 점 바 아시아 수준 가운데 주요 20개국 개국 협력 기구 원조 위원회 파리 클럽 회원국 오늘날 조선 인민 조선민주주의 개 분단 분단국가 남북 위치 부 부속도서의 속도 서의 면적 22만 조선민주주의인민공화국 7,700 7,700만 9 높 높 같 높 따르다 살다 통하다 관하다 의하다 이루다 있다 하다 열리다 하다 하다 합치다 달하다'

# %%
# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# 유니코드에서  음수 부호설정
plt.rc('axes', unicode_minus=False)

wc = WordCloud('./NanumGothic.ttf',
               background_color = "white",
               max_words = 200)
               #stopwords = stopwords)
wc = wc.generate(re1) # str자료만 가능, list자료는 안됨
plt.figure(figsize = (12, 12))
plt.imshow(wc) #interpolation = "bilinear")
plt.axis("off")
plt.show()

# %%
s = ['이', '호', '대한민국', '대한', '한국', '민국']
re = [i for i in re if i not in s]

# %%
# Out:
# <module 're' from 'C:\\Users\\user\\.conda\\envs\\han\\lib\\re.py'>
