# %% [markdown]
# ### 티처블머신(라벨링)
#
#
# #### [참고] numpy 최소, 최대, 조건 색인값 : np.argmin(), np.argmax(), np.where()
#
# * 출처: https://rfriend.tistory.com/356
# ![image-3.png](attachment:image-3.png)

# %%
# 이미지 라벨링
from keras.models import load_model
from PIL import Image, ImageOps
import numpy as np

# Load the model
model = load_model('./converted_keras/keras_model.h5')

data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

image = Image.open('./tmp.jpg')
size = (224, 224)
image = ImageOps.fit(image, size, Image.ANTIALIAS)
image_array = np.asarray(image)
normalized_image_array = (image_array.astype(np.float32) / 127.0) - 1
data[0] = normalized_image_array

prediction = model.predict(data)
print(prediction)
class_name=['남','여']
print(class_name[np.argmax(prediction)])
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# [[0.11170391 0.88829607]]
# 여

# %%
# 여러 이미지 라벨링
from keras.models import load_model
from PIL import Image, ImageOps
import numpy as np
import matplotlib.pyplot as plt

# Load the model
model = load_model('./keras_model.h5')
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

#적용할 이미지list(fileList)
from glob import glob
fileList=glob('./image7/*.jpg')

for i in fileList:
    image = Image.open(i)
    size = (224, 224)
    image = ImageOps.fit(image, size, Image.ANTIALIAS)
    image_array = np.asarray(image)
    normalized_image_array = (image_array.astype(np.float32) / 127.0) - 1
    data[0] = normalized_image_array
    prediction = model.predict(data)
    class_name=['남','여']
    plt.imshow(image_array)
    plt.show()
    print(i,'====>',class_name[np.argmax(prediction)])
    print(prediction)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# C:\Users\user\AppData\Local\Temp\ipykernel_12824\3116760319.py:18: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   image = ImageOps.fit(image, size, Image.ANTIALIAS)
# 1/1 [==============================] - 1s 657ms/step
# ./image7\1face.jpg ====> 여
# [[0.06613892 0.9338611 ]]
# 1/1 [==============================] - 0s 33ms/step
# ./image7\2face.jpg ====> 남
# [[0.9149946  0.08500539]]
# 1/1 [==============================] - 0s 29ms/step
# ./image7\3face.jpg ====> 여
# [[0.32896322 0.6710368 ]]
# 1/1 [==============================] - 0s 35ms/step
# ./image7\4face.jpg ====> 남
# [[0.758823   0.24117704]]
# 1/1 [==============================] - 0s 32ms/step
# ./image7\5face.jpg ====> 남
# [[0.7255915 0.2744085]]
# 1/1 [==============================] - 0s 36ms/step
# ./image7\6face.jpg ====> 남
# [[0.58674806 0.41325197]]
# 1/1 [==============================] - 0s 28ms/step
# ./image7\7face.jpg ====> 남
# [[0.89832115 0.10167887]]
# 1/1 [==============================] - 0s 35ms/step
# ./image7\8face.jpg ====> 여
# [[0.16673012 0.8332699 ]]
