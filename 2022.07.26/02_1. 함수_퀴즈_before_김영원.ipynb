# %% [markdown]
# ### [퀴즈] 몫과 나머지를 구하는 함수
#
# ![image-2.png](attachment:image-2.png)

# %%
x = 10
y = 3

quotient, remainder = get_quotient_remainder(x, y)
print('몫: {0}, 나머지: {1}'.format(quotient, remainder))
# Out:
# 몫: 3, 나머지: 1

# %%
x = 10
y = 3

def get_quotient_remainder(x, y):
    return int(x/y), x%y

quotient, remainder = get_quotient_remainder(x, y)
print('몫: {0}, 나머지: {1}'.format(quotient, remainder))
# Out:
# 몫: 3, 나머지: 1

# %% [markdown]
# ### [퀴즈] 사칙 연산 만들기
# ![image.png](attachment:image.png)

# %%
x, y = map(int, input().split())


a, s, m, d = calc(x, y)
print('덧셈: {0}, 뺄셈: {1}, 곱셈: {2}, 나눗셈: {3}'.format(a, s, m, d))

# %%
x, y = map(int, input().split())

def calc(x, y):
    덧셈 = x+y
    뺄셈 = x-y
    곱셈 = x*y
    나눗셈 = format(x/y, '.1f')
    return 덧셈, 뺄셈, 곱셈 ,나눗셈

a, s, m, d = calc(x, y)
print('덧셈: {0}, 뺄셈: {1}, 곱셈: {2}, 나눗셈: {3}'.format(a, s, m, d))
# Out:
# 10 20
# 덧셈: 30, 뺄셈: -10, 곱셈: 200, 나눗셈: 0.5

# %% [markdown]
# ### [퀴즈] 가장 높은 점수 구하기
# ![image.png](attachment:image.png)

# %%
korean, english, mathematics, science = 100, 86, 81, 91



 
max_score = get_max_score(korean, english, mathematics, science)
print('높은 점수:', max_score)
 
max_score = get_max_score(english, science)
print('높은 점수:', max_score)
# Out:
# 높은 점수: 100
# 높은 점수: 91

# %%
korean, english, mathematics, science = 100, 86, 81, 91

def get_max_score(*args):
    print(type(args))
    return max(args)
 
max_score = get_max_score(korean, english, mathematics, science)
print('높은 점수:', max_score)
 
max_score = get_max_score(english, science)
print('높은 점수:', max_score)
# Out:
# <class 'tuple'>
# 높은 점수: 100
# <class 'tuple'>
# 높은 점수: 91

# %% [markdown]
# ### 퀴즈
# ![image.png](attachment:image.png)

# %%
korean, english, mathematics, science = map(int, input().split())

 


min_score, max_score = get_min_max_score(korean, english, mathematics, science)
average_score = get_average(korean=korean, english=english,
                            mathematics=mathematics, science=science)
print('낮은 점수: {0:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2:.2f}'
      .format(min_score, max_score, average_score))
# Out:
# 50 90 100 80
# 낮은 점수: 50.00, 높은 점수: 100.00, 평균 점수: 80.00

# %%
korean, english, mathematics, science = map(int, input().split())

def get_min_max_score(*a):
    return min(a), max(a)

def get_average(**a):
    return sum(a.values())/len(a)

min_score, max_score = get_min_max_score(korean, english, mathematics, science)
average_score = get_average(korean=korean, english=english,
                            mathematics=mathematics, science=science)
print('낮은 점수: {0:.2f}, 높은 점수: {1:.2f}, 평균 점수: {2:.2f}'
      .format(min_score, max_score, average_score))
# Out:
# 50 90 100 80
# 낮은 점수: 50.00, 높은 점수: 100.00, 평균 점수: 80.00

# %%
get_average(국어=30, 영어=20, 수학=100, 과학=40)
# Out:
# 47.5

# %%
get_average(음악=50, 미술=60)
# Out:
# 55.0

# %%
get_min_max_score(10,20,30)
# Out:
# (10, 30)

# %%
get_min_max_score(10,20,30,100,1,20,12,456)
# Out:
# (1, 456)
